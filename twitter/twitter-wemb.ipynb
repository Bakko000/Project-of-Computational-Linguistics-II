# %%
import sqlite3
import os
import sys

dim = 64   #32 o 64
dir = 'itwac'

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

sql_path = f'{parent_dir}/{dir}/itwac{dim}.sqlite'
txt_path = f'{parent_dir}/{dir}/itwac{dim}.txt'
conllu_dir = 'data/profiling_output/11226'

# %%
sql_path
# Out:
# 'c:\\Users\\corra\\Documents\\GitHub\\ProgettoLinCompII\\Project-of-Computational-Linguistics-II/itwac/itwac64.sqlite'

# %%
con = sqlite3.connect(sql_path)

# %%
cur = con.cursor()

# %%
with open(txt_path, 'w+') as out_file:
    for embedding in cur.execute("SELECT * FROM store"):
        str_embedding = [str(el) for el in embedding[:-1]]
        out_file.write('\t'.join(str_embedding)+'\n')

out_file.close()

# %%
embeddings_dim = 64
embeddings_path = f'itwac/itwac{embeddings_dim}.txt'

# %%
sys.path.append('..')  # Add parent directory to the Python path
from utils.helpers import *

# %%
embeddings = load_word_embeddings(parent_dir+"/"+embeddings_path)

# %%
embeddings['veder-']
# Out:
# array([-0.21470731, -0.1392023 ,  0.27303648, -0.05340238, -0.03936952,
#         0.02390084, -0.02741197, -0.12491986, -0.02866316,  0.00107179,
#        -0.09525209,  0.05685699,  0.01190181, -0.09539247,  0.06602568,
#        -0.0245655 , -0.09080959,  0.10820474, -0.04021769,  0.01245855,
#         0.19386294, -0.17447612, -0.03580143,  0.14230289,  0.22230086,
#         0.00798338, -0.07439804,  0.06270457, -0.00456899, -0.37990505,
#         0.06431432,  0.00839787, -0.06637963,  0.06906799, -0.30072612,
#         0.27667612, -0.06807792, -0.09943178, -0.10579097,  0.02905671,
#         0.20786461,  0.01789608, -0.08334571,  0.01347961,  0.06287382,
#         0.01383804, -0.00558291, -0.14960463, -0.12520191,  0.16182758,
#         0.07295152,  0.01592852, -0.01849817,  0.0850869 ,  0.04188532,
#        -0.05708888,  0.0698403 ,  0.02712907,  0.07868258, -0.01340355,
#         0.14947875, -0.33357722, -0.07842311,  0.02836373])

# %%
import os
all_documents_paths = []
for file_name in os.listdir(conllu_dir):
    file_path = os.path.join(conllu_dir, file_name)
    all_documents_paths.append(file_path)

# %%
all_documents = []

for document_path in all_documents_paths:
    document_tokens = get_tokens_from_file(document_path)
    all_documents.append(document_tokens)

# %%
all_documents
# Out:
# [[{'word': 'Ho', 'pos': 'AUX'},
#   {'word': 'appena', 'pos': 'ADV'},
#   {'word': 'visto', 'pos': 'VERB'},
#   {'word': "l'", 'pos': 'DET'},
#   {'word': 'ultima', 'pos': 'ADJ'},
#   {'word': 'puntata', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'quando', 'pos': 'SCONJ'},
#   {'word': 'ho', 'pos': 'AUX'},
#   {'word': 'iniziato', 'pos': 'VERB'},
#   {'word': 'sta', 'pos': 'ADJ'},
#   {'word': 'serie', 'pos': 'NOUN'},
#   {'word': 'tv', 'pos': 'NOUN'},
#   {'word': 'frank', 'pos': 'ADJ'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'faceva', 'pos': 'VERB'},
#   {'word': 'ridere', 'pos': 'VERB'},
#   {'word': 'ora', 'pos': 'ADV'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'fa', 'pos': 'VERB'},
#   {'word': 'solo', 'pos': 'ADV'},
#   {'word': 'incazzare', 'pos': 'VERB'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '#shameless', 'pos': 'NOUN'},
#   {'word': '#@dgx@dg@dg', 'pos': 'NUM'}],
#  [{'word': 'Oddio', 'pos': 'INTJ'},
#   {'word': 'Emiliano..', 'pos': 'PROPN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': "L'", 'pos': 'PRON'},
#   {'word': 'ho', 'pos': 'AUX'},
#   {'word': 'incrociato', 'pos': 'VERB'},
#   {'word': "all'", 'pos': 'ADP'},
#   {'word': 'inizio', 'pos': 'NOUN'},
#   {'word': 'della', 'pos': 'ADP'},
#   {'word': 'carriera', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'fine', 'pos': 'NOUN'},
#   {'word': 'anni', 'pos': 'NOUN'},
#   {'word': "'@dg@dg", 'pos': 'NUM'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'inizio', 'pos': 'NOUN'},
#   {'word': "'@dg@dg", 'pos': 'NUM'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Lui', 'pos': 'PRON'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'quel', 'pos': 'DET'},
#   {'word': 'tempo', 'pos': 'NOUN'},
#   {'word': 'faceva', 'pos': 'VERB'},
#   {'word': '...', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@matteorenzi', 'pos': 'ADP'},
#   {'word': 'Matteo', 'pos': 'PROPN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'mia', 'pos': 'DET'},
#   {'word': 'nonna', 'pos': 'NOUN'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'orecchiette', 'pos': 'NOUN'},
#   {'word': 'col', 'pos': 'ADP'},
#   {'word': 'ragù', 'pos': 'NOUN'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'vengono', 'pos': 'VERB'},
#   {'word': 'più', 'pos': 'ADV'},
#   {'word': 'come', 'pos': 'ADP'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'faceva', 'pos': 'VERB'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'volta', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Mettete', 'pos': 'VERB'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'emendamento', 'pos': 'NOUN'},
#   {'word': 'nel', 'pos': 'ADP'},
#   {'word': 'Cucinaitaliam', 'pos': 'PROPN'}],
#  [{'word': '@ch_distef', 'pos': 'NOUN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'faceva', 'pos': 'VERB'},
#   {'word': 'schifo', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': 'avevo', 'pos': 'AUX'},
#   {'word': 'sospetti', 'pos': 'VERB'},
#   {'word': 'anche', 'pos': 'ADV'},
#   {'word': 'sulla', 'pos': 'ADP'},
#   {'word': 'prima', 'pos': 'ADJ'}],
#  [{'word': '@arredi_sardi', 'pos': 'ADV'},
#   {'word': '@beppesardinia', 'pos': 'PROPN'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'lei..si', 'pos': 'ADJ'},
#   {'word': 'vede', 'pos': 'VERB'},
#   {'word': 'benissimo', 'pos': 'ADV'}],
#  [{'word': '@pierpaolorossi@dg', 'pos': 'SYM'},
#   {'word': 'forse', 'pos': 'ADV'},
#   {'word': 'dici', 'pos': 'VERB'},
#   {'word': 'così', 'pos': 'ADV'},
#   {'word': 'perché', 'pos': 'SCONJ'},
#   {'word': 'X', 'pos': 'ADJ'},
#   {'word': 'via', 'pos': 'NOUN'},
#   {'word': 'del', 'pos': 'ADP'},
#   {'word': 'ruolo', 'pos': 'NOUN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'ricopri.', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Ma', 'pos': 'CCONJ'},
#   {'word': 'tu', 'pos': 'PRON'},
#   {'word': 'sai', 'pos': 'VERB'},
#   {'word': 'benissimo', 'pos': 'ADV'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'Nn', 'pos': 'PROPN'},
#   {'word': 'hai', 'pos': 'AUX'},
#   {'word': 'mai', 'pos': 'ADV'},
#   {'word': 'avuto', 'pos': 'VERB'},
#   {'word': 'prova', 'pos': 'NOUN'},
#   {'word': "dell'", 'pos': 'ADP'},
#   {'word': 'esistenza', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'dio', 'pos': 'NOUN'}],
#  [{'word': '@sheilasartoni', 'pos': 'VERB'},
#   {'word': 'invece', 'pos': 'ADV'},
#   {'word': 'stai', 'pos': 'VERB'},
#   {'word': 'benissimo', 'pos': 'ADV'},
#   {'word': '...', 'pos': 'PUNCT'},
#   {'word': '!!!', 'pos': 'PUNCT'}],
#  [{'word': '@referenergia', 'pos': 'ADV'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'maggior', 'pos': 'ADJ'},
#   {'word': 'parte', 'pos': 'NOUN'},
#   {'word': 'delle', 'pos': 'ADP'},
#   {'word': 'concessioni', 'pos': 'NOUN'},
#   {'word': 'scadono', 'pos': 'VERB'},
#   {'word': 'tra', 'pos': 'ADP'},
#   {'word': 'quindici', 'pos': 'NUM'},
#   {'word': 'anni', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'lo', 'pos': 'PRON'},
#   {'word': 'sapete', 'pos': 'VERB'},
#   {'word': 'benissimo', 'pos': 'ADV'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '@giordi@dg@dg', 'pos': 'NUM'},
#   {'word': '@huffpostitalia', 'pos': 'PROPN'}],
#  [{'word': '@lilletta@dg@dg', 'pos': 'PROPN'},
#   {'word': 'hai', 'pos': 'AUX'},
#   {'word': 'notato', 'pos': 'VERB'},
#   {'word': 'pure', 'pos': 'ADV'},
#   {'word': 'te', 'pos': 'PRON'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'posa', 'pos': 'NOUN'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': 'aggraziatam', 'pos': 'PROPN'},
#   {'word': 'E', 'pos': 'CCONJ'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'panzam', 'pos': 'PROPN'},
#   {'word': 'Xd', 'pos': 'PROPN'}],
#  [{'word': 'Averne', 'pos': 'VERB'},
#   {'word': 'uno', 'pos': 'PRON'},
#   {'word': 'così', 'pos': 'ADV'},
#   {'word': 'oggi...', 'pos': 'PUNCT'},
#   {'word': 'visto', 'pos': 'VERB'},
#   {'word': 'come', 'pos': 'SCONJ'},
#   {'word': 'siamo', 'pos': 'AUX'},
#   {'word': 'messi', 'pos': 'VERB'},
#   {'word': 'servirebbe', 'pos': 'VERB'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': '...', 'pos': 'PUNCT'},
#   {'word': '#sixers', 'pos': 'PROPN'},
#   {'word': '#iverson', 'pos': 'ADP'},
#   {'word': '#nba', 'pos': 'NOUN'},
#   {'word': '___URL___', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'NOUN'},
#   {'word': '__LONG-LONG__', 'pos': 'PROPN'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': 'great-allen', 'pos': 'INTJ'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': 'iverson', 'pos': 'X'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': 'named-@dg@dg@dg@dg', 'pos': 'NUM'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': 'naismith-memorial', 'pos': 'ADJ'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': 'basketball-hall', 'pos': 'NOUN'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': 'fame-class', 'pos': 'NOUN'},
#   {'word': '…', 'pos': 'PUNCT'}],
#  [{'word': 'Crucia', 'pos': 'NOUN'},
#   {'word': "'", 'pos': 'PUNCT'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'certo', 'pos': 'ADV'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'Padova', 'pos': 'PROPN'},
#   {'word': 'ti', 'pos': 'PRON'},
#   {'word': 'lovvano', 'pos': 'VERB'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': 'Così', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'addolcirci', 'pos': 'VERB'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'lunedì', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '@giucruciani', 'pos': 'NOUN'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': 'mi', 'pos': 'PRON'},
#   {'word': 'piace', 'pos': 'VERB'},
#   {'word': '...', 'pos': 'PUNCT'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': 'Pensavo', 'pos': 'VERB'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'aver', 'pos': 'AUX'},
#   {'word': 'cestinato', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'sempre', 'pos': 'ADV'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'mia', 'pos': 'DET'},
#   {'word': 'nuova', 'pos': 'ADJ'},
#   {'word': 'filastrocca', 'pos': 'NOUN'},
#   {'word': '(', 'pos': 'PUNCT'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'piace', 'pos': 'VERB'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': ')', 'pos': 'PUNCT'},
#   {'word': '@twetmok', 'pos': 'ADJ'},
#   {'word': "l'", 'pos': 'PRON'},
#   {'word': 'ha', 'pos': 'AUX'},
#   {'word': 'recuperata', 'pos': 'VERB'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': 'io', 'pos': 'PRON'},
#   {'word': 'ora', 'pos': 'ADV'},
#   {'word': 'respiro', 'pos': 'VERB'},
#   {'word': 'Bravo', 'pos': 'PROPN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': '@luciasegreta', 'pos': 'VERB'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'perfezione..', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Sei', 'pos': 'NUM'},
#   {'word': 'strafiga', 'pos': 'NOUN'},
#   {'word': 'assai', 'pos': 'ADV'}],
#  [{'word': 'Ahahah', 'pos': 'NOUN'},
#   {'word': 'grazie', 'pos': 'NOUN'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'lo', 'pos': 'PRON'},
#   {'word': 'so', 'pos': 'VERB'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': ')', 'pos': 'PUNCT'},
#   {'word': '@faustoigorcampo', 'pos': 'NOUN'}],
#  [{'word': 'Assai', 'pos': 'PROPN'},
#   {'word': 'Mi', 'pos': 'PROPN'},
#   {'word': 'Piace', 'pos': 'PROPN'},
#   {'word': 'Certo', 'pos': 'PROPN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'piace', 'pos': 'VERB'},
#   {'word': 'mirare', 'pos': 'VERB'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'corpo', 'pos': 'NOUN'},
#   {'word': 'tuo', 'pos': 'ADJ'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'compiace…', 'pos': 'PUNCT'},
#   {'word': 'E', 'pos': 'CCONJ'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'tue', 'pos': 'DET'},
#   {'word': 'mani', 'pos': 'NOUN'},
#   {'word': 'bramo', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'sentire', 'pos': 'VERB'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'sul...', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@corriere', 'pos': 'VERB'},
#   {'word': 'I', 'pos': 'DET'},
#   {'word': 'vegani', 'pos': 'NOUN'},
#   {'word': 'sono', 'pos': 'AUX'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': 'bizzarri', 'pos': 'ADJ'}],
#  [{'word': 'Richardson', 'pos': 'PROPN'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'piace', 'pos': 'VERB'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': "L'", 'pos': 'DET'},
#   {'word': 'avevo', 'pos': 'NOUN'},
#   {'word': 'detto', 'pos': 'ADJ'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '#italianmadness', 'pos': 'PROPN'}],
#  [{'word': '@fabioarboit', 'pos': 'PROPN'},
#   {'word': 'menomale', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'Pupo', 'pos': 'PROPN'},
#   {'word': 'ha', 'pos': 'AUX'},
#   {'word': 'rallentato', 'pos': 'VERB'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': 'con', 'pos': 'ADP'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'produzione', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'materiale', 'pos': 'NOUN'},
#   {'word': 'discografico', 'pos': 'ADJ'},
#   {'word': '!', 'pos': 'PUNCT'}],
#  [{'word': '@gabryp@dg@dg@dg@dg', 'pos': 'PROPN'},
#   {'word': 'si', 'pos': 'PRON'},
#   {'word': 'assai', 'pos': 'VERB'},
#   {'word': 'proprio', 'pos': 'DET'},
#   {'word': 'ahahah', 'pos': 'NOUN'}],
#  [{'word': '@telerompo', 'pos': 'NOUN'},
#   {'word': 'dopo', 'pos': 'ADP'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'tante', 'pos': 'DET'},
#   {'word': 'uscite', 'pos': 'NOUN'},
#   {'word': 'assai', 'pos': 'ADV'},
#   {'word': 'dementi', 'pos': 'ADJ'},
#   {'word': 'era', 'pos': 'AUX'},
#   {'word': 'rimasto', 'pos': 'VERB'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'corto', 'pos': 'ADJ'},
#   {'word': "d'", 'pos': 'ADP'},
#   {'word': 'argomenti', 'pos': 'NOUN'}],
#  [{'word': 'Rt', 'pos': 'PROPN'},
#   {'word': '@laurapausini', 'pos': 'PROPN'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': 'Ah....grazie', 'pos': 'INTJ'},
#   {'word': 'anche', 'pos': 'ADV'},
#   {'word': 'da', 'pos': 'ADP'},
#   {'word': 'parte', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': '@paolacortellesi', 'pos': 'PROPN'},
#   {'word': 'altrimenti', 'pos': 'ADV'},
#   {'word': 'finiamo', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'ringraziare', 'pos': 'VERB'},
#   {'word': "l'", 'pos': 'DET'},
#   {'word': '8', 'pos': 'NUM'},
#   {'word': 'aprile', 'pos': 'NOUN'},
#   {'word': '2022', 'pos': 'NUM'},
#   {'word': '#', 'pos': 'PUNCT'},
#   {'word': 'Lauraepaola', 'pos': 'PROPN'}],
#  [{'word': '@giovannuzo', 'pos': 'PROPN'},
#   {'word': '@icapiscers', 'pos': 'PROPN'},
#   {'word': '@poliziadistato', 'pos': 'VERB'},
#   {'word': 'si', 'pos': 'PRON'},
#   {'word': 'calmi', 'pos': 'VERB'},
#   {'word': 'altrimenti', 'pos': 'ADV'},
#   {'word': 'le', 'pos': 'PRON'},
#   {'word': 'mando', 'pos': 'VERB'},
#   {'word': 'i', 'pos': 'DET'},
#   {'word': 'travoni', 'pos': 'NOUN'},
#   {'word': 'ha', 'pos': 'VERB'},
#   {'word': 'casa', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': '@giuliosiamonoi', 'pos': 'DET'},
#   {'word': '@giusyoni', 'pos': 'NOUN'},
#   {'word': 'Lo', 'pos': 'PRON'},
#   {'word': 'vorrei', 'pos': 'AUX'},
#   {'word': 'fare', 'pos': 'VERB'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'purtroppo', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'mio', 'pos': 'DET'},
#   {'word': 'pc', 'pos': 'NOUN'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'funziona', 'pos': 'VERB'},
#   {'word': 'bene', 'pos': 'ADV'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'fà', 'pos': 'VERB'},
#   {'word': 'più', 'pos': 'ADV'},
#   {'word': 'salvare', 'pos': 'VERB'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'foto', 'pos': 'NOUN'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': '(', 'pos': 'PUNCT'}],
#  [{'word': 'Sono', 'pos': 'AUX'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'dieta', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'sento', 'pos': 'VERB'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'profumo', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'pizza', 'pos': 'NOUN'},
#   {'word': 'dappertutto', 'pos': 'ADV'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@com_santin', 'pos': 'ADP'},
#   {'word': 'ti', 'pos': 'PRON'},
#   {'word': 'stolkeró', 'pos': 'PROPN'},
#   {'word': 'dappertutto', 'pos': 'ADV'}],
#  [{'word': 'A', 'pos': 'ADP'},
#   {'word': 'Pordenone', 'pos': 'PROPN'},
#   {'word': 'asfaltano', 'pos': 'VERB'},
#   {'word': 'dappertutto', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'strisce', 'pos': 'NOUN'},
#   {'word': 'le', 'pos': 'PRON'},
#   {'word': 'mettono', 'pos': 'VERB'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'mese', 'pos': 'NOUN'},
#   {'word': 'dopo', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'utile', 'pos': 'ADJ'},
#   {'word': 'devo', 'pos': 'AUX'},
#   {'word': 'dire', 'pos': 'VERB'}],
#  [{'word': '@luisaloffredo@dg@dg', 'pos': 'NUM'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': 'sta', 'pos': 'VERB'},
#   {'word': '#boschi', 'pos': 'PRON'},
#   {'word': 'spunta', 'pos': 'VERB'},
#   {'word': 'dappertutto', 'pos': 'DET'},
#   {'word': '@beppe_grillo', 'pos': 'NOUN'}],
#  [{'word': '@zooeydafne', 'pos': 'NOUN'},
#   {'word': 'vegani', 'pos': 'VERB'},
#   {'word': 'dappertutto', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'pagherete', 'pos': 'VERB'},
#   {'word': 'caro', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'pagherete', 'pos': 'VERB'},
#   {'word': 'tutto', 'pos': 'PRON'},
#   {'word': '!', 'pos': 'PUNCT'}],
#  [{'word': '@breakingdeed', 'pos': 'CCONJ'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'capisci', 'pos': 'NOUN'},
#   {'word': 'avrei', 'pos': 'VERB'},
#   {'word': 'da', 'pos': 'ADP'},
#   {'word': 'fare', 'pos': 'VERB'},
#   {'word': 'così', 'pos': 'ADV'},
#   {'word': 'tante', 'pos': 'DET'},
#   {'word': 'cose', 'pos': 'NOUN'},
#   {'word': '!', 'pos': 'PUNCT'}],
#  [{'word': '@paddypoweritaly', 'pos': 'PROPN'},
#   {'word': '@perottilucas', 'pos': 'PROPN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'cosa', 'pos': 'PRON'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': '4', 'pos': 'NUM'},
#   {'word': 'domenichem', 'pos': 'PROPN'}],
#  [{'word': '@carlopalomar', 'pos': 'NOUN'},
#   {'word': 'Sono', 'pos': 'AUX'},
#   {'word': 'sicura', 'pos': 'ADJ'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'ce', 'pos': 'VERB'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'farete', 'pos': 'NOUN'},
#   {'word': '...', 'pos': 'PUNCT'},
#   {'word': 'anzi', 'pos': 'ADV'},
#   {'word': 'faremo..', 'pos': 'PUNCT'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'siamo', 'pos': 'VERB'},
#   {'word': 'o', 'pos': 'CCONJ'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'siamo', 'pos': 'AUX'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'grande', 'pos': 'ADJ'},
#   {'word': 'famiglia', 'pos': 'NOUN'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': '#braccialettirossi', 'pos': 'PROPN'},
#   {'word': 'Watanka', 'pos': 'PROPN'}],
#  [{'word': '@epccattelan', 'pos': 'PROPN'},
#   {'word': '@alecattelan', 'pos': 'PROPN'},
#   {'word': '@skyuno', 'pos': 'PROPN'},
#   {'word': 'Ditemi', 'pos': 'PROPN'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': 'Cofanetto', 'pos': 'PROPN'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'Epcc', 'pos': 'PROPN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'please..', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': 'Iniziate', 'pos': 'PROPN'},
#   {'word': 'A', 'pos': 'PROPN'},
#   {'word': 'Riflettere', 'pos': 'PROPN'},
#   {'word': 'Su', 'pos': 'PROPN'},
#   {'word': 'Quello', 'pos': 'PROPN'},
#   {'word': 'Che', 'pos': 'PROPN'},
#   {'word': 'Farete', 'pos': 'PROPN'},
#   {'word': 'Il', 'pos': 'PROPN'},
#   {'word': '16', 'pos': 'NUM'},
#   {'word': '/@dg@dg', 'pos': 'NUM'},
#   {'word': 'Aprile', 'pos': 'PROPN'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': 'Sono', 'pos': 'AUX'},
#   {'word': 'Aperte', 'pos': 'PROPN'},
#   {'word': 'Le', 'pos': 'PROPN'},
#   {'word': 'Prenotazioni', 'pos': 'PROPN'},
#   {'word': 'Per', 'pos': 'PROPN'},
#   {'word': 'Assistere', 'pos': 'PROPN'},
#   {'word': 'Al', 'pos': 'ADP'},
#   {'word': 'Dramma...', 'pos': 'PROPN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@cicap', 'pos': 'NOUN'},
#   {'word': '@dariobressanini', 'pos': 'PROPN'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'ripresaf', 'pos': 'PROPN'},
#   {'word': 'Vi', 'pos': 'PRON'},
#   {'word': 'imploro', 'pos': 'VERB'}],
#  [{'word': 'Buongiorno', 'pos': 'ADV'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'tutti', 'pos': 'PRON'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': 'Cosa', 'pos': 'PRON'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'bello', 'pos': 'ADJ'},
#   {'word': 'oggif', 'pos': 'PROPN'},
#   {'word': 'Chi', 'pos': 'PRON'},
#   {'word': 'va', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'pratif', 'pos': 'PROPN'},
#   {'word': 'Cosa', 'pos': 'PROPN'},
#   {'word': 'metterete', 'pos': 'VERB'},
#   {'word': 'nel', 'pos': 'ADP'},
#   {'word': 'cestino', 'pos': 'NOUN'},
#   {'word': 'da', 'pos': 'ADP'},
#   {'word': 'pic-nicf', 'pos': 'PROPN'},
#   {'word': 'Imiterete...', 'pos': 'PROPN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': 'posto', 'pos': 'VERB'},
#   {'word': 'qui', 'pos': 'ADV'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'Link', 'pos': 'PROPN'},
#   {'word': 'dll', 'pos': 'NOUN'},
#   {'word': 'nostra', 'pos': 'DET'},
#   {'word': 'pagina', 'pos': 'NOUN'},
#   {'word': 'Youtube,tnt', 'pos': 'PROPN'},
#   {'word': 'Likee', 'pos': 'PROPN'},
#   {'word': 'Iscriveteviii', 'pos': 'PROPN'},
#   {'word': 'grazie', 'pos': 'NOUN'},
#   {'word': 'mille', 'pos': 'NUM'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'tutti..vi', 'pos': 'ADV'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'tante', 'pos': 'DET'},
#   {'word': 'risate.', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'},
#   {'word': 'Fjsgvxrsjsdzrtk@dgzg', 'pos': 'PROPN'},
#   {'word': '…', 'pos': 'PUNCT'}],
#  [{'word': '@dcava@dg@dg', 'pos': 'NUM'},
#   {'word': 'forza', 'pos': 'NOUN'},
#   {'word': 'ragazzi', 'pos': 'NOUN'},
#   {'word': 'sono', 'pos': 'AUX'},
#   {'word': 'sicura', 'pos': 'ADJ'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'gran', 'pos': 'ADJ'},
#   {'word': 'partita', 'pos': 'NOUN'},
#   {'word': 'domani', 'pos': 'ADV'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Siamo', 'pos': 'AUX'},
#   {'word': 'sempre', 'pos': 'ADV'},
#   {'word': 'con', 'pos': 'ADP'},
#   {'word': 'voi', 'pos': 'PRON'},
#   {'word': '#', 'pos': 'PUNCT'},
#   {'word': 'Govarese', 'pos': 'PROPN'},
#   {'word': '@pallvarese', 'pos': 'PROPN'}],
#  [{'word': 'Non', 'pos': 'ADV'},
#   {'word': 'so', 'pos': 'VERB'},
#   {'word': 'come', 'pos': 'SCONJ'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'scegliere', 'pos': 'VERB'},
#   {'word': 'quali', 'pos': 'DET'},
#   {'word': 'canzoni', 'pos': 'NOUN'},
#   {'word': 'cantare', 'pos': 'VERB'},
#   {'word': 'ai', 'pos': 'ADP'},
#   {'word': 'live', 'pos': 'NOUN'},
#   {'word': 'sono', 'pos': 'AUX'},
#   {'word': 'tutte', 'pos': 'DET'},
#   {'word': 'stupende', 'pos': 'NOUN'},
#   {'word': ';', 'pos': 'PUNCT'},
#   {'word': ')', 'pos': 'PUNCT'},
#   {'word': '@zeroassoluto', 'pos': 'ADJ'},
#   {'word': '@matteozero', 'pos': 'PROPN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'},
#   {'word': 'Zbqmfszo@dgwuuj@dg', 'pos': 'PROPN'},
#   {'word': '…', 'pos': 'PUNCT'}],
#  [{'word': '@michaelismysin', 'pos': 'ADP'},
#   {'word': 'Sì', 'pos': 'INTJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'fregatevene', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'tutto', 'pos': 'PRON'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'tutti', 'pos': 'PRON'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'vivete', 'pos': 'VERB'},
#   {'word': 'quello', 'pos': 'PRON'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'sentite', 'pos': 'VERB'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'sempre', 'pos': 'ADV'},
#   {'word': 'bene', 'pos': 'ADV'},
#   {'word': 'se', 'pos': 'SCONJ'},
#   {'word': 'seguite', 'pos': 'VERB'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'vostro', 'pos': 'DET'},
#   {'word': 'cuore', 'pos': 'NOUN'}],
#  [{'word': 'Viva', 'pos': 'VERB'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'speranza', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'salda', 'pos': 'NOUN'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'certezza', 'pos': 'NOUN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'farete', 'pos': 'VERB'},
#   {'word': 'Giustizia', 'pos': 'PROPN'},
#   {'word': '#gm@dg@dg@dg@dginfanzia', 'pos': 'VERB'},
#   {'word': '#finoallultimoidoneo', 'pos': 'ADJ'},
#   {'word': '@elenacentemero', 'pos': 'PROPN'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': 'I', 'pos': 'DET'},
#   {'word': 'punti', 'pos': 'NOUN'},
#   {'word': '3', 'pos': 'NUM'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'grazie', 'pos': 'NOUN'},
#   {'word': "all'", 'pos': 'ADP'},
#   {'word': 'Udinesem', 'pos': 'PROPN'},
#   {'word': 'Non', 'pos': 'ADV'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'risulta', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'pari', 'pos': 'ADJ'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'classifica', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Mi', 'pos': 'PRON'},
#   {'word': 'risulta', 'pos': 'VERB'},
#   {'word': 'invece', 'pos': 'ADV'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'avete...', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@fedefederossi', 'pos': 'VERB'},
#   {'word': 'Non', 'pos': 'ADV'},
#   {'word': 'vorrei', 'pos': 'AUX'},
#   {'word': 'dire', 'pos': 'VERB'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': "'", 'pos': 'PUNCT'},
#   {'word': 'sta', 'pos': 'VERB'},
#   {'word': 'notte', 'pos': 'NOUN'},
#   {'word': 'ho', 'pos': 'AUX'},
#   {'word': 'sognato', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'stavamo', 'pos': 'VERB'},
#   {'word': 'assieme', 'pos': 'ADV'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': 'Più', 'pos': 'ADV'},
#   {'word': 'o', 'pos': 'CCONJ'},
#   {'word': 'meno', 'pos': 'ADV'},
#   {'word': 'alle', 'pos': 'ADP'},
#   {'word': '18', 'pos': 'NUM'},
#   {'word': 'del', 'pos': 'ADP'},
#   {'word': '2', 'pos': 'NUM'},
#   {'word': 'Aprile', 'pos': 'PROPN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'tre', 'pos': 'NUM'},
#   {'word': 'anni', 'pos': 'NOUN'},
#   {'word': 'fa', 'pos': 'ADV'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'facendo', 'pos': 'VERB'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'nostra', 'pos': 'DET'},
#   {'word': 'prima', 'pos': 'ADJ'},
#   {'word': 'passeggiata', 'pos': 'NOUN'},
#   {'word': 'insieme', 'pos': 'ADV'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Tre', 'pos': 'NUM'},
#   {'word': 'anni', 'pos': 'NOUN'},
#   {'word': 'da...', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'ADJ'}],
#  [{'word': '@riccardol_', 'pos': 'PUNCT'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'parlando', 'pos': 'VERB'},
#   {'word': 'anche', 'pos': 'ADV'},
#   {'word': 'con', 'pos': 'ADP'},
#   {'word': 'lui', 'pos': 'PRON'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'pare', 'pos': 'VERB'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'cmq', 'pos': 'NOUN'},
#   {'word': 'dicevamo', 'pos': 'VERB'},
#   {'word': 'del', 'pos': 'ADP'},
#   {'word': 'filmm', 'pos': 'PROPN'}],
#  [{'word': 'Questa', 'pos': 'PRON'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'oggi', 'pos': 'ADV'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'piace', 'pos': 'VERB'},
#   {'word': 'Da', 'pos': 'PROPN'},
#   {'word': 'Impazzire', 'pos': 'PROPN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Stavamo', 'pos': 'AUX'},
#   {'word': 'cantando', 'pos': 'VERB'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'squarciagola', 'pos': 'NOUN'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'macchina', 'pos': 'NOUN'},
#   {'word': 'delle…', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': 'Per', 'pos': 'ADP'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'squadra', 'pos': 'NOUN'},
#   {'word': 'bianca', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'avrei', 'pos': 'AUX'},
#   {'word': 'più', 'pos': 'ADV'},
#   {'word': 'preso', 'pos': 'VERB'},
#   {'word': 'nessuno', 'pos': 'PRON'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'bene', 'pos': 'ADV'},
#   {'word': 'così', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'senza', 'pos': 'ADP'},
#   {'word': 'Emanuele', 'pos': 'PROPN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'Rua', 'pos': 'PROPN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '#amici@dg@dg', 'pos': 'PROPN'}],
#  [{'word': 'Adesso', 'pos': 'ADV'},
#   {'word': 'tutte', 'pos': 'DET'},
#   {'word': 'ad', 'pos': 'NOUN'},
#   {'word': 'essere', 'pos': 'AUX'},
#   {'word': 'fiere', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': '#mindofmine', 'pos': 'PROPN'},
#   {'word': 'quando', 'pos': 'SCONJ'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'anno', 'pos': 'NOUN'},
#   {'word': 'fa', 'pos': 'ADV'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'sclerando', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'suo', 'pos': 'DET'},
#   {'word': 'abbandono', 'pos': 'NOUN'}],
#  [{'word': 'Con', 'pos': 'ADP'},
#   {'word': 'bomber', 'pos': 'NOUN'},
#   {'word': 'Iodice', 'pos': 'PROPN'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': '5', 'pos': 'NUM'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': '1', 'pos': 'NUM'}],
#  [{'word': 'Pensare', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'io', 'pos': 'PRON'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'mia', 'pos': 'DET'},
#   {'word': 'sorella', 'pos': 'NOUN'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'guardando', 'pos': 'VERB'},
#   {'word': 'i', 'pos': 'DET'},
#   {'word': 'biglietti', 'pos': 'NOUN'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'andare', 'pos': 'VERB'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'Bruxelles', 'pos': 'PROPN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': 'Mi', 'pos': 'PRON'},
#   {'word': 'dispiace', 'pos': 'VERB'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'comunque', 'pos': 'ADV'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Una', 'pos': 'DET'},
#   {'word': 'volta', 'pos': 'NOUN'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'bene', 'pos': 'ADV'},
#   {'word': 'insieme', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': 'credo', 'pos': 'VERB'},
#   {'word': 'sia', 'pos': 'AUX'},
#   {'word': 'meglio', 'pos': 'ADV'},
#   {'word': 'prendere', 'pos': 'VERB'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'distanze', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': '@aranciatina', 'pos': 'NOUN'},
#   {'word': 'Ohohhh', 'pos': 'PROPN'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': 'Il', 'pos': 'DET'},
#   {'word': 'ritorno', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'Giusy', 'pos': 'PROPN'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': 'stavamo', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'chiamare', 'pos': 'VERB'},
#   {'word': 'Chi', 'pos': 'PRON'},
#   {'word': "l'", 'pos': 'PRON'},
#   {'word': 'ha', 'pos': 'VERB'},
#   {'word': 'visto...', 'pos': 'PUNCT'},
#   {'word': 'Daje', 'pos': 'ADV'},
#   {'word': 'de', 'pos': 'ADP'},
#   {'word': 'Taxi', 'pos': 'PROPN'},
#   {'word': '!', 'pos': 'PUNCT'}],
#  [{'word': '@lastvpart', 'pos': 'NOUN'},
#   {'word': '@butchurban', 'pos': 'NOUN'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'mia', 'pos': 'DET'},
#   {'word': 'amica', 'pos': 'NOUN'},
#   {'word': 'si', 'pos': 'PRON'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'fatta', 'pos': 'VERB'},
#   {'word': 'male', 'pos': 'ADV'},
#   {'word': 'allora', 'pos': 'ADV'},
#   {'word': 'ci', 'pos': 'PRON'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'preoccupando', 'pos': 'VERB'},
#   {'word': '"', 'pos': 'PUNCT'}],
#  [{'word': '@palets_@dg', 'pos': 'NUM'},
#   {'word': 'qua', 'pos': 'ADV'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'sa', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'scherzando', 'pos': 'VERB'},
#   {'word': 'sulle', 'pos': 'ADP'},
#   {'word': 'diete', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': '@peppepoeta', 'pos': 'PROPN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'vai', 'pos': 'VERB'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'sputtanare', 'pos': 'VERB'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'Tv', 'pos': 'PROPN'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@fcbayern', 'pos': 'ADP'},
#   {'word': 'certo', 'pos': 'ADV'},
#   {'word': 'mancava', 'pos': 'VERB'},
#   {'word': 'solo', 'pos': 'ADV'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'scritta', 'pos': 'NOUN'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': 'Arbeit', 'pos': 'PROPN'},
#   {'word': 'Macht', 'pos': 'PROPN'},
#   {'word': 'Frei', 'pos': 'PROPN'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'apposto', 'pos': 'VERB'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Ottima', 'pos': 'ADJ'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'scelta', 'pos': 'NOUN'},
#   {'word': 'dei', 'pos': 'ADP'},
#   {'word': 'binari', 'pos': 'NOUN'},
#   {'word': '#mangiacrauti', 'pos': 'ADJ'}],
#  [{'word': 'sembra', 'pos': 'VERB'},
#   {'word': 'tipo', 'pos': 'NOUN'},
#   {'word': 'ieri', 'pos': 'ADV'},
#   {'word': 'quando', 'pos': 'SCONJ'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'impazzendo', 'pos': 'VERB'},
#   {'word': 'su', 'pos': 'ADP'},
#   {'word': 'whatsapp', 'pos': 'NOUN'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'i', 'pos': 'DET'},
#   {'word': 'tuoi', 'pos': 'DET'},
#   {'word': 'primissimi', 'pos': 'ADJ'},
#   {'word': '@dg@dg@dgk', 'pos': 'NOUN'},
#   {'word': 'su', 'pos': 'ADP'},
#   {'word': 'yt', 'pos': 'NOUN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'NOUN'},
#   {'word': '/status/@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg',
#    'pos': 'NUM'},
#   {'word': '…', 'pos': 'PUNCT'}],
#  [{'word': '@benji_mascolo@benjiefede', 'pos': 'VERB'},
#   {'word': 'Eleni', 'pos': 'PROPN'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'nostro', 'pos': 'DET'},
#   {'word': 'sogno', 'pos': 'NOUN'},
#   {'word': 'Oddio', 'pos': 'PROPN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'bello', 'pos': 'ADJ'},
#   {'word': 'finalmente', 'pos': 'ADV'},
#   {'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'pianificando', 'pos': 'VERB'},
#   {'word': 'questa', 'pos': 'DET'},
#   {'word': 'cosa', 'pos': 'NOUN'},
#   {'word': 'da', 'pos': 'ADP'},
#   {'word': 'mesi', 'pos': 'NOUN'},
#   {'word': 'ormai', 'pos': 'ADV'}],
#  [{'word': 'stavamo', 'pos': 'AUX'},
#   {'word': 'tornando', 'pos': 'VERB'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'classe', 'pos': 'NOUN'},
#   {'word': 'alle', 'pos': 'ADP'},
#   {'word': '10', 'pos': 'NUM'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'ce', 'pos': 'VERB'},
#   {'word': "l'", 'pos': 'DET'},
#   {'word': 'avevo', 'pos': 'NOUN'},
#   {'word': 'davanti', 'pos': 'ADV'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'cazzo', 'pos': 'NOUN'},
#   {'word': 'quanto', 'pos': 'PRON'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'alto', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'me', 'pos': 'PRON'},
#   {'word': 'ne', 'pos': 'PRON'},
#   {'word': 'sono', 'pos': 'AUX'},
#   {'word': 'accorta', 'pos': 'VERB'},
#   {'word': 'soltanto', 'pos': 'ADV'},
#   {'word': 'adesso', 'pos': 'ADV'}],
#  [{'word': '@rvasco@dg@dg', 'pos': 'PROPN'},
#   {'word': 'si', 'pos': 'PRON'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'figata', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Anche', 'pos': 'ADV'},
#   {'word': 'noi', 'pos': 'PRON'},
#   {'word': 'facevamo', 'pos': 'VERB'},
#   {'word': 'fatica', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'adesso', 'pos': 'ADV'},
#   {'word': 'potremmo', 'pos': 'AUX'},
#   {'word': 'organizzare', 'pos': 'VERB'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'partita', 'pos': 'NOUN'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': '11', 'pos': 'NUM'},
#   {'word': 'anziché', 'pos': 'CCONJ'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': '5', 'pos': 'NUM'},
#   {'word': 'da', 'pos': 'ADP'},
#   {'word': 'tanti', 'pos': 'PRON'},
#   {'word': 'siamo', 'pos': 'AUX'}],
#  [{'word': '@fiat_it', 'pos': 'VERB'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'volta', 'pos': 'NOUN'},
#   {'word': 'facevamo', 'pos': 'VERB'},
#   {'word': 'belle', 'pos': 'ADJ'},
#   {'word': 'auto', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Ora', 'pos': 'ADV'},
#   {'word': 'con', 'pos': 'ADP'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'nuovo', 'pos': 'ADJ'},
#   {'word': 'A.d.', 'pos': 'PROPN'},
#   {'word': 'le', 'pos': 'PRON'},
#   {'word': 'prendiamo', 'pos': 'VERB'},
#   {'word': "dall'", 'pos': 'ADP'},
#   {'word': 'estero', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'È', 'pos': 'AUX'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'mazda', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': 'A', 'pos': 'ADP'},
#   {'word': 'saperlo', 'pos': 'VERB'},
#   {'word': 'lo', 'pos': 'PRON'},
#   {'word': 'facevamo', 'pos': 'AUX'},
#   {'word': 'accoppiare', 'pos': 'VERB'},
#   {'word': 'mesi', 'pos': 'NOUN'},
#   {'word': 'fa', 'pos': 'ADV'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'NOUN'},
#   {'word': 'tatus/@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg',
#    'pos': 'NUM'},
#   {'word': '…', 'pos': 'PUNCT'}],
#  [{'word': 'Ho', 'pos': 'AUX'},
#   {'word': 'sognato', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'biscottino', 'pos': 'VERB'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'vomitava', 'pos': 'AUX'},
#   {'word': 'addosso', 'pos': 'VERB'},
#   {'word': 'mentre', 'pos': 'SCONJ'},
#   {'word': 'facevamo', 'pos': 'VERB'},
#   {'word': 'cosacce', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'Volevo', 'pos': 'PROPN'},
#   {'word': 'Salutare', 'pos': 'PROPN'},
#   {'word': 'Freud', 'pos': 'PROPN'},
#   {'word': 'Che', 'pos': 'PROPN'},
#   {'word': 'Mi', 'pos': 'PROPN'},
#   {'word': 'Segue', 'pos': 'PROPN'},
#   {'word': 'Sempre', 'pos': 'VERB'},
#   {'word': 'Da', 'pos': 'PROPN'},
#   {'word': 'Casa', 'pos': 'PROPN'},
#   {'word': 'Ciao', 'pos': 'PROPN'},
#   {'word': 'Freud', 'pos': 'PROPN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': 'questa', 'pos': 'PRON'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'via', 'pos': 'NOUN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'facevamo', 'pos': 'VERB'},
#   {'word': 'avanti', 'pos': 'ADV'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'dietro', 'pos': 'ADV'},
#   {'word': 'spensierate', 'pos': 'VERB'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'era', 'pos': 'AUX'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'punto', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'incontro', 'pos': 'NOUN'},
#   {'word': 'con', 'pos': 'ADP'},
#   {'word': 'i', 'pos': 'DET'},
#   {'word': 'ragazzi', 'pos': 'NOUN'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'manca', 'pos': 'VERB'},
#   {'word': 'tutto...', 'pos': 'NOUN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@nunlodianessuno', 'pos': 'PRON'},
#   {'word': 'Se', 'pos': 'SCONJ'},
#   {'word': 'era', 'pos': 'VERB'},
#   {'word': 'della', 'pos': 'ADP'},
#   {'word': 'Roma', 'pos': 'PROPN'},
#   {'word': 'se', 'pos': 'SCONJ'},
#   {'word': 'facevamo', 'pos': 'VERB'},
#   {'word': 'tutte', 'pos': 'DET'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'trasferte', 'pos': 'NOUN'},
#   {'word': 'tutte.', 'pos': 'NOUN'},
#   {'word': '...e', 'pos': 'ADV'},
#   {'word': "'", 'pos': 'PUNCT'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'fratello', 'pos': 'NOUN'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': "c'", 'pos': 'PRON'},
#   {'word': 'ha', 'pos': 'AUX'},
#   {'word': 'sto', 'pos': 'VERB'},
#   {'word': 'difetto', 'pos': 'NOUN'},
#   {'word': 'grosso..', 'pos': 'NUM'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': '@officialmaz', 'pos': 'NOUN'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'telecronaca', 'pos': 'NOUN'},
#   {'word': 'la', 'pos': 'PRON'},
#   {'word': 'potevate', 'pos': 'AUX'},
#   {'word': 'far', 'pos': 'VERB'},
#   {'word': 'fare', 'pos': 'VERB'},
#   {'word': 'direttamente', 'pos': 'ADV'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'Moratti', 'pos': 'PROPN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'Thohir', 'pos': 'PROPN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'almeno', 'pos': 'ADV'},
#   {'word': 'ci', 'pos': 'PRON'},
#   {'word': 'facevamo', 'pos': 'VERB'},
#   {'word': '4', 'pos': 'NUM'},
#   {'word': 'risate', 'pos': 'NOUN'}],
#  [{'word': 'E', 'pos': 'CCONJ'},
#   {'word': 'visto', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'questa', 'pos': 'DET'},
#   {'word': 'settimana', 'pos': 'NOUN'},
#   {'word': 'sarei', 'pos': 'AUX'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'ferie', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'oggi', 'pos': 'ADV'},
#   {'word': 'ho', 'pos': 'ADJ'},
#   {'word': '3', 'pos': 'NUM'},
#   {'word': 'assemblee', 'pos': 'NOUN'},
#   {'word': 'da', 'pos': 'ADP'},
#   {'word': "un'", 'pos': 'DET'},
#   {'word': 'ora', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'mezza', 'pos': 'ADJ'},
#   {'word': 'ciascuna', 'pos': 'PRON'},
#   {'word': '...', 'pos': 'PUNCT'},
#   {'word': 'No', 'pos': 'INTJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'vabbè', 'pos': 'INTJ'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': '@davlucia', 'pos': 'PROPN'},
#   {'word': '@ritaritask@dg@dg', 'pos': 'PROPN'},
#   {'word': 'I', 'pos': 'DET'},
#   {'word': 'miei', 'pos': 'DET'},
#   {'word': 'Auguri', 'pos': 'NOUN'},
#   {'word': 'più', 'pos': 'ADV'},
#   {'word': 'cari', 'pos': 'ADJ'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'abbraccio', 'pos': 'NOUN'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'ciascuna', 'pos': 'PRON'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'voi*_*', 'pos': 'PUNCT'},
#   {'word': "'", 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': 'Si', 'pos': 'PRON'},
#   {'word': 'dice', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'ogni', 'pos': 'DET'},
#   {'word': 'persona', 'pos': 'NOUN'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'un’', 'pos': 'DET'},
#   {'word': 'isola', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'vero', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'ogni', 'pos': 'DET'},
#   {'word': 'persona', 'pos': 'NOUN'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'silenzio', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'questo', 'pos': 'PRON'},
#   {'word': 'sì', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'silenzio', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'ciascuna', 'pos': 'PRON'},
#   {'word': '...', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': 'Abbiamo', 'pos': 'VERB'},
#   {'word': "un'", 'pos': 'DET'},
#   {'word': 'arma', 'pos': 'NOUN'},
#   {'word': 'segreta', 'pos': 'ADJ'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'passione', 'pos': 'NOUN'},
#   {'word': 'politica', 'pos': 'ADJ'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'civile', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': "l'", 'pos': 'DET'},
#   {'word': 'intelligenza', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'competenze', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'ciascuna', 'pos': 'PRON'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'ciascuno', 'pos': 'PRON'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'voi', 'pos': 'PRON'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '#lameglioroma', 'pos': 'ADV'}],
#  [{'word': '@ginolanza@dg@dg', 'pos': 'NUM'},
#   {'word': 'sto', 'pos': 'AUX'},
#   {'word': 'lasciando', 'pos': 'VERB'},
#   {'word': 'fare', 'pos': 'VERB'},
#   {'word': 'tutto', 'pos': 'DET'},
#   {'word': 'ciò', 'pos': 'PRON'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'credi', 'pos': 'VERB'},
#   {'word': 'senza', 'pos': 'ADP'},
#   {'word': 'avere', 'pos': 'VERB'},
#   {'word': 'nessuna', 'pos': 'DET'},
#   {'word': 'reazione', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'E', 'pos': 'CCONJ'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'ne', 'pos': 'PRON'},
#   {'word': 'avrai', 'pos': 'VERB'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Sei', 'pos': 'AUX'},
#   {'word': 'grande', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'devo', 'pos': 'AUX'},
#   {'word': 'dirti', 'pos': 'VERB'},
#   {'word': 'io', 'pos': 'PRON'},
#   {'word': 'come', 'pos': 'ADP'}],
#  [{'word': '@arcibaldo@dg@dg@dg@dg@dg', 'pos': 'SYM'},
#   {'word': 'Nessuna', 'pos': 'DET'},
#   {'word': 'polemica', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Penso', 'pos': 'VERB'},
#   {'word': 'tu', 'pos': 'PRON'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'abbia', 'pos': 'VERB'},
#   {'word': 'idea', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'cosa', 'pos': 'PRON'},
#   {'word': 'possano', 'pos': 'AUX'},
#   {'word': 'dire', 'pos': 'VERB'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'purtroppo', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'specie', 'pos': 'ADV'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'noi', 'pos': 'PRON'},
#   {'word': 'donne.te', 'pos': 'PROPN'},
#   {'word': 'lo', 'pos': 'PRON'},
#   {'word': 'lascio', 'pos': 'VERB'},
#   {'word': 'immaginare', 'pos': 'VERB'},
#   {'word': '!', 'pos': 'PUNCT'}],
#  [{'word': '@pvantomhive', 'pos': 'X'},
#   {'word': 'me', 'pos': 'X'},
#   {'word': 'too', 'pos': 'X'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': 'Purtroppo', 'pos': 'ADV'},
#   {'word': 'quasi', 'pos': 'ADV'},
#   {'word': 'nessuna', 'pos': 'PRON'},
#   {'word': 'delle', 'pos': 'ADP'},
#   {'word': 'persone', 'pos': 'NOUN'},
#   {'word': 'con', 'pos': 'ADP'},
#   {'word': 'cui', 'pos': 'PRON'},
#   {'word': 'parlo', 'pos': 'PRON'},
#   {'word': 'li', 'pos': 'PRON'},
#   {'word': 'conosce', 'pos': 'VERB'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'sigh', 'pos': 'INTJ'}],
#  [{'word': '@sole@dg@dgore', 'pos': 'NOUN'},
#   {'word': 'Anche', 'pos': 'PROPN'},
#   {'word': 'Padoan', 'pos': 'PROPN'},
#   {'word': 'capitola', 'pos': 'NOUN'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': 'ripresa', 'pos': 'NOUN'},
#   {'word': 'più', 'pos': 'ADV'},
#   {'word': 'debole', 'pos': 'ADJ'},
#   {'word': 'del', 'pos': 'ADP'},
#   {'word': 'previsto', 'pos': 'NOUN'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Tra', 'pos': 'ADP'},
#   {'word': 'qualche', 'pos': 'DET'},
#   {'word': 'mese', 'pos': 'NOUN'},
#   {'word': 'dirà', 'pos': 'VERB'},
#   {'word': 'nessuna', 'pos': 'DET'},
#   {'word': 'ripresa', 'pos': 'NOUN'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': 'Altro', 'pos': 'PRON'},
#   {'word': 'che', 'pos': 'ADP'},
#   {'word': 'Gufi', 'pos': 'PROPN'},
#   {'word': '!!!', 'pos': 'PUNCT'}],
#  [{'word': 'Formigoni', 'pos': 'PROPN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'quanto', 'pos': 'ADV'},
#   {'word': 'vorrei', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': "t'", 'pos': 'PRON'},
#   {'word': 'avessero', 'pos': 'AUX'},
#   {'word': 'condannato', 'pos': 'VERB'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'pagare', 'pos': 'VERB'},
#   {'word': 'milioni', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'euro', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Che', 'pos': 'ADP'},
#   {'word': 'mai', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'tuttavia', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'sarebbero...', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@marcellochirico', 'pos': 'PROPN'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': 'se', 'pos': 'SCONJ'},
#   {'word': 'anche', 'pos': 'ADV'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'avessero', 'pos': 'AUX'},
#   {'word': 'espulso', 'pos': 'VERB'},
# ...
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'fax', 'pos': 'NOUN'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'tecnologicamente', 'pos': 'ADV'},
#   {'word': 'evoluto', 'pos': 'ADJ'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': '@maxrayspring', 'pos': 'PROPN'},
#   {'word': '@alesbaudelaire', 'pos': 'PROPN'},
#   {'word': '@edithbrinca', 'pos': 'PROPN'},
#   {'word': 'Ragazzi', 'pos': 'PROPN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'posate', 'pos': 'VERB'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'grappa', 'pos': 'NOUN'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': 'Ahahahah', 'pos': 'PROPN'},
#   {'word': 'No', 'pos': 'PROPN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'dai', 'pos': 'ADP'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'effetti', 'pos': 'NOUN'},
#   {'word': 'può', 'pos': 'AUX'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'bambolotto', 'pos': 'NOUN'},
#   {'word': 'sdraiato', 'pos': 'ADJ'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': ')', 'pos': 'PUNCT'}],
#  [{'word': 'Quercia…un', 'pos': 'DET'},
#   {'word': 'nome', 'pos': 'NOUN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'può', 'pos': 'AUX'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'bizzarro', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'inadeguato', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'venere', 'pos': 'NOUN'},
#   {'word': 'bianca', 'pos': 'ADJ'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'stupenda', 'pos': 'ADJ'},
#   {'word': 'come', 'pos': 'ADP'},
#   {'word': 'questa', 'pos': 'DET'},
#   {'word': 'dolcissima...', 'pos': 'NOUN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@simplemariatv', 'pos': 'PROPN'},
#   {'word': '@franciscorubio_', 'pos': 'PROPN'},
#   {'word': '@claudiatroyo', 'pos': 'PROPN'},
#   {'word': 'Se', 'pos': 'PROPN'},
#   {'word': 'Si', 'pos': 'PROPN'},
#   {'word': 'Guarda', 'pos': 'PROPN'},
#   {'word': 'Maria', 'pos': 'PROPN'},
#   {'word': 'Sembra', 'pos': 'PROPN'},
#   {'word': 'Che', 'pos': 'PROPN'},
#   {'word': 'Voglia', 'pos': 'PROPN'},
#   {'word': 'A', 'pos': 'ADP'},
#   {'word': 'Tutti', 'pos': 'DET'},
#   {'word': 'I', 'pos': 'DET'},
#   {'word': 'Costi', 'pos': 'NOUN'},
#   {'word': 'Sembrare', 'pos': 'PROPN'},
#   {'word': 'Felice', 'pos': 'PROPN'},
#   {'word': 'Di', 'pos': 'ADP'},
#   {'word': 'Santocristo', 'pos': 'PROPN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'Ma', 'pos': 'PROPN'},
#   {'word': 'Dudo', 'pos': 'PROPN'}],
#  [{'word': '#perquanto', 'pos': 'ADV'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'vita', 'pos': 'NOUN'},
#   {'word': 'possa', 'pos': 'AUX'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'difficile', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'c’', 'pos': 'PRON'},
#   {'word': 'è', 'pos': 'VERB'},
#   {'word': 'sempre', 'pos': 'ADV'},
#   {'word': 'qualcosa', 'pos': 'PRON'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'si', 'pos': 'PRON'},
#   {'word': 'può', 'pos': 'AUX'},
#   {'word': 'fare', 'pos': 'VERB'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'avere', 'pos': 'VERB'},
#   {'word': 'successo', 'pos': 'NOUN'}],
#  [{'word': '"', 'pos': 'PUNCT'},
#   {'word': 'La', 'pos': 'DET'},
#   {'word': 'cucina', 'pos': 'NOUN'},
#   {'word': 'semplice', 'pos': 'ADJ'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'deve', 'pos': 'AUX'},
#   {'word': 'mai', 'pos': 'ADV'},
#   {'word': 'vergognarsi', 'pos': 'VERB'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'povera', 'pos': 'ADJ'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'gusto', 'pos': 'NOUN'},
#   {'word': 'è', 'pos': 'VERB'},
#   {'word': 'nelle', 'pos': 'ADP'},
#   {'word': 'piccole', 'pos': 'ADJ'},
#   {'word': 'cose', 'pos': 'NOUN'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': 'Paolo', 'pos': 'PROPN'},
#   {'word': 'Cacciani...', 'pos': 'PROPN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': '@mirka_elena', 'pos': 'PROPN'},
#   {'word': '@ilavolover@dg@dg', 'pos': 'PROPN'},
#   {'word': '@emma_bosco', 'pos': 'ADJ'},
#   {'word': '@maretta_@dg@dg', 'pos': 'PROPN'},
#   {'word': '@laury@dg@dg@dg@dg@dg', 'pos': 'NUM'},
#   {'word': 'effettivamente', 'pos': 'ADV'},
#   {'word': 'potrebbe', 'pos': 'AUX'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': ')', 'pos': 'PUNCT'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': '-)ma', 'pos': 'ADJ'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'normale', 'pos': 'ADJ'}],
#  [{'word': 'Ma', 'pos': 'CCONJ'},
#   {'word': 'poi', 'pos': 'ADV'},
#   {'word': 'pensa', 'pos': 'VERB'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'bello', 'pos': 'ADJ'},
#   {'word': 'Batman', 'pos': 'PROPN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'può', 'pos': 'AUX'},
#   {'word': 'andare', 'pos': 'VERB'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'giro', 'pos': 'NOUN'},
#   {'word': 'dalle', 'pos': 'ADP'},
#   {'word': 'tipe', 'pos': 'NOUN'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'chiedere', 'pos': 'VERB'},
#   {'word': 'se', 'pos': 'SCONJ'},
#   {'word': 'vogliono', 'pos': 'AUX'},
#   {'word': 'vedere', 'pos': 'VERB'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'pipistrello', 'pos': 'NOUN'},
#   {'word': 'senza', 'pos': 'ADP'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'maniaco', 'pos': 'NOUN'}],
#  [{'word': '#', 'pos': 'PUNCT'},
#   {'word': 'Perquanto', 'pos': 'ADV'},
#   {'word': 'possa', 'pos': 'AUX'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'difficile', 'pos': 'ADJ'},
#   {'word': "l'", 'pos': 'DET'},
#   {'word': 'importante', 'pos': 'ADJ'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'sorridere', 'pos': 'VERB'},
#   {'word': 'ogni', 'pos': 'DET'},
#   {'word': 'giorno', 'pos': 'NOUN'}],
#  [{'word': 'Grazie', 'pos': 'NOUN'},
#   {'word': 'Chiara', 'pos': 'PROPN'},
#   {'word': 'Ferragni', 'pos': 'PROPN'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'far', 'pos': 'VERB'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'mia', 'pos': 'DET'},
#   {'word': 'vita', 'pos': 'NOUN'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'merda', 'pos': 'NOUN'}],
#  [{'word': '"', 'pos': 'PUNCT'},
#   {'word': 'Weekend', 'pos': 'PROPN'},
#   {'word': 'con', 'pos': 'ADP'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'mirto', 'pos': 'NOUN'},
#   {'word': '"', 'pos': 'PUNCT'},
#   {'word': 'Storia', 'pos': 'PROPN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'un', 'pos': 'DET'},
#   {'word': 'sardo', 'pos': 'NOUN'},
#   {'word': 'ubriaco', 'pos': 'ADJ'},
#   {'word': 'portato', 'pos': 'VERB'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'giro', 'pos': 'NOUN'},
#   {'word': 'dai', 'pos': 'ADP'},
#   {'word': 'suoi', 'pos': 'DET'},
#   {'word': 'amici', 'pos': 'NOUN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': 'cercano', 'pos': 'VERB'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'farlo', 'pos': 'VERB'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'sobrio', 'pos': 'ADJ'},
#   {'word': '#storpiamiunfilm', 'pos': 'PROPN'}],
#  [{'word': 'E', 'pos': 'CCONJ'},
#   {'word': 'Senza', 'pos': 'ADP'},
#   {'word': 'mai', 'pos': 'ADV'},
#   {'word': 'badare', 'pos': 'VERB'},
#   {'word': 'quanto', 'pos': 'PRON'},
#   {'word': 'debole', 'pos': 'ADJ'},
#   {'word': 'agli', 'pos': 'ADP'},
#   {'word': 'occhi', 'pos': 'NOUN'},
#   {'word': 'di', 'pos': 'ADP'},
#   {'word': 'qualcuno', 'pos': 'PRON'},
#   {'word': 'puoi', 'pos': 'AUX'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'chi', 'pos': 'PRON'},
#   {'word': 'sopravvive', 'pos': 'VERB'},
#   {'word': 'senza', 'pos': 'ADP'},
#   {'word': 'lamentarsi', 'pos': 'VERB'},
#   {'word': '!', 'pos': 'PUNCT'}],
#  [{'word': 'Il', 'pos': 'DET'},
#   {'word': 'servizio', 'pos': 'NOUN'},
#   {'word': 'pseudofemminista', 'pos': 'ADJ'},
#   {'word': 'sulla', 'pos': 'ADP'},
#   {'word': 'sminatrice', 'pos': 'NOUN'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'moderni', 'pos': 'ADJ'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '#tg@dg', 'pos': 'NUM'}],
#  [{'word': '@_thebrainer', 'pos': 'PROPN'},
#   {'word': 'dipende', 'pos': 'VERB'},
#   {'word': 'dal', 'pos': 'ADP'},
#   {'word': 'colorito', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': "dall'", 'pos': 'ADP'},
#   {'word': 'età', 'pos': 'NOUN'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': 'può', 'pos': 'AUX'},
#   {'word': 'anche', 'pos': 'ADV'},
#   {'word': 'farci', 'pos': 'VERB'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'annegati', 'pos': 'NOUN'},
#   {'word': 'ripescati', 'pos': 'ADJ'},
#   {'word': 'o', 'pos': 'CCONJ'},
#   {'word': 'vecchi', 'pos': 'ADJ'},
#   {'word': 'pappagalli', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': '@earl_decker', 'pos': 'PROPN'},
#   {'word': 'È', 'pos': 'AUX'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'differenza', 'pos': 'NOUN'},
#   {'word': 'che', 'pos': 'PRON'},
#   {'word': "c'", 'pos': 'PRON'},
#   {'word': 'è', 'pos': 'VERB'},
#   {'word': 'tra', 'pos': 'ADP'},
#   {'word': "l'", 'pos': 'DET'},
#   {'word': 'essere', 'pos': 'AUX'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': '...ciao', 'pos': 'PROPN'},
#   {'word': 'grazie,un', 'pos': 'DET'},
#   {'word': 'caro', 'pos': 'ADJ'},
#   {'word': 'saluto', 'pos': 'NOUN'}],
#  [{'word': 'Sembrare', 'pos': 'VERB'},
#   {'word': 'più', 'pos': 'ADV'},
#   {'word': 'giovani', 'pos': 'ADJ'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': 'tante', 'pos': 'DET'},
#   {'word': 'piccole', 'pos': 'ADJ'},
#   {'word': 'buone', 'pos': 'ADJ'},
#   {'word': 'abitudini', 'pos': 'NOUN'},
#   {'word': 'da', 'pos': 'ADP'},
#   {'word': 'seguire', 'pos': 'VERB'},
#   {'word': 'ogni', 'pos': 'DET'},
#   {'word': 'giorno', 'pos': 'NOUN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'}],
#  [{'word': 'Dio', 'pos': 'NOUN'},
#   {'word': 'Pull', 'pos': 'PROPN'},
#   {'word': '&', 'pos': 'SYM'},
#   {'word': 'Bear', 'pos': 'PROPN'},
#   {'word': 'con', 'pos': 'ADP'},
#   {'word': 'tutte', 'pos': 'DET'},
#   {'word': 'quelle', 'pos': 'DET'},
#   {'word': 'luci', 'pos': 'NOUN'},
#   {'word': 'camioncini', 'pos': 'ADJ'},
#   {'word': 'commesse', 'pos': 'ADJ'},
#   {'word': 'fighe', 'pos': 'NOUN'},
#   {'word': 'fa', 'pos': 'VERB'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'cose', 'pos': 'NOUN'},
#   {'word': 'belle', 'pos': 'ADJ'},
#   {'word': 'poi', 'pos': 'ADV'},
#   {'word': 'le', 'pos': 'DET'},
#   {'word': 'provi', 'pos': 'NOUN'},
#   {'word': 'nella', 'pos': 'ADP'},
#   {'word': 'tua', 'pos': 'DET'},
#   {'word': 'cameretta', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'fanno', 'pos': 'VERB'},
#   {'word': 'cagare', 'pos': 'VERB'}],
#  [{'word': 'Com', 'pos': 'NOUN'},
#   {'word': 'se', 'pos': 'SCONJ'},
#   {'word': 'qui', 'pos': 'ADV'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'avessimo', 'pos': 'VERB'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'sole', 'pos': 'NOUN'},
#   {'word': '___URL___', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'PROPN'},
#   {'word': 's/@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg@dg',
#    'pos': 'NUM'},
#   {'word': '…', 'pos': 'PUNCT'}],
#  [{'word': '@f@dg@dgrux', 'pos': 'ADP'},
#   {'word': 'semplicemente', 'pos': 'ADV'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'passi', 'pos': 'VERB'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'quelle', 'pos': 'PRON'},
#   {'word': 'al', 'pos': 'ADP'},
#   {'word': 'suo', 'pos': 'DET'},
#   {'word': 'livello', 'pos': 'NOUN'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'avrà', 'pos': 'VERB'},
#   {'word': 'da', 'pos': 'ADP'},
#   {'word': 'sforzarsi', 'pos': 'VERB'},
#   {'word': 'a', 'pos': 'ADP'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'intelligente', 'pos': 'ADJ'},
#   {'word': ':', 'pos': 'PUNCT'},
#   {'word': "l'", 'pos': 'DET'},
#   {'word': 'ernia', 'pos': 'NOUN'},
#   {'word': 'al', 'pos': 'ADP'},
#   {'word': 'cervello', 'pos': 'NOUN'},
#   {'word': 'è', 'pos': 'AUX'},
#   {'word': 'brutta', 'pos': 'ADJ'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '@szampa@dg@dg', 'pos': 'SYM'}],
#  [{'word': 'Ho', 'pos': 'VERB'},
#   {'word': '30', 'pos': 'NUM'},
#   {'word': 'anni', 'pos': 'NOUN'},
#   {'word': ',', 'pos': 'PUNCT'},
#   {'word': 'sono', 'pos': 'AUX'},
#   {'word': 'sottopagata', 'pos': 'VERB'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'frustrata', 'pos': 'VERB'},
#   {'word': 'ma', 'pos': 'CCONJ'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'mia', 'pos': 'DET'},
#   {'word': 'vita', 'pos': 'NOUN'},
#   {'word': 'su', 'pos': 'ADP'},
#   {'word': '#instagram', 'pos': 'PROPN'},
#   {'word': 'deve', 'pos': 'AUX'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'contrario', 'pos': 'NOUN'},
#   {'word': '-', 'pos': 'PUNCT'},
#   {'word': 'Tpi', 'pos': 'DET'},
#   {'word': '___URL___', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '___URL___', 'pos': 'DET'},
#   {'word': 'iti', 'pos': 'NOUN'},
#   {'word': '/', 'pos': 'PUNCT'},
#   {'word': 'cortometraggi', 'pos': 'NOUN'},
#   {'word': '-samantha-jayne', 'pos': 'ADJ'},
#   {'word': '-millennials', 'pos': 'X'},
#   {'word': '…', 'pos': 'PUNCT'},
#   {'word': 'via', 'pos': 'NOUN'},
#   {'word': '@tpi', 'pos': 'ADJ'}],
#  [{'word': '@astro_luca', 'pos': 'ADV'},
#   {'word': 'massiccia', 'pos': 'VERB'},
#   {'word': 'la', 'pos': 'DET'},
#   {'word': 'medaglia', 'pos': 'NOUN'},
#   {'word': 'dei', 'pos': 'ADP'},
#   {'word': '200', 'pos': 'NUM'},
#   {'word': 'gloriosi', 'pos': 'NOUN'},
#   {'word': 'miglia...', 'pos': 'PUNCT'},
#   {'word': 'Solo', 'pos': 'ADV'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'non', 'pos': 'ADV'},
#   {'word': 'usare', 'pos': 'VERB'},
#   {'word': 'figata', 'pos': 'NOUN'},
#   {'word': '!', 'pos': 'PUNCT'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'poco', 'pos': 'ADV'},
#   {'word': 'fine', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': "E'", 'pos': 'AUX'},
#   {'word': 'meglio', 'pos': 'ADV'},
#   {'word': 'stare', 'pos': 'VERB'},
#   {'word': 'in', 'pos': 'ADP'},
#   {'word': 'silenzio', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'stupidi', 'pos': 'NOUN'},
#   {'word': 'che', 'pos': 'SCONJ'},
#   {'word': 'aprire', 'pos': 'VERB'},
#   {'word': 'bocca', 'pos': 'NOUN'},
#   {'word': 'e', 'pos': 'CCONJ'},
#   {'word': 'togliere', 'pos': 'VERB'},
#   {'word': 'ogni', 'pos': 'DET'},
#   {'word': 'dubbio', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': '(', 'pos': 'PUNCT'},
#   {'word': 'Cit', 'pos': 'PROPN'},
#   {'word': '.', 'pos': 'PUNCT'},
#   {'word': 'Oscar', 'pos': 'PROPN'},
#   {'word': 'Wilde', 'pos': 'PROPN'},
#   {'word': ')', 'pos': 'PUNCT'}],
#  [{'word': '@antoniocorsa', 'pos': 'DET'},
#   {'word': '@sandrosca', 'pos': 'PROPN'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'me', 'pos': 'PRON'},
#   {'word': 'il', 'pos': 'DET'},
#   {'word': 'giornalista', 'pos': 'NOUN'},
#   {'word': 'dovrebbe', 'pos': 'AUX'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': '(', 'pos': 'PUNCT'},
#   {'word': 'oltre', 'pos': 'ADV'},
#   {'word': 'ad', 'pos': 'ADP'},
#   {'word': 'essere', 'pos': 'AUX'},
#   {'word': ')', 'pos': 'PUNCT'},
#   {'word': 'imparziale', 'pos': 'ADJ'},
#   {'word': 'per', 'pos': 'ADP'},
#   {'word': 'essere', 'pos': 'AUX'},
#   {'word': 'credibile..', 'pos': 'NOUN'},
#   {'word': '.', 'pos': 'PUNCT'}],
#  [{'word': '@rauhlvjval', 'pos': 'SCONJ'},
#   {'word': 'mi', 'pos': 'PRON'},
#   {'word': 'piace', 'pos': 'VERB'},
#   {'word': 'sembrare', 'pos': 'VERB'},
#   {'word': 'una', 'pos': 'DET'},
#   {'word': 'pedofila', 'pos': 'NOUN'}],
#  ...]

# %%
def compute_embeddings_mean(document_embeddings):
    sum_array = np.sum(document_embeddings, axis=0)
    mean_array = np.divide(sum_array, len(document_embeddings))
    return mean_array

def compute_all_embeddings_mean(document_tokens):
    document_embeddings = []
    
    for token in document_tokens:
        word = token['word']
        if word in embeddings:
            document_embeddings.append(embeddings[word])
    
    if len(document_embeddings) == 0:
        mean_document_embeddings = np.zeros(embeddings_dim)
    else:
        mean_document_embeddings = compute_embeddings_mean(document_embeddings)
    return mean_document_embeddings

def compute_filtered_embeddings_mean(document_tokens):
    document_embeddings = []
    
    for token in document_tokens:
        word = token['word']
        pos = token['pos']
        if word in embeddings and pos in ['ADJ', 'NOUN', 'VERB']:
            document_embeddings.append(embeddings[word])
    
    if len(document_embeddings) == 0:
        mean_document_embeddings = np.zeros(embeddings_dim)
    else:
        mean_document_embeddings = compute_embeddings_mean(document_embeddings)
    return mean_document_embeddings


def compute_filtered_embeddings_sep_means(document_tokens):
    adj_embeddings = []
    noun_embeddings = []
    verb_embeddings = []
    
    for token in document_tokens:
        word = token['word']
        pos = token['pos']
        if word in embeddings and pos in ['ADJ']:
            adj_embeddings.append(embeddings[word])
        elif word in embeddings and pos in ['NOUN']:
            noun_embeddings.append(embeddings[word])
        elif word in embeddings and pos in ['VERB']:
            verb_embeddings.append(embeddings[word])
    
    if len(adj_embeddings) == 0:
        mean_adj_embeddings = np.zeros(embeddings_dim)
    else:
        mean_adj_embeddings = compute_embeddings_mean(adj_embeddings)
        
    if len(noun_embeddings) == 0:
        mean_noun_embeddings = np.zeros(embeddings_dim)
    else:
        mean_noun_embeddings = compute_embeddings_mean(noun_embeddings)
        
    if len(verb_embeddings) == 0:
        mean_verb_embeddings = np.zeros(embeddings_dim)
    else:
        mean_verb_embeddings = compute_embeddings_mean(verb_embeddings)  
    
    
    mean_document_embeddings = np.concatenate([mean_adj_embeddings, mean_noun_embeddings, mean_verb_embeddings], axis=None)
    return mean_document_embeddings

# %%
def extract_features(documents):
    dataset_features = []
    for document_tokens in documents:
        document_embeddings = compute_all_embeddings_mean(document_tokens)
        #document_embeddings = compute_filtered_embeddings_mean(document_tokens)
        #document_embeddings = compute_filtered_embeddings_sep_means(document_tokens)
        dataset_features.append(document_embeddings)
    return dataset_features

# %%
all_features = extract_features(all_documents)

# %%
len(all_features), len(all_features[0])
# Out:
# (1509, 64)

# %%
all_labels = create_label_list(all_documents_paths)

# %%
all_labels[:10]
# Out:
# ['F', 'F', 'M', 'M', 'F', 'M', 'F', 'M', 'M', 'M']

# %%
def train_test_split(all_features, all_labels, all_documents_paths):
    train_features, train_labels = [], []
    test_features, test_labels = [], []
    
    for features, label,  document_path in zip(all_features, all_labels, all_documents_paths):
        if 'training' in document_path:
            train_features.append(features)
            train_labels.append(label)
        else:
            test_features.append(features)
            test_labels.append(label)
    return train_features, train_labels, test_features, test_labels

# %%
train_features, train_labels, test_features, test_labels = train_test_split(all_features, all_labels, all_documents_paths)
len(train_features), len(train_labels), len(test_features), len(test_labels)
# Out:
# (739, 739, 770, 770)

# %%
len(train_labels)
# Out:
# 739

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# X_train = np.stack(train_features, axis=0)
X_train = scaler.fit_transform(train_features)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC

# Define the parameter grid to search through
param_grid = {
    'C': [0.1, 0.01, 0.001],  # Regularization parameter
    'dual': [True, False]
}

# Initialize SVM with linear kernel
svc = LinearSVC()

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=5, refit=True)

# Fit the grid search to your data
grid_search.fit(X_train, train_labels)

# Get mean test scores across folds
mean_test_scores = grid_search.cv_results_['mean_test_score']

# Print the best parameters and best score
print("Best parameters found:", grid_search.best_params_)
print("Best score found:", grid_search.best_score_)
# Out:
# Best parameters found: {'C': 0.1, 'dual': True}
# Best score found: 0.6304743519029232

# %%
X_test = scaler.transform(test_features)
# Get the best estimator (model) found by grid search
best_model = grid_search.best_estimator_

# Now, you can use this best_model to make predictions on new data
# For example, if you have new data X_new, you can predict its labels as follows:
predictions = best_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix
test_predictions = predictions
print(classification_report(test_labels, test_predictions, zero_division=0)) # output_dict=True
# Out:
#               precision    recall  f1-score   support
#
#            F       0.58      0.72      0.64       396
#            M       0.61      0.45      0.52       374
#
#     accuracy                           0.59       770
#    macro avg       0.59      0.59      0.58       770
# weighted avg       0.59      0.59      0.58       770
