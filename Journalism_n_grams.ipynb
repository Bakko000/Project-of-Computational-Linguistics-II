# %%
import re #pacchetto per espressioni regolari
import os #pacchetto per muoversi nelle cartelle

# %%
conllu_dir = 'profiling_output/11152/'

# %%
class Document:

    def __init__(self, document_path):
        self.document_path = document_path
        self._parse_doc_info(document_path)
        self.sentences = []
        self.features = None

    def _parse_doc_info(self, document_path):
        document_path = document_path.split('/')[-1]
        document_info = document_path.split('.')[0]
        document_info = document_info.split('#')
        self.split = document_info[0]
        self.genre = document_info[2]
        self.gender = document_info[3]

    def add_sentence(self, sentences):
        self.sentences.append(sentences)

    # Per dopo

    def get_num_tokens(self):
        num_words = 0
        for sentence in self.sentences:
            num_words = num_words + sentence.get_num_tokens()
        return num_words

    def get_num_chars(self):
        num_chars = 0
        for sentence in self.sentences:
            sentence_char_len = sentence.get_num_chars()
            num_chars = num_chars + sentence_char_len
        return num_chars

class Sentence:

    def __init__(self):
        self.tokens = []

    def add_token(self, token):
        self.tokens.append(token)

    # Per dopo

    def get_words(self):
        return [token.word for token in self.tokens]

    def get_lemmas(self):
        return [token.lemma for token in self.tokens]

    def get_pos(self):
        return [token.pos for token in self.tokens]

    def get_num_tokens(self):
        return len(self.tokens)

    def get_num_chars(self):
        num_chars = 0
        for token in self.tokens:
            num_chars = num_chars + token.get_num_chars()
        num_chars = num_chars + self.get_num_tokens() - 1 # contiamo anche gli spazi
        return num_chars

    def __str__(self):
        return ' '.join([token.word for token in self.tokens])

class Token:

    def __init__(self, word, lemma, pos):
        self.word = word
        self.lemma = lemma
        self.pos = pos


    # Per dopo

    def get_num_chars(self):
        return len(self.word)

# %%
def load_document_sentences(document):
    sentence = Sentence()
    for line in open(document.document_path, 'r'):
        if line[0].isdigit():  # se la riga inizia con un numero
            splitted_line = line.strip().split('\t')
            if '-' not in splitted_line[0]:  # se l'id della parola non contiene un trattino
                token = Token(splitted_line[1], splitted_line[2], splitted_line[3])
                sentence.add_token(token)
        if line == '\n':  # se la riga è vuota significa che la frase è finita
            document.add_sentence(sentence)
            sentence = Sentence()

# %%
all_documents = []
for file_name in os.listdir(conllu_dir):
    file_path = os.path.join(conllu_dir, file_name)
    document = Document(file_path)
    load_document_sentences(document)
    all_documents.append(document)

# %%
sample_document = all_documents[0]
for sentence in sample_document.sentences[:2]:
    tokens = [token.word for token in sentence.tokens]
    print(' - '.join(tokens))
    print('\n_________________\n')
# Out:
# " - Gay - Pride - ?
#
# _________________
#
# Solo - folklore - " - .
#
# _________________

# %%
sample_sentence = sample_document.sentences[0]
print(sample_sentence)
# Out:
# " Gay Pride ?

# %%
def extract_word_ngrams_from_sentence(word_ngrams, sentence, el, n):
    # creiamo una lista con tutte le parole
    if el == 'word':
        all_words = sentence.get_words()
    elif el == 'lemma':
        all_words = sentence.get_lemmas()
    elif el == 'pos':
        all_words = sentence.get_pos()
    else:
        raise Exception(f'Invalid element {el}')
    

    # scorriamo la lista delle parole ed estraiamo gli n-grammi
    for i in range(0, len(all_words) - n + 1): # -n+1 serve per non uscire dal vettore
        ngram_words = all_words[i: i + n]
        ngram = f'{el.upper()}_{n}_' + '_'.join(ngram_words)
        # print(f'{i}: {ngram_words} -> {ngram}')
        if ngram not in word_ngrams:
            word_ngrams[ngram] = 1
        else:
            word_ngrams[ngram] += 1

    return word_ngrams

# %%
extract_word_ngrams_from_sentence(dict(), sample_sentence, 'word', 3)

# %%
def extract_char_ngrams_from_sentence(char_ngrams, sentence, n):
    # creiamo una lista con tutte le parole
    all_words = sentence.get_words()

    # creiamo una stringa che contenga tutte le parole separate tra spazi perchè vogliamo scorrere i caratteri
    all_words = ' '.join(all_words)
    # print(all_words)
    # all_words = all_words.lower()

    # scorriamo la stringa ed estraiamo gli n-grammi di caratteri
    for i in range(0, len(all_words) - n + 1):
        ngram_chars = all_words[i:i + n]
        ngram = f'CHAR_{n}_' + ngram_chars
        # print(f'{i}: {ngram_chars} -> {ngram}')

        if ngram not in char_ngrams:
            char_ngrams[ngram] = 1
        else:
            char_ngrams[ngram] += 1

    return char_ngrams

# %%
extract_char_ngrams_from_sentence(dict(), sample_sentence, 2);

# %%
print(sample_document.features)
# Out:
# None

# %%
def extract_documents_ngrams(all_documents):
    for document in all_documents:
        document_ngrams = dict()
        for sentence in document.sentences:
            extract_word_ngrams_from_sentence(document_ngrams, sentence, 'word', 1)
            extract_word_ngrams_from_sentence(document_ngrams, sentence, 'word', 2)
            extract_char_ngrams_from_sentence(document_ngrams, sentence, 1)
            extract_char_ngrams_from_sentence(document_ngrams, sentence, 2)

        document.features = document_ngrams

# %%
extract_documents_ngrams(all_documents)

# %%
sample_document.features

# %%
def normalize_ngrams(ngrams_dict, doc_len):
    for ngram in ngrams_dict:
        ngrams_dict[ngram] = ngrams_dict[ngram] / float(doc_len)
        
def extract_documents_ngrams_normalized(all_documents):
    for document in all_documents:
        word_unigrams = dict()
        word_bigrams = dict()
        char_unigrams = dict()
        char_bigrams = dict()
        for sentence in document.sentences:
            extract_word_ngrams_from_sentence(word_unigrams, sentence, 'word', 1)
            extract_word_ngrams_from_sentence(word_bigrams, sentence, 'word', 2)
            extract_char_ngrams_from_sentence(char_unigrams, sentence, 1)
            extract_char_ngrams_from_sentence(char_bigrams, sentence, 2)

        num_words = document.get_num_tokens()
        num_chars = document.get_num_chars()
        normalize_ngrams(word_unigrams, num_words)
        normalize_ngrams(word_bigrams, num_words)
        normalize_ngrams(char_unigrams, num_chars)
        normalize_ngrams(char_bigrams, num_chars)

        document_ngrams = word_unigrams | word_bigrams | char_unigrams | char_bigrams

        # user_features = dict()
        # for ngrams_dict in [word_unigrams, word_bigrams, char_unigrams, char_bigrams]:
        #     for ngram in ngrams_dict:
        #         user_features[ngram] = ngrams_dict[ngram]

        document.features = document_ngrams

# %%
extract_documents_ngrams_normalized(all_documents)

# %%
sample_document.features
# Out:
# {'WORD_1_"': 0.030982905982905984,
#  'WORD_1_Gay': 0.004273504273504274,
#  'WORD_1_Pride': 0.01282051282051282,
#  'WORD_1_?': 0.002136752136752137,
#  'WORD_1_Solo': 0.002136752136752137,
#  'WORD_1_folklore': 0.004273504273504274,
#  'WORD_1_.': 0.03205128205128205,
#  'WORD_1_A': 0.004273504273504274,
#  'WORD_1_Novara': 0.01282051282051282,
#  'WORD_1_il': 0.06623931623931624,
#  'WORD_1_sindaco': 0.014957264957264958,
#  'WORD_1_leghista': 0.003205128205128205,
#  'WORD_1_nega': 0.003205128205128205,
#  'WORD_1_patrocinio': 0.009615384615384616,
#  'WORD_1_ed': 0.002136752136752137,
#  'WORD_1_è': 0.008547008547008548,
#  'WORD_1_polemica': 0.002136752136752137,
#  'WORD_1_Canelli': 0.007478632478632479,
#  'WORD_1_,': 0.04700854700854701,
#  'WORD_1_già': 0.0010683760683760685,
#  'WORD_1_a': 0.029914529914529916,
#  'WORD_1_centro': 0.0010683760683760685,
#  'WORD_1_di': 0.05448717948717949,
#  'WORD_1_le': 0.009615384615384616,
#  'WORD_1_critiche': 0.0010683760683760685,
#  'WORD_1_per': 0.00641025641025641,
#  'WORD_1_no': 0.003205128205128205,
#  'WORD_1_i': 0.00641025641025641,
#  'WORD_1_corsi': 0.002136752136752137,
#  'WORD_1_nuoto': 0.002136752136752137,
#  'WORD_1_immigrati': 0.0010683760683760685,
#  'WORD_1_boccia': 0.0010683760683760685,
#  'WORD_1_corteo': 0.0010683760683760685,
#  'WORD_1_:': 0.004273504273504274,
#  'WORD_1_Inutile': 0.0010683760683760685,
#  'WORD_1_ostentazione': 0.002136752136752137,
#  'WORD_1_Il': 0.0010683760683760685,
#  'WORD_1_Pd': 0.002136752136752137,
#  'WORD_1_Decisione': 0.0010683760683760685,
#  'WORD_1_svilente': 0.002136752136752137,
#  'WORD_1_e': 0.023504273504273504,
#  'WORD_1_moralista': 0.002136752136752137,
#  'WORD_1_Bufera': 0.0010683760683760685,
#  'WORD_1_su': 0.004273504273504274,
#  'WORD_1_Alessandro': 0.003205128205128205,
#  'WORD_1_che': 0.014957264957264958,
#  'WORD_1_Comune': 0.002136752136752137,
#  'WORD_1_primo': 0.0010683760683760685,
#  'WORD_1_cittadino': 0.0010683760683760685,
#  'WORD_1_in': 0.008547008547008548,
#  'WORD_1_programma': 0.002136752136752137,
#  'WORD_1_26': 0.003205128205128205,
#  'WORD_1_maggio': 0.003205128205128205,
#  'WORD_1_Secondo': 0.0010683760683760685,
#  'WORD_1_Partito': 0.0010683760683760685,
#  'WORD_1_democratico': 0.0010683760683760685,
#  'WORD_1_rifiuto': 0.0010683760683760685,
#  'WORD_1_concedere': 0.002136752136752137,
#  'WORD_1_gratuito': 0.002136752136752137,
#  'WORD_1_concesso': 0.0010683760683760685,
#  'WORD_1_invece': 0.002136752136752137,
#  'WORD_1_da': 0.007478632478632479,
#  'WORD_1_Regione': 0.0010683760683760685,
#  'WORD_1_Provincia': 0.0010683760683760685,
#  'WORD_1_rappresenta': 0.0010683760683760685,
#  'WORD_1_“': 0.002136752136752137,
#  'WORD_1_una': 0.007478632478632479,
#  'WORD_1_decisione': 0.005341880341880342,
#  'WORD_1_anacronistica': 0.0010683760683760685,
#  'WORD_1_discriminatoria': 0.0010683760683760685,
#  'WORD_1_-': 0.01282051282051282,
#  'WORD_1_prosegue': 0.0010683760683760685,
#  'WORD_1_bollare': 0.0010683760683760685,
#  'WORD_1_questa': 0.0010683760683760685,
#  'WORD_1_manifestazione': 0.00641025641025641,
#  'WORD_1_come': 0.004273504273504274,
#  'WORD_1_ha': 0.007478632478632479,
#  'WORD_1_fatto': 0.002136752136752137,
#  "WORD_1_'": 0.008547008547008548,
#  'WORD_1_controproducente': 0.002136752136752137,
#  'WORD_1_quanto': 0.0010683760683760685,
#  'WORD_1_più': 0.002136752136752137,
#  'WORD_1_ci': 0.003205128205128205,
#  'WORD_1_si': 0.005341880341880342,
#  'WORD_1_possa': 0.003205128205128205,
#  'WORD_1_aspettare': 0.0010683760683760685,
#  'WORD_1_2018': 0.0010683760683760685,
#  'WORD_1_”': 0.0010683760683760685,
#  'WORD_1_Dopo': 0.0010683760683760685,
#  'WORD_1_migranti': 0.0010683760683760685,
#  'WORD_1_piscina': 0.0010683760683760685,
#  'WORD_1_comunale': 0.003205128205128205,
#  'WORD_1_insomma': 0.0010683760683760685,
#  'WORD_1_l’': 0.003205128205128205,
#  'WORD_1_amministrazione': 0.003205128205128205,
#  'WORD_1_guidata': 0.0010683760683760685,
#  'WORD_1_la': 0.022435897435897436,
#  'WORD_1_Lega': 0.0010683760683760685,
#  'WORD_1_Nord': 0.0010683760683760685,
#  'WORD_1_denunciano': 0.0010683760683760685,
#  'WORD_1_opposizioni': 0.0010683760683760685,
#  'WORD_1_prende': 0.0010683760683760685,
#  'WORD_1_un’': 0.002136752136752137,
#  'WORD_1_altra': 0.0010683760683760685,
#  'WORD_1_contro': 0.002136752136752137,
#  'WORD_1_minoranze': 0.0010683760683760685,
#  'WORD_1_La': 0.002136752136752137,
#  'WORD_1_non': 0.011752136752136752,
#  'WORD_1_sostenere': 0.0010683760683760685,
#  'WORD_1_titolo': 0.0010683760683760685,
#  'WORD_1_Lgbt': 0.0010683760683760685,
#  'WORD_1_stata': 0.0010683760683760685,
#  'WORD_1_comunicata': 0.0010683760683760685,
#  'WORD_1_con': 0.004273504273504274,
#  'WORD_1_un': 0.00641025641025641,
#  'WORD_1_messaggio': 0.0010683760683760685,
#  'WORD_1_posta': 0.0010683760683760685,
#  'WORD_1_elettronica': 0.0010683760683760685,
#  'WORD_1_ieri': 0.0010683760683760685,
#  'WORD_1_gli': 0.0010683760683760685,
#  'WORD_1_organizzatori': 0.0010683760683760685,
#  'WORD_1_associazione': 0.002136752136752137,
#  'WORD_1_NovarArcobaleno': 0.0010683760683760685,
#  'WORD_1_Sermais': 0.0010683760683760685,
#  'WORD_1_Amnesty': 0.0010683760683760685,
#  'WORD_1_internazional': 0.0010683760683760685,
#  'WORD_1_hanno': 0.0010683760683760685,
#  'WORD_1_ottenuto': 0.0010683760683760685,
#  'WORD_1_adesione': 0.0010683760683760685,
#  'WORD_1_oltre': 0.002136752136752137,
#  'WORD_1_30': 0.0010683760683760685,
#  'WORD_1_tra': 0.0010683760683760685,
#  'WORD_1_associazioni': 0.0010683760683760685,
#  'WORD_1_partiti': 0.0010683760683760685,
#  'WORD_1_almeno': 0.0010683760683760685,
#  'WORD_1_duemila': 0.0010683760683760685,
#  'WORD_1_manifestanti': 0.0010683760683760685,
#  'WORD_1_previsti': 0.0010683760683760685,
#  'WORD_1_proposito': 0.0010683760683760685,
#  'WORD_1_detto': 0.0010683760683760685,
#  'WORD_1_giunta': 0.002136752136752137,
#  'WORD_1_deciso': 0.002136752136752137,
#  'WORD_1_ritenendo': 0.0010683760683760685,
#  'WORD_1_tipo': 0.002136752136752137,
#  'WORD_1_simbolico': 0.002136752136752137,
#  'WORD_1_folkloristico': 0.0010683760683760685,
#  'WORD_1_nostro': 0.003205128205128205,
#  'WORD_1_modo': 0.0010683760683760685,
#  'WORD_1_vedere': 0.0010683760683760685,
#  'WORD_1_può': 0.0010683760683760685,
#  'WORD_1_apportare': 0.0010683760683760685,
#  'WORD_1_giusto': 0.0010683760683760685,
#  'WORD_1_contributo': 0.002136752136752137,
#  'WORD_1_crescita': 0.0010683760683760685,
#  'WORD_1_consapevolezza': 0.0010683760683760685,
#  'WORD_1_problemi': 0.002136752136752137,
#  'WORD_1_questo': 0.003205128205128205,
#  'WORD_1_Ritengo': 0.0010683760683760685,
#  'WORD_1_essere': 0.002136752136752137,
#  'WORD_1_addirittura': 0.0010683760683760685,
#  'WORD_1_rispetto': 0.0010683760683760685,
#  'WORD_1_finalità': 0.0010683760683760685,
#  'WORD_1_intendono': 0.0010683760683760685,
#  'WORD_1_raggiungere': 0.0010683760683760685,
#  'WORD_1_È': 0.0010683760683760685,
#  'WORD_1_inutile': 0.0010683760683760685,
#  'WORD_1_So': 0.0010683760683760685,
#  'WORD_1_saranno': 0.0010683760683760685,
#  'WORD_1_tante': 0.0010683760683760685,
#  'WORD_1_polemiche': 0.0010683760683760685,
#  'WORD_1_ma': 0.0010683760683760685,
#  'WORD_1_sono': 0.0010683760683760685,
#  'WORD_1_convinto': 0.0010683760683760685,
#  'WORD_1_pubblica': 0.0010683760683760685,
#  'WORD_1_fare': 0.0010683760683760685,
#  'WORD_1_meglio': 0.0010683760683760685,
#  'WORD_1_causa': 0.0010683760683760685,
#  'WORD_1_discriminazioni': 0.0010683760683760685,
#  'WORD_1_sessuali': 0.0010683760683760685,
#  'WORD_1_patrocinando': 0.0010683760683760685,
#  'WORD_1_eventi': 0.0010683760683760685,
#  'WORD_1_Come': 0.002136752136752137,
#  'WORD_1_me': 0.0010683760683760685,
#  'WORD_1_pensano': 0.0010683760683760685,
#  'WORD_1_tanti': 0.002136752136752137,
#  'WORD_1_omosessuali': 0.0010683760683760685,
#  'WORD_1_Credo': 0.0010683760683760685,
#  'WORD_1_questi': 0.002136752136752137,
#  'WORD_1_sindaci': 0.002136752136752137,
#  'WORD_1_bigotti': 0.0010683760683760685,
#  'WORD_1_omofobi': 0.0010683760683760685,
#  'WORD_1_abbiano': 0.0010683760683760685,
#  'WORD_1_loro': 0.0010683760683760685,
#  'WORD_1_tempo': 0.0010683760683760685,
#  'WORD_1_Noi': 0.0010683760683760685,
#  'WORD_1_continueremo': 0.0010683760683760685,
#  'WORD_1_sfilare': 0.0010683760683760685,
#  'WORD_1_sempre': 0.0010683760683760685,
#  'WORD_1_colorati': 0.0010683760683760685,
#  'WORD_1_baracconi': 0.0010683760683760685,
#  'WORD_1_Lo': 0.003205128205128205,
#  'WORD_1_afferma': 0.002136752136752137,
#  'WORD_1_nota': 0.002136752136752137,
#  'WORD_1_Daniele': 0.0010683760683760685,
#  'WORD_1_Viotti': 0.0010683760683760685,
#  'WORD_1_parlamentare': 0.0010683760683760685,
#  'WORD_1_europeo': 0.002136752136752137,
#  'WORD_1_piemontese': 0.0010683760683760685,
#  'WORD_1_copresidente': 0.0010683760683760685,
#  "WORD_1_l'": 0.007478632478632479,
#  'WORD_1_Intergruppo': 0.0010683760683760685,
#  'WORD_1_Lgbti': 0.0010683760683760685,
#  'WORD_1_Parlamento': 0.0010683760683760685,
#  'WORD_1_Sarò': 0.0010683760683760685,
#  'WORD_1_dove': 0.0010683760683760685,
#  'WORD_1_manifesteremo': 0.0010683760683760685,
#  'WORD_1_tutto': 0.0010683760683760685,
#  'WORD_1_orgoglio': 0.003205128205128205,
#  'WORD_1_faremo': 0.0010683760683760685,
#  'WORD_1_meraviglioso': 0.0010683760683760685,
#  'WORD_1_aggiunge': 0.003205128205128205,
#  'WORD_1_Gli': 0.0010683760683760685,
#  'WORD_1_atti': 0.0010683760683760685,
#  'WORD_1_quello': 0.0010683760683760685,
#  'WORD_1_ultimo': 0.0010683760683760685,
#  'WORD_1_serie': 0.0010683760683760685,
#  'WORD_1_mi': 0.0010683760683760685,
#  'WORD_1_sembrano': 0.0010683760683760685,
#  'WORD_1_operazioni': 0.0010683760683760685,
#  'WORD_1_chi': 0.0010683760683760685,
#  'WORD_1_sapendo': 0.0010683760683760685,
#  'WORD_1_amministrare': 0.0010683760683760685,
#  'WORD_1_cerchi': 0.0010683760683760685,
#  'WORD_1_pò': 0.0010683760683760685,
#  'WORD_1_pubblicità': 0.0010683760683760685,
#  'WORD_1_nostra': 0.0010683760683760685,
#  'WORD_1_pelle': 0.0010683760683760685,
#  'WORD_1_Spiace': 0.0010683760683760685,
#  'WORD_1_abbia': 0.0010683760683760685,
#  'WORD_1_negare': 0.002136752136752137,
#  'WORD_1_Penso': 0.0010683760683760685,
#  'WORD_1_certe': 0.0010683760683760685,
#  'WORD_1_battaglie': 0.0010683760683760685,
#  'WORD_1_libertà': 0.0010683760683760685,
#  'WORD_1_civiltà': 0.0010683760683760685,
#  'WORD_1_debbano': 0.0010683760683760685,
#  'WORD_1_appartenere': 0.0010683760683760685,
#  'WORD_1_tutti': 0.003205128205128205,
#  'WORD_1_scrive': 0.0010683760683760685,
#  'WORD_1_Facebook': 0.0010683760683760685,
#  'WORD_1_presidente': 0.002136752136752137,
#  'WORD_1_Consiglio': 0.003205128205128205,
#  'WORD_1_regionale': 0.004273504273504274,
#  'WORD_1_Comitato': 0.002136752136752137,
#  'WORD_1_Diritti': 0.002136752136752137,
#  'WORD_1_Umani': 0.002136752136752137,
#  'WORD_1_Nino': 0.0010683760683760685,
#  'WORD_1_Boeti': 0.002136752136752137,
#  'WORD_1_Piemonte': 0.002136752136752137,
#  'WORD_1_attraverso': 0.0010683760683760685,
#  'WORD_1_anche': 0.0010683760683760685,
#  "WORD_1_quest'": 0.0010683760683760685,
#  'WORD_1_anno': 0.0010683760683760685,
#  'WORD_1_sosterremo': 0.0010683760683760685,
#  'WORD_1_Coordinamento': 0.002136752136752137,
#  'WORD_1_LGBT': 0.0010683760683760685,
#  'WORD_1_organizzazione': 0.0010683760683760685,
#  'WORD_1_iniziative': 0.0010683760683760685,
#  'WORD_1_Perché': 0.002136752136752137,
#  'WORD_1_festa': 0.0010683760683760685,
#  'WORD_1_Con': 0.0010683760683760685,
#  'WORD_1_suo': 0.0010683760683760685,
#  'WORD_1_sfoggiato': 0.0010683760683760685,
#  'WORD_1_atteggiamento': 0.0010683760683760685,
#  'WORD_1_omofobo': 0.0010683760683760685,
#  'WORD_1_discriminatorio': 0.0010683760683760685,
#  'WORD_1_sbandierato': 0.0010683760683760685,
#  'WORD_1_sua': 0.0010683760683760685,
#  'WORD_1_incapacità': 0.0010683760683760685,
#  'WORD_1_tutte': 0.0010683760683760685,
#  'WORD_1_folkloristica': 0.0010683760683760685,
#  'WORD_1_coordinatore': 0.0010683760683760685,
#  'WORD_1_Torino': 0.002136752136752137,
#  'WORD_1_secondo': 0.0010683760683760685,
#  'WORD_1_livello': 0.0010683760683760685,
#  'WORD_1_cui': 0.0010683760683760685,
#  'WORD_1_fa': 0.0010683760683760685,
#  'WORD_1_capo': 0.0010683760683760685,
#  'WORD_1_coordinamento': 0.0010683760683760685,
#  'WORD_1_prevede': 0.0010683760683760685,
#  'WORD_1_altre': 0.0010683760683760685,
#  'WORD_1_due': 0.0010683760683760685,
#  'WORD_1_parate': 0.0010683760683760685,
#  'WORD_1_ad': 0.0010683760683760685,
#  'WORD_1_Alba': 0.0010683760683760685,
#  'WORD_1_Certo': 0.0010683760683760685,
#  'WORD_1_aspettavamo': 0.0010683760683760685,
#  'WORD_1_molto': 0.0010683760683760685,
#  'WORD_1_vantato': 0.0010683760683760685,
#  'WORD_1_celebrare': 0.0010683760683760685,
#  'WORD_1_unioni': 0.0010683760683760685,
#  'WORD_1_civili': 0.0010683760683760685,
#  'WORD_1_perché': 0.0010683760683760685,
#  'WORD_1_Paese': 0.0010683760683760685,
#  'WORD_1_altri': 0.0010683760683760685,
#  'WORD_1_urgenti': 0.0010683760683760685,
#  'WORD_1_affrontare': 0.0010683760683760685,
#  'WORD_1_erano': 0.0010683760683760685,
#  'WORD_1_attese': 0.0010683760683760685,
#  'WORD_1_forse': 0.0010683760683760685,
#  'WORD_1_2.000': 0.0010683760683760685,
#  'WORD_1_persone': 0.0010683760683760685,
#  'WORD_1_credo': 0.0010683760683760685,
#  'WORD_1_dopo': 0.0010683760683760685,
#  'WORD_1_mirabolanti': 0.0010683760683760685,
#  'WORD_1_dichiarazioni': 0.0010683760683760685,
#  'WORD_1_saremo': 0.0010683760683760685,
#  'WORD_1_ancora': 0.0010683760683760685,
#  'WORD_1_allegria': 0.0010683760683760685,
#  'WORD_1_determinazione': 0.0010683760683760685,
#  'WORD_1_soprattutto': 0.0010683760683760685,
#  'WORD_1_tutta': 0.0010683760683760685,
#  'WORD_1_regione': 0.0010683760683760685,
#  'WORD_1_Apprendo': 0.0010683760683760685,
#  'WORD_1_dispiacere': 0.0010683760683760685,
#  'WORD_1_omosessuale': 0.0010683760683760685,
#  'WORD_1_sabato': 0.0010683760683760685,
#  'WORD_1_Inviterei': 0.0010683760683760685,
#  'WORD_1_rivedere': 0.0010683760683760685,
#  'WORD_1_posizione': 0.0010683760683760685,
#  'WORD_1_Forse': 0.0010683760683760685,
#  'WORD_1_mai': 0.0010683760683760685,
#  'WORD_1_partecipato': 0.0010683760683760685,
#  'WORD_1_tratta': 0.0010683760683760685,
#  'WORD_1_Così': 0.0010683760683760685,
#  'WORD_1_assessora': 0.0010683760683760685,
#  'WORD_1_Pari': 0.0010683760683760685,
#  'WORD_1_Opportunità': 0.0010683760683760685,
#  'WORD_1_Monica': 0.0010683760683760685,
#  'WORD_1_Cerutti': 0.0010683760683760685,
#  'WORD_1_invita': 0.0010683760683760685,
#  'WORD_1_dare': 0.0010683760683760685,
#  'WORD_1_partecipare': 0.0010683760683760685,
#  'WORD_1_Appoggio': 0.0010683760683760685,
#  'WORD_1_arriva': 0.0010683760683760685,
#  'WORD_1_Fratelli': 0.0010683760683760685,
#  "WORD_1_d'": 0.0010683760683760685,
#  'WORD_1_Italia': 0.0010683760683760685,
#  'WORD_1_Appoggiamo': 0.0010683760683760685,
#  'WORD_1_pieno': 0.0010683760683760685,
#  'WORD_1_scrivono': 0.0010683760683760685,
#  'WORD_1_senatore': 0.0010683760683760685,
#  'WORD_1_Gaetano': 0.0010683760683760685,
#  'WORD_1_Nastri': 0.0010683760683760685,
#  'WORD_1_consigliere': 0.0010683760683760685,
#  'WORD_1_Giuseppe': 0.0010683760683760685,
#  'WORD_1_Policaro': 0.0010683760683760685,
#  'WORD_1_componenti': 0.0010683760683760685,
#  'WORD_1_gruppo': 0.0010683760683760685,
#  'WORD_1_consiliare': 0.0010683760683760685,
#  'WORD_1_Fdi': 0.0010683760683760685,
#  'WORD_1_scelta': 0.0010683760683760685,
#  'WORD_1_Era': 0.0010683760683760685,
#  'WORD_1_scontato': 0.0010683760683760685,
#  'WORD_1_avrebbe': 0.0010683760683760685,
#  'WORD_1_suscitato': 0.0010683760683760685,
#  'WORD_1_reazione': 0.0010683760683760685,
#  'WORD_1_sinistra': 0.0010683760683760685,
#  'WORD_1_soliti': 0.0010683760683760685,
#  'WORD_1_radical-chic': 0.0010683760683760685,
#  'WORD_1_mentre': 0.0010683760683760685,
#  'WORD_1_noi': 0.0010683760683760685,
#  'WORD_1_problema': 0.0010683760683760685,
#  'WORD_1_poneva': 0.0010683760683760685,
#  'WORD_1_neppure': 0.0010683760683760685,
#  'WORD_1_perchè': 0.0010683760683760685,
#  'WORD_1_partito': 0.0010683760683760685,
#  'WORD_1_difende': 0.0010683760683760685,
#  'WORD_1_famiglia': 0.0010683760683760685,
#  'WORD_1_tradizionale': 0.0010683760683760685,
#  'WORD_1_quella': 0.0010683760683760685,
#  'WORD_1_composta': 0.0010683760683760685,
#  'WORD_1_padre': 0.0010683760683760685,
#  'WORD_1_madre': 0.0010683760683760685,
#  'WORD_1_figli': 0.0010683760683760685,
#  'WORD_2_"_Gay': 0.002136752136752137,
#  'WORD_2_Gay_Pride': 0.004273504273504274,
#  'WORD_2_Pride_?': 0.002136752136752137,
#  'WORD_2_Solo_folklore': 0.002136752136752137,
#  'WORD_2_folklore_"': 0.002136752136752137,
#  'WORD_2_"_.': 0.014957264957264958,
#  'WORD_2_A_Novara': 0.003205128205128205,
#  'WORD_2_Novara_il': 0.003205128205128205,
#  'WORD_2_il_sindaco': 0.013888888888888888,
#  'WORD_2_sindaco_leghista': 0.003205128205128205,
#  'WORD_2_leghista_nega': 0.002136752136752137,
#  'WORD_2_nega_il': 0.003205128205128205,
#  'WORD_2_il_patrocinio': 0.008547008547008548,
#  'WORD_2_patrocinio_ed': 0.002136752136752137,
#  'WORD_2_ed_è': 0.002136752136752137,
#  'WORD_2_è_polemica': 0.002136752136752137,
#  'WORD_2_polemica_"': 0.0010683760683760685,
#  'WORD_2_Canelli_,': 0.003205128205128205,
#  'WORD_2_,_già': 0.0010683760683760685,
#  'WORD_2_già_a': 0.0010683760683760685,
#  'WORD_2_a_il': 0.008547008547008548,
#  'WORD_2_il_centro': 0.0010683760683760685,
#  'WORD_2_centro_di': 0.0010683760683760685,
#  'WORD_2_di_le': 0.002136752136752137,
#  'WORD_2_le_critiche': 0.0010683760683760685,
#  'WORD_2_critiche_per': 0.0010683760683760685,
#  'WORD_2_per_il': 0.0010683760683760685,
#  'WORD_2_il_no': 0.002136752136752137,
#  'WORD_2_no_a': 0.003205128205128205,
#  'WORD_2_a_i': 0.003205128205128205,
#  'WORD_2_i_corsi': 0.002136752136752137,
#  'WORD_2_corsi_di': 0.002136752136752137,
#  'WORD_2_di_nuoto': 0.002136752136752137,
#  'WORD_2_nuoto_per': 0.002136752136752137,
#  'WORD_2_per_immigrati': 0.0010683760683760685,
#  'WORD_2_immigrati_,': 0.0010683760683760685,
#  'WORD_2_,_boccia': 0.0010683760683760685,
#  'WORD_2_boccia_il': 0.0010683760683760685,
#  'WORD_2_il_corteo': 0.0010683760683760685,
#  'WORD_2_corteo_:': 0.0010683760683760685,
#  'WORD_2_"_Inutile': 0.0010683760683760685,
#  'WORD_2_Inutile_ostentazione': 0.0010683760683760685,
#  'WORD_2_ostentazione_"': 0.0010683760683760685,
#  'WORD_2_Il_Pd': 0.0010683760683760685,
#  'WORD_2_Pd_:': 0.0010683760683760685,
#  'WORD_2_:_"': 0.0010683760683760685,
#  'WORD_2_"_Decisione': 0.0010683760683760685,
#  'WORD_2_Decisione_svilente': 0.0010683760683760685,
#  'WORD_2_svilente_e': 0.002136752136752137,
#  'WORD_2_e_moralista': 0.002136752136752137,
#  'WORD_2_moralista_"': 0.0010683760683760685,
#  'WORD_2_Bufera_su': 0.0010683760683760685,
#  'WORD_2_su_il': 0.0010683760683760685,
#  'WORD_2_sindaco_di': 0.003205128205128205,
#  'WORD_2_di_Novara': 0.005341880341880342,
#  'WORD_2_Novara_Alessandro': 0.0010683760683760685,
#  'WORD_2_Alessandro_Canelli': 0.003205128205128205,
#  'WORD_2_Canelli_che': 0.0010683760683760685,
#  'WORD_2_che_nega': 0.0010683760683760685,
#  'WORD_2_patrocinio_di': 0.0010683760683760685,
#  'WORD_2_di_il': 0.011752136752136752,
#  'WORD_2_il_Comune': 0.002136752136752137,
#  'WORD_2_Comune_a': 0.0010683760683760685,
#  'WORD_2_il_primo': 0.0010683760683760685,
#  'WORD_2_primo_Gay': 0.0010683760683760685,
#  'WORD_2_Pride_cittadino': 0.0010683760683760685,
#  'WORD_2_cittadino_,': 0.0010683760683760685,
#  'WORD_2_,_in': 0.002136752136752137,
#  'WORD_2_in_programma': 0.002136752136752137,
#  'WORD_2_programma_il': 0.0010683760683760685,
#  'WORD_2_il_26': 0.002136752136752137,
#  'WORD_2_26_maggio': 0.003205128205128205,
#  'WORD_2_maggio_.': 0.002136752136752137,
#  'WORD_2_Secondo_il': 0.0010683760683760685,
#  'WORD_2_il_Partito': 0.0010683760683760685,
#  'WORD_2_Partito_democratico': 0.0010683760683760685,
#  'WORD_2_democratico_il': 0.0010683760683760685,
#  'WORD_2_il_rifiuto': 0.0010683760683760685,
#  'WORD_2_rifiuto_di': 0.0010683760683760685,
#  'WORD_2_di_concedere': 0.0010683760683760685,
#  'WORD_2_concedere_il': 0.002136752136752137,
#  'WORD_2_il_gratuito': 0.0010683760683760685,
#  'WORD_2_gratuito_patrocinio': 0.0010683760683760685,
#  'WORD_2_patrocinio_,': 0.0010683760683760685,
#  'WORD_2_,_concesso': 0.0010683760683760685,
#  'WORD_2_concesso_invece': 0.0010683760683760685,
#  'WORD_2_invece_da': 0.002136752136752137,
#  'WORD_2_da_Regione': 0.0010683760683760685,
#  'WORD_2_Regione_e': 0.0010683760683760685,
#  'WORD_2_e_Provincia': 0.0010683760683760685,
#  'WORD_2_Provincia_,': 0.0010683760683760685,
#  'WORD_2_,_rappresenta': 0.0010683760683760685,
#  'WORD_2_rappresenta_“': 0.0010683760683760685,
#  'WORD_2_“_una': 0.0010683760683760685,
#  'WORD_2_una_decisione': 0.0010683760683760685,
#  'WORD_2_decisione_anacronistica': 0.0010683760683760685,
#  'WORD_2_anacronistica_e': 0.0010683760683760685,
#  'WORD_2_e_discriminatoria': 0.0010683760683760685,
#  'WORD_2_discriminatoria_,': 0.0010683760683760685,
#  'WORD_2_,_e': 0.002136752136752137,
#  'WORD_2_e_-': 0.0010683760683760685,
#  'WORD_2_-_prosegue': 0.0010683760683760685,
#  'WORD_2_prosegue_il': 0.0010683760683760685,
#  'WORD_2_il_Pd': 0.0010683760683760685,
#  'WORD_2_Pd_-': 0.0010683760683760685,
#  'WORD_2_-_bollare': 0.0010683760683760685,
#  'WORD_2_bollare_questa': 0.0010683760683760685,
#  'WORD_2_questa_manifestazione': 0.0010683760683760685,
#  'WORD_2_manifestazione_come': 0.0010683760683760685,
#  'WORD_2_come_ha': 0.0010683760683760685,
#  'WORD_2_ha_fatto': 0.0010683760683760685,
#  'WORD_2_fatto_il': 0.002136752136752137,
#  'WORD_2_sindaco_Canelli': 0.003205128205128205,
#  'WORD_2_,_come': 0.002136752136752137,
#  "WORD_2_come_'": 0.0010683760683760685,
#  "WORD_2_'_folklore": 0.002136752136752137,
#  'WORD_2_folklore_controproducente': 0.0010683760683760685,
#  "WORD_2_controproducente_'": 0.0010683760683760685,
#  "WORD_2_'_è": 0.0010683760683760685,
#  'WORD_2_è_quanto': 0.0010683760683760685,
#  'WORD_2_quanto_di': 0.0010683760683760685,
#  'WORD_2_di_più': 0.002136752136752137,
#  'WORD_2_più_svilente': 0.0010683760683760685,
#  'WORD_2_moralista_ci': 0.0010683760683760685,
#  'WORD_2_ci_si': 0.0010683760683760685,
#  'WORD_2_si_possa': 0.0010683760683760685,
#  'WORD_2_possa_aspettare': 0.0010683760683760685,
#  'WORD_2_aspettare_in': 0.0010683760683760685,
#  'WORD_2_in_il': 0.002136752136752137,
#  'WORD_2_il_2018': 0.0010683760683760685,
#  'WORD_2_2018_”': 0.0010683760683760685,
#  'WORD_2_”_.': 0.0010683760683760685,
#  'WORD_2_Dopo_il': 0.0010683760683760685,
#  'WORD_2_per_i': 0.0010683760683760685,
#  'WORD_2_i_migranti': 0.0010683760683760685,
#  'WORD_2_migranti_in': 0.0010683760683760685,
#  'WORD_2_il_piscina': 0.0010683760683760685,
#  'WORD_2_piscina_comunale': 0.0010683760683760685,
#  'WORD_2_comunale_,': 0.0010683760683760685,
#  'WORD_2_,_insomma': 0.0010683760683760685,
#  'WORD_2_insomma_,': 0.0010683760683760685,
#  'WORD_2_,_l’': 0.002136752136752137,
#  'WORD_2_l’_amministrazione': 0.0010683760683760685,
#  'WORD_2_amministrazione_comunale': 0.0010683760683760685,
#  'WORD_2_comunale_guidata': 0.0010683760683760685,
#  'WORD_2_guidata_da': 0.0010683760683760685,
#  'WORD_2_da_la': 0.0010683760683760685,
#  'WORD_2_la_Lega': 0.0010683760683760685,
#  'WORD_2_Lega_Nord': 0.0010683760683760685,
#  'WORD_2_Nord_,': 0.0010683760683760685,
#  'WORD_2_,_denunciano': 0.0010683760683760685,
#  'WORD_2_denunciano_le': 0.0010683760683760685,
#  'WORD_2_le_opposizioni': 0.0010683760683760685,
#  'WORD_2_opposizioni_,': 0.0010683760683760685,
#  'WORD_2_,_"': 0.002136752136752137,
#  'WORD_2_"_prende': 0.0010683760683760685,
#  'WORD_2_prende_un’': 0.0010683760683760685,
#  'WORD_2_un’_altra': 0.0010683760683760685,
#  'WORD_2_altra_decisione': 0.0010683760683760685,
#  'WORD_2_decisione_contro': 0.0010683760683760685,
#  'WORD_2_contro_le': 0.002136752136752137,
#  'WORD_2_le_minoranze': 0.0010683760683760685,
#  'WORD_2_minoranze_"': 0.0010683760683760685,
#  'WORD_2_La_decisione': 0.0010683760683760685,
#  'WORD_2_decisione_di': 0.003205128205128205,
#  'WORD_2_di_non': 0.003205128205128205,
#  'WORD_2_non_sostenere': 0.0010683760683760685,
#  'WORD_2_sostenere_,': 0.0010683760683760685,
#  'WORD_2_,_a': 0.0010683760683760685,
#  'WORD_2_a_titolo': 0.0010683760683760685,
#  'WORD_2_titolo_gratuito': 0.0010683760683760685,
#  'WORD_2_gratuito_,': 0.0010683760683760685,
#  'WORD_2_,_la': 0.002136752136752137,
#  'WORD_2_la_manifestazione': 0.003205128205128205,
#  'WORD_2_manifestazione_Lgbt': 0.0010683760683760685,
#  'WORD_2_Lgbt_è': 0.0010683760683760685,
#  'WORD_2_è_stata': 0.0010683760683760685,
#  'WORD_2_stata_comunicata': 0.0010683760683760685,
#  'WORD_2_comunicata_con': 0.0010683760683760685,
#  'WORD_2_con_un': 0.002136752136752137,
#  'WORD_2_un_messaggio': 0.0010683760683760685,
#  'WORD_2_messaggio_di': 0.0010683760683760685,
#  'WORD_2_di_posta': 0.0010683760683760685,
#  'WORD_2_posta_elettronica': 0.0010683760683760685,
#  'WORD_2_elettronica_ieri': 0.0010683760683760685,
#  'WORD_2_ieri_a': 0.0010683760683760685,
#  'WORD_2_a_gli': 0.0010683760683760685,
#  'WORD_2_gli_organizzatori': 0.0010683760683760685,
#  'WORD_2_organizzatori_,': 0.0010683760683760685,
#  'WORD_2_l’_associazione': 0.0010683760683760685,
#  'WORD_2_associazione_NovarArcobaleno': 0.0010683760683760685,
#  'WORD_2_NovarArcobaleno_,': 0.0010683760683760685,
#  'WORD_2_,_Sermais': 0.0010683760683760685,
#  'WORD_2_Sermais_e': 0.0010683760683760685,
#  'WORD_2_e_Amnesty': 0.0010683760683760685,
#  'WORD_2_Amnesty_internazional': 0.0010683760683760685,
#  'WORD_2_internazional_,': 0.0010683760683760685,
#  'WORD_2_,_che': 0.002136752136752137,
#  'WORD_2_che_hanno': 0.0010683760683760685,
#  'WORD_2_hanno_ottenuto': 0.0010683760683760685,
#  'WORD_2_ottenuto_l’': 0.0010683760683760685,
#  'WORD_2_l’_adesione': 0.0010683760683760685,
#  'WORD_2_adesione_di': 0.0010683760683760685,
#  'WORD_2_di_oltre': 0.0010683760683760685,
#  'WORD_2_oltre_30': 0.0010683760683760685,
#  'WORD_2_30_tra': 0.0010683760683760685,
#  'WORD_2_tra_associazioni': 0.0010683760683760685,
#  'WORD_2_associazioni_e': 0.0010683760683760685,
#  'WORD_2_e_partiti': 0.0010683760683760685,
#  'WORD_2_partiti_e': 0.0010683760683760685,
#  'WORD_2_e_almeno': 0.0010683760683760685,
#  'WORD_2_almeno_duemila': 0.0010683760683760685,
#  'WORD_2_duemila_manifestanti': 0.0010683760683760685,
#  'WORD_2_manifestanti_previsti': 0.0010683760683760685,
#  'WORD_2_previsti_.': 0.0010683760683760685,
#  'WORD_2_A_proposito': 0.0010683760683760685,
#  'WORD_2_proposito_di': 0.0010683760683760685,
#  'WORD_2_di_la': 0.003205128205128205,
#  'WORD_2_manifestazione_il': 0.0010683760683760685,
#  'WORD_2_Canelli_ha': 0.0010683760683760685,
#  'WORD_2_ha_detto': 0.0010683760683760685,
#  'WORD_2_detto_:': 0.0010683760683760685,
#  'WORD_2_“_La': 0.0010683760683760685,
#  'WORD_2_La_giunta': 0.0010683760683760685,
#  'WORD_2_giunta_ha': 0.0010683760683760685,
#  'WORD_2_ha_deciso': 0.0010683760683760685,
#  'WORD_2_deciso_di': 0.002136752136752137,
#  'WORD_2_non_concedere': 0.0010683760683760685,
#  'WORD_2_patrocinio_ritenendo': 0.0010683760683760685,
#  'WORD_2_ritenendo_la': 0.0010683760683760685,
#  'WORD_2_la_una': 0.0010683760683760685,
#  'WORD_2_una_manifestazione': 0.002136752136752137,
#  'WORD_2_manifestazione_di': 0.0010683760683760685,
#  'WORD_2_di_tipo': 0.0010683760683760685,
#  'WORD_2_tipo_simbolico': 0.0010683760683760685,
#  'WORD_2_simbolico_-': 0.002136752136752137,
#  'WORD_2_-_folkloristico': 0.0010683760683760685,
#  'WORD_2_folkloristico_che': 0.0010683760683760685,
#  'WORD_2_che_a': 0.0010683760683760685,
#  'WORD_2_a_nostro': 0.0010683760683760685,
#  'WORD_2_nostro_modo': 0.0010683760683760685,
#  'WORD_2_modo_di': 0.0010683760683760685,
#  'WORD_2_di_vedere': 0.0010683760683760685,
#  'WORD_2_vedere_non': 0.0010683760683760685,
#  'WORD_2_non_può': 0.0010683760683760685,
#  'WORD_2_può_apportare': 0.0010683760683760685,
#  'WORD_2_apportare_il': 0.0010683760683760685,
#  'WORD_2_il_giusto': 0.0010683760683760685,
#  'WORD_2_giusto_contributo': 0.0010683760683760685,
#  'WORD_2_contributo_a': 0.0010683760683760685,
#  'WORD_2_a_la': 0.003205128205128205,
#  'WORD_2_la_crescita': 0.0010683760683760685,
#  'WORD_2_crescita_e': 0.0010683760683760685,
#  'WORD_2_e_a': 0.003205128205128205,
#  'WORD_2_la_consapevolezza': 0.0010683760683760685,
#  'WORD_2_consapevolezza_su': 0.0010683760683760685,
#  'WORD_2_su_problemi': 0.0010683760683760685,
#  'WORD_2_problemi_di': 0.0010683760683760685,
#  'WORD_2_di_questo': 0.0010683760683760685,
#  'WORD_2_questo_tipo': 0.0010683760683760685,
#  'WORD_2_tipo_.': 0.0010683760683760685,
#  'WORD_2_Ritengo_possa': 0.0010683760683760685,
#  'WORD_2_possa_essere': 0.0010683760683760685,
#  'WORD_2_essere_addirittura': 0.0010683760683760685,
#  'WORD_2_addirittura_controproducente': 0.0010683760683760685,
#  'WORD_2_controproducente_rispetto': 0.0010683760683760685,
#  'WORD_2_rispetto_a': 0.0010683760683760685,
#  'WORD_2_a_le': 0.002136752136752137,
#  'WORD_2_le_finalità': 0.0010683760683760685,
#  'WORD_2_finalità_che': 0.0010683760683760685,
#  'WORD_2_che_si': 0.002136752136752137,
#  'WORD_2_si_intendono': 0.0010683760683760685,
#  'WORD_2_intendono_raggiungere': 0.0010683760683760685,
#  'WORD_2_raggiungere_.': 0.0010683760683760685,
#  'WORD_2_È_un’': 0.0010683760683760685,
#  'WORD_2_un’_inutile': 0.0010683760683760685,
#  'WORD_2_inutile_ostentazione': 0.0010683760683760685,
#  'WORD_2_ostentazione_.': 0.0010683760683760685,
#  'WORD_2_So_che': 0.0010683760683760685,
#  'WORD_2_che_ci': 0.0010683760683760685,
#  'WORD_2_ci_saranno': 0.0010683760683760685,
#  'WORD_2_saranno_tante': 0.0010683760683760685,
#  'WORD_2_tante_polemiche': 0.0010683760683760685,
#  'WORD_2_polemiche_,': 0.0010683760683760685,
#  'WORD_2_,_ma': 0.0010683760683760685,
#  'WORD_2_ma_sono': 0.0010683760683760685,
#  'WORD_2_sono_convinto': 0.0010683760683760685,
#  'WORD_2_convinto_che': 0.0010683760683760685,
#  'WORD_2_che_la': 0.002136752136752137,
#  'WORD_2_la_pubblica': 0.0010683760683760685,
#  'WORD_2_pubblica_amministrazione': 0.0010683760683760685,
#  'WORD_2_amministrazione_possa': 0.0010683760683760685,
#  'WORD_2_possa_fare': 0.0010683760683760685,
#  'WORD_2_fare_meglio': 0.0010683760683760685,
#  'WORD_2_meglio_a': 0.0010683760683760685,
#  'WORD_2_la_causa': 0.0010683760683760685,
#  'WORD_2_causa_contro': 0.0010683760683760685,
#  'WORD_2_le_discriminazioni': 0.0010683760683760685,
#  'WORD_2_discriminazioni_sessuali': 0.0010683760683760685,
#  'WORD_2_sessuali_non': 0.0010683760683760685,
#  'WORD_2_non_patrocinando': 0.0010683760683760685,
#  'WORD_2_patrocinando_eventi': 0.0010683760683760685,
#  'WORD_2_eventi_come': 0.0010683760683760685,
#  'WORD_2_come_questo': 0.0010683760683760685,
#  'WORD_2_questo_.': 0.0010683760683760685,
#  'WORD_2_Come_me': 0.0010683760683760685,
#  'WORD_2_me_la': 0.0010683760683760685,
#  'WORD_2_la_pensano': 0.0010683760683760685,
#  'WORD_2_pensano_tanti': 0.0010683760683760685,
#  'WORD_2_tanti_omosessuali': 0.0010683760683760685,
#  'WORD_2_omosessuali_"': 0.0010683760683760685,
#  'WORD_2_"_Credo': 0.0010683760683760685,
#  'WORD_2_Credo_che': 0.0010683760683760685,
#  'WORD_2_che_questi': 0.0010683760683760685,
#  'WORD_2_questi_sindaci': 0.002136752136752137,
#  'WORD_2_sindaci_bigotti': 0.0010683760683760685,
#  'WORD_2_bigotti_e': 0.0010683760683760685,
#  'WORD_2_e_omofobi': 0.0010683760683760685,
#  'WORD_2_omofobi_abbiano': 0.0010683760683760685,
#  'WORD_2_abbiano_fatto': 0.0010683760683760685,
#  'WORD_2_il_loro': 0.0010683760683760685,
#  'WORD_2_loro_tempo': 0.0010683760683760685,
#  'WORD_2_tempo_.': 0.0010683760683760685,
#  'WORD_2_Noi_continueremo': 0.0010683760683760685,
#  'WORD_2_continueremo_a': 0.0010683760683760685,
#  'WORD_2_a_sfilare': 0.0010683760683760685,
#  'WORD_2_sfilare_,': 0.0010683760683760685,
#  'WORD_2_come_sempre': 0.0010683760683760685,
#  "WORD_2_sempre_'": 0.0010683760683760685,
#  "WORD_2_'_colorati": 0.0010683760683760685,
#  'WORD_2_colorati_e': 0.0010683760683760685,
#  'WORD_2_e_baracconi': 0.0010683760683760685,
#  "WORD_2_baracconi_'": 0.0010683760683760685,
#  'WORD_2_\'_"': 0.002136752136752137,
#  'WORD_2_Lo_afferma': 0.002136752136752137,
#  'WORD_2_afferma_in': 0.0010683760683760685,
#  'WORD_2_in_una': 0.002136752136752137,
#  'WORD_2_una_nota': 0.002136752136752137,
#  'WORD_2_nota_Daniele': 0.0010683760683760685,
#  'WORD_2_Daniele_Viotti': 0.0010683760683760685,
#  'WORD_2_Viotti_parlamentare': 0.0010683760683760685,
#  'WORD_2_parlamentare_europeo': 0.0010683760683760685,
#  'WORD_2_europeo_piemontese': 0.0010683760683760685,
#  'WORD_2_piemontese_copresidente': 0.0010683760683760685,
#  'WORD_2_copresidente_di': 0.0010683760683760685,
#  "WORD_2_di_l'": 0.002136752136752137,
#  "WORD_2_l'_Intergruppo": 0.0010683760683760685,
#  'WORD_2_Intergruppo_Lgbti': 0.0010683760683760685,
#  'WORD_2_Lgbti_a': 0.0010683760683760685,
#  'WORD_2_il_Parlamento': 0.0010683760683760685,
#  'WORD_2_Parlamento_europeo': 0.0010683760683760685,
#  'WORD_2_europeo_.': 0.0010683760683760685,
#  'WORD_2_"_Sarò': 0.0010683760683760685,
#  'WORD_2_Sarò_a': 0.0010683760683760685,
#  'WORD_2_a_Novara': 0.002136752136752137,
#  'WORD_2_Novara_dove': 0.0010683760683760685,
#  'WORD_2_dove_manifesteremo': 0.0010683760683760685,
#  'WORD_2_manifesteremo_tutto': 0.0010683760683760685,
#  'WORD_2_tutto_il': 0.0010683760683760685,
#  'WORD_2_il_nostro': 0.002136752136752137,
#  'WORD_2_nostro_orgoglio': 0.0010683760683760685,
#  'WORD_2_orgoglio_e': 0.0010683760683760685,
#  'WORD_2_e_faremo': 0.0010683760683760685,
#  'WORD_2_faremo_un': 0.0010683760683760685,
#  'WORD_2_un_Pride': 0.0010683760683760685,
#  'WORD_2_Pride_meraviglioso': 0.0010683760683760685,
#  'WORD_2_meraviglioso_-': 0.0010683760683760685,
#  'WORD_2_-_aggiunge': 0.003205128205128205,
#  'WORD_2_aggiunge_-': 0.0010683760683760685,
#  'WORD_2_-_Gli': 0.0010683760683760685,
#  'WORD_2_Gli_atti': 0.0010683760683760685,
#  'WORD_2_atti_di': 0.0010683760683760685,
#  'WORD_2_di_questi': 0.0010683760683760685,
#  'WORD_2_sindaci_,': 0.0010683760683760685,
#  'WORD_2_e_quello': 0.0010683760683760685,
#  'WORD_2_quello_di': 0.0010683760683760685,
#  'WORD_2_Novara_è': 0.0010683760683760685,
#  "WORD_2_è_l'": 0.0010683760683760685,
#  "WORD_2_l'_ultimo": 0.0010683760683760685,
#  'WORD_2_ultimo_di': 0.0010683760683760685,
#  'WORD_2_di_una': 0.0010683760683760685,
#  'WORD_2_una_serie': 0.0010683760683760685,
#  'WORD_2_serie_,': 0.0010683760683760685,
#  'WORD_2_,_mi': 0.0010683760683760685,
#  'WORD_2_mi_sembrano': 0.0010683760683760685,
#  'WORD_2_sembrano_operazioni': 0.0010683760683760685,
#  'WORD_2_operazioni_di': 0.0010683760683760685,
#  'WORD_2_di_chi': 0.0010683760683760685,
#  'WORD_2_chi_non': 0.0010683760683760685,
#  'WORD_2_non_sapendo': 0.0010683760683760685,
#  'WORD_2_sapendo_amministrare': 0.0010683760683760685,
#  'WORD_2_amministrare_cerchi': 0.0010683760683760685,
#  'WORD_2_cerchi_un': 0.0010683760683760685,
#  'WORD_2_un_pò': 0.0010683760683760685,
#  'WORD_2_pò_di': 0.0010683760683760685,
#  'WORD_2_di_pubblicità': 0.0010683760683760685,
#  'WORD_2_pubblicità_su': 0.0010683760683760685,
#  'WORD_2_su_la': 0.0010683760683760685,
#  'WORD_2_la_nostra': 0.0010683760683760685,
#  'WORD_2_nostra_pelle': 0.0010683760683760685,
#  'WORD_2_pelle_"': 0.0010683760683760685,
#  'WORD_2_"_Spiace': 0.0010683760683760685,
#  'WORD_2_Spiace_che': 0.0010683760683760685,
#  'WORD_2_che_il': 0.0010683760683760685,
#  'WORD_2_Comune_di': 0.0010683760683760685,
#  'WORD_2_Novara_abbia': 0.0010683760683760685,
#  'WORD_2_abbia_deciso': 0.0010683760683760685,
#  'WORD_2_di_negare': 0.002136752136752137,
#  'WORD_2_negare_il': 0.002136752136752137,
#  'WORD_2_patrocinio_a': 0.003205128205128205,
#  'WORD_2_il_Novara': 0.002136752136752137,
#  'WORD_2_Novara_Pride': 0.002136752136752137,
#  'WORD_2_Pride_.': 0.0010683760683760685,
#  'WORD_2_Penso_che': 0.0010683760683760685,
#  'WORD_2_che_certe': 0.0010683760683760685,
#  'WORD_2_certe_battaglie': 0.0010683760683760685,
#  'WORD_2_battaglie_di': 0.0010683760683760685,
#  'WORD_2_di_libertà': 0.0010683760683760685,
#  'WORD_2_libertà_e': 0.0010683760683760685,
#  'WORD_2_e_di': 0.002136752136752137,
#  'WORD_2_di_civiltà': 0.0010683760683760685,
#  'WORD_2_civiltà_debbano': 0.0010683760683760685,
#  'WORD_2_debbano_appartenere': 0.0010683760683760685,
#  'WORD_2_appartenere_a': 0.0010683760683760685,
#  'WORD_2_a_tutti': 0.0010683760683760685,
#  'WORD_2_tutti_"': 0.002136752136752137,
#  'WORD_2_Lo_scrive': 0.0010683760683760685,
#  'WORD_2_scrive_su': 0.0010683760683760685,
#  'WORD_2_su_Facebook': 0.0010683760683760685,
#  'WORD_2_Facebook_il': 0.0010683760683760685,
#  'WORD_2_il_presidente': 0.0010683760683760685,
#  'WORD_2_presidente_di': 0.002136752136752137,
#  'WORD_2_il_Consiglio': 0.0010683760683760685,
#  'WORD_2_Consiglio_regionale': 0.002136752136752137,
#  'WORD_2_regionale_e': 0.0010683760683760685,
#  'WORD_2_e_presidente': 0.0010683760683760685,
#  'WORD_2_il_Comitato': 0.002136752136752137,
#  'WORD_2_Comitato_Diritti': 0.002136752136752137,
#  'WORD_2_Diritti_Umani': 0.002136752136752137,
#  'WORD_2_Umani_,': 0.002136752136752137,
#  'WORD_2_,_Nino': 0.0010683760683760685,
#  'WORD_2_Nino_Boeti': 0.0010683760683760685,
#  'WORD_2_Boeti_.': 0.0010683760683760685,
#  'WORD_2_"_Come': 0.0010683760683760685,
#  'WORD_2_Come_Consiglio': 0.0010683760683760685,
#  'WORD_2_regionale_di': 0.0010683760683760685,
#  'WORD_2_il_Piemonte': 0.002136752136752137,
#  'WORD_2_Piemonte_,': 0.0010683760683760685,
#  'WORD_2_,_attraverso': 0.0010683760683760685,
#  'WORD_2_attraverso_il': 0.0010683760683760685,
#  'WORD_2_,_anche': 0.0010683760683760685,
#  "WORD_2_anche_quest'": 0.0010683760683760685,
#  "WORD_2_quest'_anno": 0.0010683760683760685,
#  'WORD_2_anno_sosterremo': 0.0010683760683760685,
#  'WORD_2_sosterremo_con': 0.0010683760683760685,
#  'WORD_2_un_contributo': 0.0010683760683760685,
#  'WORD_2_contributo_il': 0.0010683760683760685,
#  'WORD_2_il_Coordinamento': 0.002136752136752137,
#  'WORD_2_Coordinamento_LGBT': 0.0010683760683760685,
#  'WORD_2_LGBT_per': 0.0010683760683760685,
#  "WORD_2_per_l'": 0.002136752136752137,
#  "WORD_2_l'_organizzazione": 0.0010683760683760685,
#  'WORD_2_organizzazione_di': 0.0010683760683760685,
#  'WORD_2_le_iniziative': 0.0010683760683760685,
#  'WORD_2_iniziative_di': 0.0010683760683760685,
#  'WORD_2_il_Pride': 0.002136752136752137,
#  'WORD_2_Pride_-': 0.0010683760683760685,
#  'WORD_2_aggiunge_Boeti': 0.0010683760683760685,
#  'WORD_2_Boeti_-': 0.0010683760683760685,
#  'WORD_2_-_Perché': 0.0010683760683760685,
#  'WORD_2_Perché_è': 0.0010683760683760685,
#  'WORD_2_è_una': 0.002136752136752137,
#  'WORD_2_una_festa': 0.0010683760683760685,
#  'WORD_2_festa_di': 0.0010683760683760685,
#  'WORD_2_di_tutti': 0.0010683760683760685,
#  'WORD_2_Con_il': 0.0010683760683760685,
#  'WORD_2_il_suo': 0.0010683760683760685,
#  'WORD_2_suo_no': 0.0010683760683760685,
#  'WORD_2_il_Gay': 0.0010683760683760685,
#  'WORD_2_Pride_,': 0.004273504273504274,
#  'WORD_2_,_il': 0.003205128205128205,
#  'WORD_2_leghista_di': 0.0010683760683760685,
#  'WORD_2_Novara_,': 0.002136752136752137,
#  'WORD_2_,_Alessandro': 0.0010683760683760685,
#  'WORD_2_"_ha': 0.0010683760683760685,
#  'WORD_2_ha_sfoggiato': 0.0010683760683760685,
#  'WORD_2_sfoggiato_un': 0.0010683760683760685,
#  'WORD_2_un_atteggiamento': 0.0010683760683760685,
#  'WORD_2_atteggiamento_omofobo': 0.0010683760683760685,
#  'WORD_2_omofobo_,': 0.0010683760683760685,
#  'WORD_2_,_discriminatorio': 0.0010683760683760685,
#  'WORD_2_discriminatorio_,': 0.0010683760683760685,
#  'WORD_2_,_ha': 0.0010683760683760685,
#  'WORD_2_ha_sbandierato': 0.0010683760683760685,
#  'WORD_2_sbandierato_la': 0.0010683760683760685,
#  'WORD_2_la_sua': 0.0010683760683760685,
#  'WORD_2_sua_incapacità': 0.0010683760683760685,
#  'WORD_2_incapacità_di': 0.0010683760683760685,
#  'WORD_2_di_essere': 0.0010683760683760685,
#  'WORD_2_essere_il': 0.0010683760683760685,
#  'WORD_2_di_tutte': 0.0010683760683760685,
#  'WORD_2_tutte_e': 0.0010683760683760685,
#  'WORD_2_e_tutti': 0.0010683760683760685,
#  'WORD_2_tutti_.': 0.0010683760683760685,
#  'WORD_2_Perché_il': 0.0010683760683760685,
#  'WORD_2_Pride_non': 0.0010683760683760685,
#  'WORD_2_non_è': 0.0010683760683760685,
#  'WORD_2_manifestazione_simbolico': 0.0010683760683760685,
#  'WORD_2_-_folkloristica': 0.0010683760683760685,
#  'WORD_2_folkloristica_"': 0.0010683760683760685,
#  'WORD_2_afferma_,': 0.0010683760683760685,
#  'WORD_2_nota_,': 0.0010683760683760685,
#  'WORD_2_il_coordinatore': 0.0010683760683760685,
#  'WORD_2_coordinatore_di': 0.0010683760683760685,
#  'WORD_2_il_Torino': 0.0010683760683760685,
#  'WORD_2_Torino_Pride': 0.0010683760683760685,
#  "WORD_2_,_l'": 0.0010683760683760685,
#  "WORD_2_l'_associazione": 0.0010683760683760685,
#  'WORD_2_associazione_di': 0.0010683760683760685,
#  'WORD_2_di_secondo': 0.0010683760683760685,
#  'WORD_2_secondo_livello': 0.0010683760683760685,
#  'WORD_2_livello_a': 0.0010683760683760685,
#  'WORD_2_a_cui': 0.0010683760683760685,
#  'WORD_2_cui_fa': 0.0010683760683760685,
#  'WORD_2_fa_capo': 0.0010683760683760685,
#  'WORD_2_capo_il': 0.0010683760683760685,
#  'WORD_2_il_coordinamento': 0.0010683760683760685,
#  'WORD_2_coordinamento_di': 0.0010683760683760685,
#  'WORD_2_Piemonte_Pride': 0.0010683760683760685,
#  'WORD_2_Pride_che': 0.0010683760683760685,
#  'WORD_2_che_prevede': 0.0010683760683760685,
#  'WORD_2_prevede_,': 0.0010683760683760685,
#  'WORD_2_,_oltre': 0.0010683760683760685,
#  'WORD_2_oltre_a': 0.0010683760683760685,
#  'WORD_2_,_altre': 0.0010683760683760685,
#  'WORD_2_altre_due': 0.0010683760683760685,
#  'WORD_2_due_parate': 0.0010683760683760685,
#  'WORD_2_parate_ad': 0.0010683760683760685,
#  'WORD_2_ad_Alba': 0.0010683760683760685,
#  'WORD_2_Alba_e': 0.0010683760683760685,
#  'WORD_2_a_Torino': 0.0010683760683760685,
#  'WORD_2_Torino_.': 0.0010683760683760685,
#  'WORD_2_"_Certo': 0.0010683760683760685,
#  'WORD_2_Certo_non': 0.0010683760683760685,
#  'WORD_2_non_ci': 0.0010683760683760685,
#  'WORD_2_ci_aspettavamo': 0.0010683760683760685,
#  'WORD_2_aspettavamo_molto': 0.0010683760683760685,
#  'WORD_2_molto_da': 0.0010683760683760685,
#  'WORD_2_da_un': 0.0010683760683760685,
#  'WORD_2_un_sindaco': 0.0010683760683760685,
#  'WORD_2_sindaco_che': 0.0010683760683760685,
#  'WORD_2_si_è': 0.0010683760683760685,
#  'WORD_2_è_vantato': 0.0010683760683760685,
#  'WORD_2_vantato_di': 0.0010683760683760685,
#  'WORD_2_non_celebrare': 0.0010683760683760685,
#  'WORD_2_celebrare_le': 0.0010683760683760685,
#  'WORD_2_le_unioni': 0.0010683760683760685,
#  'WORD_2_unioni_civili': 0.0010683760683760685,
#  'WORD_2_civili_perché': 0.0010683760683760685,
#  "WORD_2_perché_'": 0.0010683760683760685,
#  "WORD_2_'_questo": 0.0010683760683760685,
#  'WORD_2_questo_Paese': 0.0010683760683760685,
#  'WORD_2_Paese_ha': 0.0010683760683760685,
#  'WORD_2_ha_tanti': 0.0010683760683760685,
#  'WORD_2_tanti_altri': 0.0010683760683760685,
#  'WORD_2_altri_problemi': 0.0010683760683760685,
#  'WORD_2_problemi_urgenti': 0.0010683760683760685,
#  'WORD_2_urgenti_da': 0.0010683760683760685,
#  'WORD_2_da_affrontare': 0.0010683760683760685,
#  "WORD_2_affrontare_'": 0.0010683760683760685,
#  "WORD_2_'_-": 0.0010683760683760685,
#  'WORD_2_aggiunge_il': 0.0010683760683760685,
#  'WORD_2_Coordinamento_-': 0.0010683760683760685,
#  'WORD_2_-_A': 0.0010683760683760685,
#  'WORD_2_maggio_erano': 0.0010683760683760685,
#  'WORD_2_erano_attese': 0.0010683760683760685,
#  'WORD_2_attese_forse': 0.0010683760683760685,
#  'WORD_2_forse_2.000': 0.0010683760683760685,
#  'WORD_2_2.000_persone': 0.0010683760683760685,
#  'WORD_2_persone_,': 0.0010683760683760685,
#  'WORD_2_,_credo': 0.0010683760683760685,
#  'WORD_2_credo_che': 0.0010683760683760685,
#  'WORD_2_che_dopo': 0.0010683760683760685,
#  'WORD_2_dopo_le': 0.0010683760683760685,
#  'WORD_2_le_mirabolanti': 0.0010683760683760685,
#  'WORD_2_mirabolanti_dichiarazioni': 0.0010683760683760685,
#  'WORD_2_dichiarazioni_di': 0.0010683760683760685,
#  'WORD_2_sindaco_saremo': 0.0010683760683760685,
#  'WORD_2_saremo_ancora': 0.0010683760683760685,
#  'WORD_2_ancora_di': 0.0010683760683760685,
#  'WORD_2_più_,': 0.0010683760683760685,
#  'WORD_2_,_con': 0.0010683760683760685,
#  'WORD_2_con_allegria': 0.0010683760683760685,
#  'WORD_2_allegria_,': 0.0010683760683760685,
#  'WORD_2_,_determinazione': 0.0010683760683760685,
#  'WORD_2_determinazione_e': 0.0010683760683760685,
#  'WORD_2_e_soprattutto': 0.0010683760683760685,
#  'WORD_2_soprattutto_orgoglio': 0.0010683760683760685,
#  'WORD_2_orgoglio_da': 0.0010683760683760685,
#  'WORD_2_da_tutta': 0.0010683760683760685,
#  'WORD_2_tutta_la': 0.0010683760683760685,
#  'WORD_2_la_regione': 0.0010683760683760685,
#  'WORD_2_regione_"': 0.0010683760683760685,
#  'WORD_2_"_Apprendo': 0.0010683760683760685,
#  'WORD_2_Apprendo_con': 0.0010683760683760685,
#  'WORD_2_con_dispiacere': 0.0010683760683760685,
#  'WORD_2_dispiacere_la': 0.0010683760683760685,
#  'WORD_2_la_decisione': 0.002136752136752137,
#  'WORD_2_Novara_di': 0.0010683760683760685,
#  'WORD_2_manifestazione_per': 0.0010683760683760685,
#  "WORD_2_l'_orgoglio": 0.0010683760683760685,
#  'WORD_2_orgoglio_omosessuale': 0.0010683760683760685,
#  'WORD_2_omosessuale_in': 0.0010683760683760685,
#  'WORD_2_programma_sabato': 0.0010683760683760685,
#  'WORD_2_sabato_26': 0.0010683760683760685,
#  ...}

# %%
def train_test_split(all_documents):
    train_features_dict, train_labels = [], []
    test_features_dict, test_labels = [], []
    
    for document in all_documents:
        if document.split == 'training':
            train_features_dict.append(document.features)
            train_labels.append(document.gender)
        else:
            test_features_dict.append(document.features)
            test_labels.append(document.gender)
    
    return train_features_dict, train_labels, test_features_dict, test_labels

# %%
train_features_dict, train_labels, test_features_dict, test_labels = train_test_split(all_documents)

# %%
len(train_features_dict), len(train_labels), len(test_features_dict), len(test_labels)
# Out:
# (200, 200, 200, 200)

# %%
def get_num_features(features_dict):
    all_features = set()
    for document_feats in features_dict:
        all_features.update(list(document_feats.keys()))
    return len(all_features)

# %%
get_num_features(train_features_dict)
print(f'Numero features: {get_num_features(train_features_dict)}')
# Out:
# Numero features: 96238

# %%
def filter_features(train_features_dict, min_occurrences):
    # contiamo ogni feature in quanti user diversi compare
    features_counter = dict()
    for document_features_dict in train_features_dict:
        for feature in document_features_dict:
            if feature in features_counter:
                features_counter[feature] += 1
            else:
                features_counter[feature] = 1

    # per ogni user, togliamo le features che compaiono in meno di "min_occurrences" utenti
    for document_features_dict in train_features_dict:
        document_features = list(document_features_dict.keys())
        for feature in document_features:
            if features_counter[feature] < min_occurrences:
                document_features_dict.pop(feature)

    return train_features_dict

# %%
train_features_dict = filter_features(train_features_dict, 5)
print(f'Numero features dopo il filtro: {get_num_features(train_features_dict)}')
# Out:
# Numero features dopo il filtro: 5754

# %%
from sklearn.feature_extraction import DictVectorizer

vectorizer = DictVectorizer()
X_train = vectorizer.fit_transform(train_features_dict)

# %%
vectorizer.get_feature_names_out(X_train).tolist()
# Out:
# ['CHAR_1_ ',
#  'CHAR_1_!',
#  'CHAR_1_"',
#  'CHAR_1_%',
#  'CHAR_1_&',
#  "CHAR_1_'",
#  'CHAR_1_(',
#  'CHAR_1_)',
#  'CHAR_1_,',
#  'CHAR_1_-',
#  'CHAR_1_.',
#  'CHAR_1_/',
#  'CHAR_1_0',
#  'CHAR_1_1',
#  'CHAR_1_2',
#  'CHAR_1_3',
#  'CHAR_1_4',
#  'CHAR_1_5',
#  'CHAR_1_6',
#  'CHAR_1_7',
#  'CHAR_1_8',
#  'CHAR_1_9',
#  'CHAR_1_:',
#  'CHAR_1_;',
#  'CHAR_1_?',
#  'CHAR_1_A',
#  'CHAR_1_B',
#  'CHAR_1_C',
#  'CHAR_1_D',
#  'CHAR_1_E',
#  'CHAR_1_F',
#  'CHAR_1_G',
#  'CHAR_1_H',
#  'CHAR_1_I',
#  'CHAR_1_J',
#  'CHAR_1_K',
#  'CHAR_1_L',
#  'CHAR_1_M',
#  'CHAR_1_N',
#  'CHAR_1_O',
#  'CHAR_1_P',
#  'CHAR_1_Q',
#  'CHAR_1_R',
#  'CHAR_1_S',
#  'CHAR_1_T',
#  'CHAR_1_U',
#  'CHAR_1_V',
#  'CHAR_1_W',
#  'CHAR_1_Y',
#  'CHAR_1_Z',
#  'CHAR_1_a',
#  'CHAR_1_b',
#  'CHAR_1_c',
#  'CHAR_1_d',
#  'CHAR_1_e',
#  'CHAR_1_f',
#  'CHAR_1_g',
#  'CHAR_1_h',
#  'CHAR_1_i',
#  'CHAR_1_j',
#  'CHAR_1_k',
#  'CHAR_1_l',
#  'CHAR_1_m',
#  'CHAR_1_n',
#  'CHAR_1_o',
#  'CHAR_1_p',
#  'CHAR_1_q',
#  'CHAR_1_r',
#  'CHAR_1_s',
#  'CHAR_1_t',
#  'CHAR_1_u',
#  'CHAR_1_v',
#  'CHAR_1_w',
#  'CHAR_1_x',
#  'CHAR_1_y',
#  'CHAR_1_z',
#  'CHAR_1_~',
#  'CHAR_1_«',
#  'CHAR_1_°',
#  'CHAR_1_»',
#  'CHAR_1_È',
#  'CHAR_1_à',
#  'CHAR_1_è',
#  'CHAR_1_é',
#  'CHAR_1_ì',
#  'CHAR_1_ò',
#  'CHAR_1_ù',
#  'CHAR_1_—',
#  'CHAR_1_’',
#  'CHAR_1_“',
#  'CHAR_1_”',
#  'CHAR_2_ !',
#  'CHAR_2_ "',
#  'CHAR_2_ %',
#  "CHAR_2_ '",
#  'CHAR_2_ (',
#  'CHAR_2_ )',
#  'CHAR_2_ ,',
#  'CHAR_2_ -',
#  'CHAR_2_ .',
#  'CHAR_2_ /',
#  'CHAR_2_ 0',
#  'CHAR_2_ 1',
#  'CHAR_2_ 2',
#  'CHAR_2_ 3',
#  'CHAR_2_ 4',
#  'CHAR_2_ 5',
#  'CHAR_2_ 6',
#  'CHAR_2_ 7',
#  'CHAR_2_ 8',
#  'CHAR_2_ 9',
#  'CHAR_2_ :',
#  'CHAR_2_ ;',
#  'CHAR_2_ ?',
#  'CHAR_2_ A',
#  'CHAR_2_ B',
#  'CHAR_2_ C',
#  'CHAR_2_ D',
#  'CHAR_2_ E',
#  'CHAR_2_ F',
#  'CHAR_2_ G',
#  'CHAR_2_ H',
#  'CHAR_2_ I',
#  'CHAR_2_ J',
#  'CHAR_2_ K',
#  'CHAR_2_ L',
#  'CHAR_2_ M',
#  'CHAR_2_ N',
#  'CHAR_2_ O',
#  'CHAR_2_ P',
#  'CHAR_2_ Q',
#  'CHAR_2_ R',
#  'CHAR_2_ S',
#  'CHAR_2_ T',
#  'CHAR_2_ U',
#  'CHAR_2_ V',
#  'CHAR_2_ W',
#  'CHAR_2_ Y',
#  'CHAR_2_ Z',
#  'CHAR_2_ a',
#  'CHAR_2_ b',
#  'CHAR_2_ c',
#  'CHAR_2_ d',
#  'CHAR_2_ e',
#  'CHAR_2_ f',
#  'CHAR_2_ g',
#  'CHAR_2_ h',
#  'CHAR_2_ i',
#  'CHAR_2_ j',
#  'CHAR_2_ k',
#  'CHAR_2_ l',
#  'CHAR_2_ m',
#  'CHAR_2_ n',
#  'CHAR_2_ o',
#  'CHAR_2_ p',
#  'CHAR_2_ q',
#  'CHAR_2_ r',
#  'CHAR_2_ s',
#  'CHAR_2_ t',
#  'CHAR_2_ u',
#  'CHAR_2_ v',
#  'CHAR_2_ w',
#  'CHAR_2_ z',
#  'CHAR_2_ «',
#  'CHAR_2_ »',
#  'CHAR_2_ È',
#  'CHAR_2_ è',
#  'CHAR_2_ —',
#  'CHAR_2_ ”',
#  'CHAR_2_! ',
#  'CHAR_2_" ',
#  'CHAR_2_% ',
#  'CHAR_2_& ',
#  "CHAR_2_' ",
#  "CHAR_2_'9",
#  'CHAR_2_( ',
#  'CHAR_2_) ',
#  'CHAR_2_, ',
#  'CHAR_2_,1',
#  'CHAR_2_,3',
#  'CHAR_2_,5',
#  'CHAR_2_,6',
#  'CHAR_2_,7',
#  'CHAR_2_,9',
#  'CHAR_2_- ',
#  'CHAR_2_-s',
#  'CHAR_2_. ',
#  'CHAR_2_..',
#  'CHAR_2_.0',
#  'CHAR_2_.2',
#  'CHAR_2_.3',
#  'CHAR_2_.5',
#  'CHAR_2_.6',
#  'CHAR_2_.9',
#  'CHAR_2_.i',
#  'CHAR_2_/ ',
#  'CHAR_2_0 ',
#  'CHAR_2_0,',
#  'CHAR_2_0.',
#  'CHAR_2_00',
#  'CHAR_2_01',
#  'CHAR_2_02',
#  'CHAR_2_03',
#  'CHAR_2_04',
#  'CHAR_2_05',
#  'CHAR_2_06',
#  'CHAR_2_07',
#  'CHAR_2_08',
#  'CHAR_2_09',
#  'CHAR_2_0m',
#  'CHAR_2_1 ',
#  'CHAR_2_1,',
#  'CHAR_2_1.',
#  'CHAR_2_10',
#  'CHAR_2_11',
#  'CHAR_2_12',
#  'CHAR_2_13',
#  'CHAR_2_14',
#  'CHAR_2_15',
#  'CHAR_2_16',
#  'CHAR_2_17',
#  'CHAR_2_18',
#  'CHAR_2_19',
#  'CHAR_2_2 ',
#  'CHAR_2_2,',
#  'CHAR_2_2.',
#  'CHAR_2_20',
#  'CHAR_2_21',
#  'CHAR_2_22',
#  'CHAR_2_23',
#  'CHAR_2_24',
#  'CHAR_2_25',
#  'CHAR_2_26',
#  'CHAR_2_27',
#  'CHAR_2_28',
#  'CHAR_2_29',
#  'CHAR_2_3 ',
#  'CHAR_2_3,',
#  'CHAR_2_3.',
#  'CHAR_2_30',
#  'CHAR_2_31',
#  'CHAR_2_32',
#  'CHAR_2_33',
#  'CHAR_2_34',
#  'CHAR_2_35',
#  'CHAR_2_36',
#  'CHAR_2_37',
#  'CHAR_2_38',
#  'CHAR_2_39',
#  'CHAR_2_4 ',
#  'CHAR_2_4,',
#  'CHAR_2_40',
#  'CHAR_2_41',
#  'CHAR_2_42',
#  'CHAR_2_43',
#  'CHAR_2_44',
#  'CHAR_2_45',
#  'CHAR_2_47',
#  'CHAR_2_48',
#  'CHAR_2_49',
#  'CHAR_2_5 ',
#  'CHAR_2_5,',
#  'CHAR_2_5.',
#  'CHAR_2_50',
#  'CHAR_2_51',
#  'CHAR_2_52',
#  'CHAR_2_54',
#  'CHAR_2_55',
#  'CHAR_2_56',
#  'CHAR_2_58',
#  'CHAR_2_59',
#  'CHAR_2_5m',
#  'CHAR_2_6 ',
#  'CHAR_2_60',
#  'CHAR_2_61',
#  'CHAR_2_63',
#  'CHAR_2_65',
#  'CHAR_2_68',
#  'CHAR_2_6m',
#  'CHAR_2_7 ',
#  'CHAR_2_7,',
#  'CHAR_2_7.',
#  'CHAR_2_70',
#  'CHAR_2_71',
#  'CHAR_2_72',
#  'CHAR_2_73',
#  'CHAR_2_74',
#  'CHAR_2_75',
#  'CHAR_2_76',
#  'CHAR_2_8 ',
#  'CHAR_2_8,',
#  'CHAR_2_80',
#  'CHAR_2_84',
#  'CHAR_2_86',
#  'CHAR_2_88',
#  'CHAR_2_89',
#  'CHAR_2_9 ',
#  'CHAR_2_90',
#  'CHAR_2_91',
#  'CHAR_2_92',
#  'CHAR_2_93',
#  'CHAR_2_94',
#  'CHAR_2_95',
#  'CHAR_2_96',
#  'CHAR_2_97',
#  'CHAR_2_98',
#  'CHAR_2_99',
#  'CHAR_2_: ',
#  'CHAR_2_; ',
#  'CHAR_2_? ',
#  'CHAR_2_A ',
#  "CHAR_2_A'",
#  'CHAR_2_AC',
#  'CHAR_2_AG',
#  'CHAR_2_AL',
#  'CHAR_2_AM',
#  'CHAR_2_AN',
#  'CHAR_2_AR',
#  'CHAR_2_AS',
#  'CHAR_2_AT',
#  'CHAR_2_Ab',
#  'CHAR_2_Ac',
#  'CHAR_2_Ad',
#  'CHAR_2_Af',
#  'CHAR_2_Ag',
#  'CHAR_2_Ai',
#  'CHAR_2_Al',
#  'CHAR_2_Am',
#  'CHAR_2_An',
#  'CHAR_2_Ap',
#  'CHAR_2_Ar',
#  'CHAR_2_As',
#  'CHAR_2_At',
#  'CHAR_2_Au',
#  'CHAR_2_Av',
#  'CHAR_2_Az',
#  'CHAR_2_Ba',
#  'CHAR_2_Be',
#  'CHAR_2_Bi',
#  'CHAR_2_Bl',
#  'CHAR_2_Bo',
#  'CHAR_2_Br',
#  'CHAR_2_Bu',
#  "CHAR_2_C'",
#  'CHAR_2_CA',
#  'CHAR_2_CC',
#  'CHAR_2_CE',
#  'CHAR_2_CH',
#  'CHAR_2_CI',
#  'CHAR_2_CO',
#  'CHAR_2_Ca',
#  'CHAR_2_Ce',
#  'CHAR_2_Cg',
#  'CHAR_2_Ch',
#  'CHAR_2_Ci',
#  'CHAR_2_Cl',
#  'CHAR_2_Co',
#  'CHAR_2_Cr',
#  'CHAR_2_Cu',
#  "CHAR_2_D'",
#  'CHAR_2_DA',
#  'CHAR_2_DE',
#  'CHAR_2_DI',
#  'CHAR_2_Da',
#  'CHAR_2_De',
#  'CHAR_2_Di',
#  'CHAR_2_Do',
#  'CHAR_2_Du',
#  'CHAR_2_E ',
#  "CHAR_2_E'",
#  'CHAR_2_EG',
#  'CHAR_2_EL',
#  'CHAR_2_EN',
#  'CHAR_2_ER',
#  'CHAR_2_ES',
#  'CHAR_2_ET',
#  'CHAR_2_Ec',
#  'CHAR_2_Ed',
#  'CHAR_2_El',
#  'CHAR_2_Em',
#  'CHAR_2_En',
#  'CHAR_2_Ep',
#  'CHAR_2_Er',
#  'CHAR_2_Es',
#  'CHAR_2_Eu',
#  'CHAR_2_Ev',
#  'CHAR_2_Ex',
#  'CHAR_2_FA',
#  'CHAR_2_FI',
#  'CHAR_2_Fa',
#  'CHAR_2_Fe',
#  'CHAR_2_Fi',
#  'CHAR_2_Fl',
#  'CHAR_2_Fo',
#  'CHAR_2_Fr',
#  'CHAR_2_Fu',
#  'CHAR_2_GE',
#  'CHAR_2_GG',
#  'CHAR_2_GI',
#  'CHAR_2_GR',
#  'CHAR_2_Ga',
#  'CHAR_2_Ge',
#  'CHAR_2_Gh',
#  'CHAR_2_Gi',
#  'CHAR_2_Gl',
#  'CHAR_2_Go',
#  'CHAR_2_Gr',
#  'CHAR_2_Gu',
#  'CHAR_2_HI',
#  'CHAR_2_Ha',
#  'CHAR_2_He',
#  'CHAR_2_Hi',
#  'CHAR_2_Ho',
#  'CHAR_2_Hu',
#  'CHAR_2_I ',
#  'CHAR_2_IA',
#  'CHAR_2_IC',
#  'CHAR_2_IG',
#  'CHAR_2_II',
#  'CHAR_2_IL',
#  'CHAR_2_IM',
#  'CHAR_2_IN',
#  'CHAR_2_IO',
#  'CHAR_2_IP',
#  'CHAR_2_IR',
#  'CHAR_2_IS',
#  'CHAR_2_IT',
#  'CHAR_2_Ia',
#  'CHAR_2_Id',
#  'CHAR_2_Ie',
#  'CHAR_2_Ig',
#  'CHAR_2_Il',
#  'CHAR_2_Im',
#  'CHAR_2_In',
#  'CHAR_2_Io',
#  'CHAR_2_Ir',
#  'CHAR_2_Is',
#  'CHAR_2_It',
#  'CHAR_2_Ja',
#  'CHAR_2_Jo',
#  'CHAR_2_Ka',
#  'CHAR_2_Ke',
#  'CHAR_2_Ki',
#  'CHAR_2_L ',
#  "CHAR_2_L'",
#  'CHAR_2_LA',
#  'CHAR_2_LE',
#  'CHAR_2_LI',
#  'CHAR_2_LO',
#  'CHAR_2_LT',
#  'CHAR_2_La',
#  'CHAR_2_Le',
#  'CHAR_2_Li',
#  'CHAR_2_Lo',
#  'CHAR_2_Lu',
#  'CHAR_2_Lì',
#  'CHAR_2_L’',
#  'CHAR_2_MA',
#  'CHAR_2_ME',
#  'CHAR_2_MI',
#  'CHAR_2_MO',
#  'CHAR_2_Ma',
#  'CHAR_2_Me',
#  'CHAR_2_Mi',
#  'CHAR_2_Mo',
#  'CHAR_2_Mu',
#  'CHAR_2_N ',
#  'CHAR_2_NA',
#  'CHAR_2_ND',
#  'CHAR_2_NE',
#  'CHAR_2_NG',
#  'CHAR_2_NI',
#  'CHAR_2_NO',
#  'CHAR_2_NT',
#  'CHAR_2_Na',
#  'CHAR_2_Ne',
#  'CHAR_2_Ni',
#  'CHAR_2_No',
#  'CHAR_2_Nu',
#  'CHAR_2_O ',
#  'CHAR_2_OG',
#  'CHAR_2_OL',
#  'CHAR_2_OM',
#  'CHAR_2_ON',
#  'CHAR_2_OR',
#  'CHAR_2_OS',
#  'CHAR_2_Oc',
#  'CHAR_2_Og',
#  'CHAR_2_Ol',
#  'CHAR_2_On',
#  'CHAR_2_Op',
#  'CHAR_2_Or',
#  'CHAR_2_Os',
#  'CHAR_2_Ot',
#  'CHAR_2_PA',
#  'CHAR_2_PE',
#  'CHAR_2_PI',
#  'CHAR_2_PO',
#  'CHAR_2_PR',
#  'CHAR_2_Pa',
#  'CHAR_2_Pd',
#  'CHAR_2_Pe',
#  'CHAR_2_Ph',
#  'CHAR_2_Pi',
#  'CHAR_2_Pl',
#  'CHAR_2_Po',
#  'CHAR_2_Pr',
#  'CHAR_2_Pu',
#  'CHAR_2_Qu',
#  'CHAR_2_R ',
#  'CHAR_2_RA',
#  'CHAR_2_RE',
#  'CHAR_2_RI',
#  'CHAR_2_RM',
#  'CHAR_2_RO',
#  'CHAR_2_Ra',
#  'CHAR_2_Re',
#  'CHAR_2_Ri',
#  'CHAR_2_Ro',
#  'CHAR_2_Ru',
#  'CHAR_2_S ',
#  'CHAR_2_SA',
#  'CHAR_2_SC',
#  'CHAR_2_SE',
#  'CHAR_2_SI',
#  'CHAR_2_SP',
#  'CHAR_2_SS',
#  'CHAR_2_ST',
#  'CHAR_2_SU',
#  'CHAR_2_Sa',
#  'CHAR_2_Sc',
#  'CHAR_2_Se',
#  'CHAR_2_Sh',
#  'CHAR_2_Si',
#  'CHAR_2_Sn',
#  'CHAR_2_So',
#  'CHAR_2_Sp',
#  'CHAR_2_St',
#  'CHAR_2_Su',
#  'CHAR_2_Sv',
#  'CHAR_2_Sì',
#  'CHAR_2_TA',
#  'CHAR_2_TE',
#  'CHAR_2_TI',
#  'CHAR_2_TO',
#  'CHAR_2_TR',
#  'CHAR_2_TT',
#  'CHAR_2_Ta',
#  'CHAR_2_Te',
#  'CHAR_2_Th',
#  'CHAR_2_Ti',
#  'CHAR_2_To',
#  'CHAR_2_Tr',
#  'CHAR_2_Tu',
#  'CHAR_2_UN',
#  'CHAR_2_UO',
#  'CHAR_2_US',
#  'CHAR_2_Ud',
#  'CHAR_2_Ul',
#  'CHAR_2_Um',
#  'CHAR_2_Un',
#  'CHAR_2_Us',
#  'CHAR_2_VA',
#  'CHAR_2_VE',
#  'CHAR_2_VI',
#  'CHAR_2_Va',
#  'CHAR_2_Ve',
#  'CHAR_2_Vi',
#  'CHAR_2_Vo',
#  'CHAR_2_Wa',
#  'CHAR_2_We',
#  'CHAR_2_Wi',
#  'CHAR_2_Wo',
#  'CHAR_2_Yo',
#  'CHAR_2_ZI',
#  'CHAR_2_Za',
#  'CHAR_2_Ze',
#  'CHAR_2_a ',
#  'CHAR_2_a-',
#  'CHAR_2_a.',
#  'CHAR_2_ab',
#  'CHAR_2_ac',
#  'CHAR_2_ad',
#  'CHAR_2_ae',
#  'CHAR_2_af',
#  'CHAR_2_ag',
#  'CHAR_2_ah',
#  'CHAR_2_ai',
#  'CHAR_2_aj',
#  'CHAR_2_ak',
#  'CHAR_2_al',
#  'CHAR_2_am',
#  'CHAR_2_an',
#  'CHAR_2_ao',
#  'CHAR_2_ap',
#  'CHAR_2_ar',
#  'CHAR_2_as',
#  'CHAR_2_at',
#  'CHAR_2_au',
#  'CHAR_2_av',
#  'CHAR_2_ax',
#  'CHAR_2_ay',
#  'CHAR_2_az',
#  'CHAR_2_b ',
#  'CHAR_2_ba',
#  'CHAR_2_bb',
#  'CHAR_2_bd',
#  'CHAR_2_be',
#  'CHAR_2_bi',
#  'CHAR_2_bl',
#  'CHAR_2_bo',
#  'CHAR_2_br',
#  'CHAR_2_bu',
#  'CHAR_2_by',
#  'CHAR_2_c ',
#  "CHAR_2_c'",
#  'CHAR_2_ca',
#  'CHAR_2_cc',
#  'CHAR_2_ce',
#  'CHAR_2_ch',
#  'CHAR_2_ci',
#  'CHAR_2_ck',
#  'CHAR_2_cl',
#  'CHAR_2_cn',
#  'CHAR_2_co',
#  'CHAR_2_cq',
#  'CHAR_2_cr',
#  'CHAR_2_ct',
#  'CHAR_2_cu',
#  'CHAR_2_cy',
#  'CHAR_2_d ',
#  "CHAR_2_d'",
#  'CHAR_2_da',
#  'CHAR_2_dc',
#  'CHAR_2_dd',
#  'CHAR_2_de',
#  'CHAR_2_dg',
#  'CHAR_2_di',
#  'CHAR_2_dl',
#  'CHAR_2_do',
#  'CHAR_2_dr',
#  'CHAR_2_ds',
#  'CHAR_2_du',
#  'CHAR_2_dy',
#  'CHAR_2_dà',
#  'CHAR_2_dì',
#  'CHAR_2_d’',
#  'CHAR_2_e ',
#  'CHAR_2_e.',
#  'CHAR_2_ea',
#  'CHAR_2_eb',
#  'CHAR_2_ec',
#  'CHAR_2_ed',
#  'CHAR_2_ee',
#  'CHAR_2_ef',
#  'CHAR_2_eg',
#  'CHAR_2_eh',
#  'CHAR_2_ei',
#  'CHAR_2_ek',
#  'CHAR_2_el',
#  'CHAR_2_em',
#  'CHAR_2_en',
#  'CHAR_2_eo',
#  'CHAR_2_ep',
#  'CHAR_2_eq',
#  'CHAR_2_er',
#  'CHAR_2_es',
#  'CHAR_2_et',
#  'CHAR_2_eu',
#  'CHAR_2_ev',
#  'CHAR_2_ew',
#  'CHAR_2_ex',
#  'CHAR_2_ey',
#  'CHAR_2_ez',
#  'CHAR_2_f ',
#  'CHAR_2_fa',
#  'CHAR_2_fe',
#  'CHAR_2_ff',
#  'CHAR_2_fi',
#  'CHAR_2_fl',
#  'CHAR_2_fo',
#  'CHAR_2_fr',
#  'CHAR_2_ft',
#  'CHAR_2_fu',
#  'CHAR_2_g ',
#  'CHAR_2_ga',
#  'CHAR_2_ge',
#  'CHAR_2_gg',
#  'CHAR_2_gh',
#  'CHAR_2_gi',
#  'CHAR_2_gl',
#  'CHAR_2_gn',
#  'CHAR_2_go',
#  'CHAR_2_gr',
#  'CHAR_2_gt',
#  'CHAR_2_gu',
#  'CHAR_2_h ',
#  'CHAR_2_ha',
#  'CHAR_2_he',
#  'CHAR_2_hi',
#  'CHAR_2_hn',
#  'CHAR_2_ho',
#  'CHAR_2_hr',
#  'CHAR_2_ht',
#  'CHAR_2_hu',
#  'CHAR_2_hè',
#  'CHAR_2_hé',
#  'CHAR_2_i ',
#  'CHAR_2_i-',
#  'CHAR_2_i.',
#  'CHAR_2_ia',
#  'CHAR_2_ib',
#  'CHAR_2_ic',
#  'CHAR_2_id',
#  'CHAR_2_ie',
#  'CHAR_2_if',
#  'CHAR_2_ig',
#  'CHAR_2_ii',
#  'CHAR_2_ik',
#  'CHAR_2_il',
#  'CHAR_2_im',
#  'CHAR_2_in',
#  'CHAR_2_io',
#  'CHAR_2_ip',
#  'CHAR_2_iq',
#  'CHAR_2_ir',
#  'CHAR_2_is',
#  'CHAR_2_it',
#  'CHAR_2_iu',
#  'CHAR_2_iv',
#  'CHAR_2_ix',
#  'CHAR_2_iz',
#  'CHAR_2_ià',
#  'CHAR_2_iè',
#  'CHAR_2_iò',
#  'CHAR_2_iù',
#  'CHAR_2_ja',
#  'CHAR_2_k ',
#  'CHAR_2_ka',
#  'CHAR_2_ke',
#  'CHAR_2_ki',
#  'CHAR_2_kl',
#  'CHAR_2_ko',
#  'CHAR_2_ky',
#  'CHAR_2_l ',
#  "CHAR_2_l'",
#  'CHAR_2_la',
#  'CHAR_2_lb',
#  'CHAR_2_lc',
#  'CHAR_2_ld',
#  'CHAR_2_le',
#  'CHAR_2_lf',
#  'CHAR_2_lg',
#  'CHAR_2_li',
#  'CHAR_2_ll',
#  'CHAR_2_lm',
#  'CHAR_2_ln',
#  'CHAR_2_lo',
#  'CHAR_2_lp',
#  'CHAR_2_ls',
#  'CHAR_2_lt',
#  'CHAR_2_lu',
#  'CHAR_2_lv',
#  'CHAR_2_ly',
#  'CHAR_2_lz',
#  'CHAR_2_là',
#  'CHAR_2_lì',
#  'CHAR_2_lò',
#  'CHAR_2_lù',
#  'CHAR_2_l’',
#  'CHAR_2_m ',
#  "CHAR_2_m'",
#  'CHAR_2_ma',
#  'CHAR_2_mb',
#  'CHAR_2_me',
#  'CHAR_2_mi',
#  'CHAR_2_mm',
#  'CHAR_2_mo',
#  'CHAR_2_mp',
#  'CHAR_2_ms',
#  'CHAR_2_mu',
#  'CHAR_2_n ',
#  "CHAR_2_n'",
#  'CHAR_2_na',
#  'CHAR_2_nc',
#  'CHAR_2_nd',
#  'CHAR_2_ne',
#  'CHAR_2_nf',
#  'CHAR_2_ng',
#  'CHAR_2_nh',
#  'CHAR_2_ni',
#  'CHAR_2_nk',
#  'CHAR_2_nl',
#  'CHAR_2_nn',
#  'CHAR_2_no',
#  'CHAR_2_np',
#  'CHAR_2_nq',
#  'CHAR_2_nr',
#  'CHAR_2_ns',
#  'CHAR_2_nt',
#  'CHAR_2_nu',
#  'CHAR_2_nv',
#  'CHAR_2_ny',
#  'CHAR_2_nz',
#  'CHAR_2_né',
#  'CHAR_2_n’',
#  'CHAR_2_o ',
#  "CHAR_2_o'",
#  'CHAR_2_o-',
#  'CHAR_2_o.',
#  'CHAR_2_oa',
#  'CHAR_2_ob',
#  'CHAR_2_oc',
#  'CHAR_2_od',
#  'CHAR_2_oe',
#  'CHAR_2_of',
#  'CHAR_2_og',
#  'CHAR_2_oh',
#  'CHAR_2_oi',
#  'CHAR_2_ok',
#  'CHAR_2_ol',
#  'CHAR_2_om',
#  'CHAR_2_on',
#  'CHAR_2_oo',
#  'CHAR_2_op',
#  'CHAR_2_oq',
#  'CHAR_2_or',
#  'CHAR_2_os',
#  'CHAR_2_ot',
#  'CHAR_2_ou',
#  'CHAR_2_ov',
#  'CHAR_2_ow',
#  'CHAR_2_ox',
#  'CHAR_2_oy',
#  'CHAR_2_oz',
#  'CHAR_2_oè',
#  'CHAR_2_p ',
#  'CHAR_2_pa',
#  'CHAR_2_pd',
#  'CHAR_2_pe',
#  'CHAR_2_ph',
#  'CHAR_2_pi',
#  'CHAR_2_pl',
#  'CHAR_2_pm',
#  'CHAR_2_po',
#  'CHAR_2_pp',
#  'CHAR_2_pr',
#  'CHAR_2_ps',
#  'CHAR_2_pt',
#  'CHAR_2_pu',
#  'CHAR_2_pà',
#  'CHAR_2_qu',
#  'CHAR_2_r ',
#  'CHAR_2_ra',
#  'CHAR_2_rb',
#  'CHAR_2_rc',
#  'CHAR_2_rd',
#  'CHAR_2_re',
#  'CHAR_2_rf',
#  'CHAR_2_rg',
#  'CHAR_2_ri',
#  'CHAR_2_rk',
#  'CHAR_2_rl',
#  'CHAR_2_rm',
#  'CHAR_2_rn',
#  'CHAR_2_ro',
#  'CHAR_2_rp',
#  'CHAR_2_rq',
#  'CHAR_2_rr',
#  'CHAR_2_rs',
#  'CHAR_2_rt',
#  'CHAR_2_ru',
#  'CHAR_2_rv',
#  'CHAR_2_ry',
#  'CHAR_2_rz',
#  'CHAR_2_rà',
#  'CHAR_2_rò',
#  'CHAR_2_s ',
#  "CHAR_2_s'",
#  'CHAR_2_sa',
#  'CHAR_2_sb',
#  'CHAR_2_sc',
#  'CHAR_2_sd',
#  'CHAR_2_se',
#  'CHAR_2_sf',
#  'CHAR_2_sg',
#  'CHAR_2_sh',
#  'CHAR_2_si',
#  'CHAR_2_sk',
#  'CHAR_2_sl',
#  'CHAR_2_sm',
#  'CHAR_2_sn',
#  'CHAR_2_so',
#  'CHAR_2_sp',
#  'CHAR_2_sq',
#  'CHAR_2_ss',
#  'CHAR_2_st',
#  'CHAR_2_su',
#  'CHAR_2_sv',
#  'CHAR_2_sè',
#  'CHAR_2_sé',
#  'CHAR_2_sì',
#  'CHAR_2_t ',
#  "CHAR_2_t'",
#  'CHAR_2_ta',
#  'CHAR_2_tc',
#  'CHAR_2_te',
#  'CHAR_2_th',
#  'CHAR_2_ti',
#  'CHAR_2_tl',
#  'CHAR_2_tm',
#  'CHAR_2_tn',
#  'CHAR_2_to',
#  'CHAR_2_tr',
#  'CHAR_2_ts',
#  'CHAR_2_tt',
#  'CHAR_2_tu',
#  'CHAR_2_tv',
#  'CHAR_2_tw',
#  'CHAR_2_ty',
#  'CHAR_2_tz',
#  'CHAR_2_tà',
#  'CHAR_2_tò',
#  'CHAR_2_tù',
#  'CHAR_2_u ',
#  'CHAR_2_ua',
#  'CHAR_2_ub',
#  'CHAR_2_uc',
#  'CHAR_2_ud',
#  'CHAR_2_ue',
#  'CHAR_2_uf',
#  'CHAR_2_ug',
#  'CHAR_2_ui',
#  'CHAR_2_ul',
#  'CHAR_2_um',
#  'CHAR_2_un',
#  'CHAR_2_uo',
#  'CHAR_2_up',
#  'CHAR_2_ur',
#  'CHAR_2_us',
#  'CHAR_2_ut',
#  'CHAR_2_uv',
#  'CHAR_2_ux',
#  'CHAR_2_uz',
#  'CHAR_2_uò',
#  'CHAR_2_v ',
#  'CHAR_2_va',
#  'CHAR_2_ve',
#  'CHAR_2_vi',
#  'CHAR_2_vo',
#  'CHAR_2_vr',
#  'CHAR_2_vu',
#  'CHAR_2_vv',
#  'CHAR_2_w ',
#  'CHAR_2_wa',
#  'CHAR_2_we',
#  'CHAR_2_wi',
#  'CHAR_2_wo',
#  'CHAR_2_x ',
#  'CHAR_2_xi',
#  'CHAR_2_xp',
#  'CHAR_2_xt',
#  'CHAR_2_y ',
#  'CHAR_2_ya',
#  'CHAR_2_yd',
#  'CHAR_2_ye',
#  'CHAR_2_yl',
#  'CHAR_2_ys',
#  'CHAR_2_yw',
#  'CHAR_2_z ',
#  'CHAR_2_za',
#  'CHAR_2_ze',
#  'CHAR_2_zi',
#  'CHAR_2_zo',
#  'CHAR_2_zu',
#  'CHAR_2_zz',
#  'CHAR_2_« ',
#  'CHAR_2_° ',
#  'CHAR_2_» ',
#  'CHAR_2_È ',
#  'CHAR_2_à ',
#  'CHAR_2_è ',
#  'CHAR_2_é ',
#  'CHAR_2_ée',
#  'CHAR_2_ì ',
#  'CHAR_2_ò ',
#  'CHAR_2_ù ',
#  'CHAR_2_— ',
#  'CHAR_2_’ ',
#  'CHAR_2_“ ',
#  'CHAR_2_” ',
#  'WORD_1_!',
#  'WORD_1_"',
#  'WORD_1_%',
#  "WORD_1_'",
#  'WORD_1_(',
#  'WORD_1_)',
#  'WORD_1_,',
#  'WORD_1_-',
#  'WORD_1_.',
#  ...]

# %%
from sklearn.preprocessing import MaxAbsScaler

scaler = MaxAbsScaler()
X_train = scaler.fit_transform(X_train)

# %%
from sklearn.svm import LinearSVC

svc = LinearSVC(dual=True, max_iter=10000)
svc.fit(X_train, train_labels)
# Out:
# LinearSVC(dual=True, max_iter=10000)

# %%
X_test = vectorizer.transform(test_features_dict)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import classification_report

test_predictions = svc.predict(X_test)
print(classification_report(test_labels, test_predictions, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            F       0.49      0.56      0.52       100
#            M       0.49      0.42      0.45       100
#
#     accuracy                           0.49       200
#    macro avg       0.49      0.49      0.49       200
# weighted avg       0.49      0.49      0.49       200
