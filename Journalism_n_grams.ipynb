# %%
import re #pacchetto per espressioni regolari
import os #pacchetto per muoversi nelle cartelle

# %%
conllu_dir = '/content/profiling_output/11152'

# %%
class Document:

    def __init__(self, document_path):
        self.document_path = document_path
        self._parse_doc_info(document_path)
        self.sentences = []
        self.features = None

    def _parse_doc_info(self, document_path):
        document_path = document_path.split('/')[-1]
        document_info = document_path.split('.')[0]
        document_info = document_info.split('#')
        self.split = document_info[0]
        self.genre = document_info[2]
        self.gender = document_info[3]

    def add_sentence(self, sentences):
        self.sentences.append(sentences)

    # Per dopo

    def get_num_tokens(self):
        num_words = 0
        for sentence in self.sentences:
            num_words = num_words + sentence.get_num_tokens()
        return num_words

    def get_num_chars(self):
        num_chars = 0
        for sentence in self.sentences:
            sentence_char_len = sentence.get_num_chars()
            num_chars = num_chars + sentence_char_len
        return num_chars

class Sentence:

    def __init__(self):
        self.tokens = []

    def add_token(self, token):
        self.tokens.append(token)

    # Per dopo

    def get_words(self):
        return [token.word for token in self.tokens]

    def get_lemmas(self):
        return [token.lemma for token in self.tokens]

    def get_pos(self):
        return [token.pos for token in self.tokens]

    def get_num_tokens(self):
        return len(self.tokens)

    def get_num_chars(self):
        num_chars = 0
        for token in self.tokens:
            num_chars = num_chars + token.get_num_chars()
        num_chars = num_chars + self.get_num_tokens() - 1 # contiamo anche gli spazi
        return num_chars

    def __str__(self):
        return ' '.join([token.word for token in self.tokens])

class Token:

    def __init__(self, word, lemma, pos):
        self.word = word
        self.lemma = lemma
        self.pos = pos


    # Per dopo

    def get_num_chars(self):
        return len(self.word)

# %%
def load_document_sentences(document):
    sentence = Sentence()
    for line in open(document.document_path, 'r'):
        if line[0].isdigit():  # se la riga inizia con un numero
            splitted_line = line.strip().split('\t')
            if '-' not in splitted_line[0]:  # se l'id della parola non contiene un trattino
                token = Token(splitted_line[1], splitted_line[2], splitted_line[3])
                sentence.add_token(token)
        if line == '\n':  # se la riga è vuota significa che la frase è finita
            document.add_sentence(sentence)
            sentence = Sentence()

# %%
all_documents = []
for file_name in os.listdir(conllu_dir):
    file_path = os.path.join(conllu_dir, file_name)
    document_path = file_path.split('/')[-1]
    #document_info = file_path.split('.')[0]
    #document_info = document_info.split('#')
    #split = document_info
    #genre = document_info[2]
    #gender = document_info[3]
    print(document_path)
# Out:
# training#18#journalism#M.conllu
# test#166#journalism#F.conllu
# test#157#journalism#M.conllu
# training#117#journalism#F.conllu
# test#12#journalism#M.conllu
# test#44#journalism#M.conllu
# test#48#journalism#F.conllu
# test#98#journalism#F.conllu
# training#101#journalism#F.conllu
# training#45#journalism#M.conllu
# test#15#journalism#F.conllu
# test#143#journalism#F.conllu
# training#139#journalism#F.conllu
# training#66#journalism#M.conllu
# training#161#journalism#F.conllu
# test#108#journalism#M.conllu
# training#11#journalism#M.conllu
# training#59#journalism#M.conllu
# training#169#journalism#F.conllu
# training#190#journalism#F.conllu
# test#79#journalism#M.conllu
# training#33#journalism#M.conllu
# training#121#journalism#F.conllu
# test#174#journalism#F.conllu
# training#94#journalism#M.conllu
# test#68#journalism#M.conllu
# test#26#journalism#M.conllu
# training#131#journalism#F.conllu
# training#79#journalism#M.conllu
# test#45#journalism#M.conllu
# training#197#journalism#F.conllu
# training#99#journalism#M.conllu
# test#105#journalism#M.conllu
# test#186#journalism#M.conllu
# training#65#journalism#M.conllu
# training#27#journalism#M.conllu
# test#135#journalism#M.conllu
# training#173#journalism#F.conllu
# test#121#journalism#M.conllu
# test#183#journalism#F.conllu
# test#3#journalism#M.conllu
# training#70#journalism#M.conllu
# training#167#journalism#F.conllu
# test#24#journalism#M.conllu
# training#171#journalism#F.conllu
# training#43#journalism#M.conllu
# training#177#journalism#F.conllu
# test#59#journalism#M.conllu
# test#131#journalism#M.conllu
# training#96#journalism#M.conllu
# training#109#journalism#F.conllu
# training#141#journalism#F.conllu
# training#41#journalism#M.conllu
# test#134#journalism#F.conllu
# test#74#journalism#M.conllu
# test#54#journalism#M.conllu
# test#126#journalism#M.conllu
# test#92#journalism#M.conllu
# training#185#journalism#F.conllu
# test#83#journalism#M.conllu
# test#62#journalism#M.conllu
# training#114#journalism#F.conllu
# training#164#journalism#F.conllu
# training#116#journalism#F.conllu
# training#128#journalism#F.conllu
# training#76#journalism#M.conllu
# training#160#journalism#F.conllu
# test#177#journalism#F.conllu
# training#148#journalism#F.conllu
# training#140#journalism#F.conllu
# test#191#journalism#F.conllu
# training#22#journalism#M.conllu
# training#57#journalism#M.conllu
# training#125#journalism#F.conllu
# training#93#journalism#M.conllu
# training#166#journalism#F.conllu
# test#89#journalism#M.conllu
# test#145#journalism#F.conllu
# test#141#journalism#F.conllu
# training#35#journalism#M.conllu
# training#16#journalism#M.conllu
# test#90#journalism#F.conllu
# test#75#journalism#M.conllu
# test#103#journalism#F.conllu
# training#42#journalism#M.conllu
# training#132#journalism#F.conllu
# test#40#journalism#M.conllu
# test#95#journalism#M.conllu
# training#175#journalism#F.conllu
# training#71#journalism#M.conllu
# training#110#journalism#F.conllu
# training#104#journalism#F.conllu
# test#11#journalism#F.conllu
# test#123#journalism#M.conllu
# training#14#journalism#M.conllu
# training#61#journalism#M.conllu
# test#84#journalism#F.conllu
# training#144#journalism#F.conllu
# test#7#journalism#F.conllu
# test#78#journalism#F.conllu
# training#77#journalism#M.conllu
# test#94#journalism#M.conllu
# training#95#journalism#M.conllu
# test#117#journalism#F.conllu
# training#82#journalism#M.conllu
# test#42#journalism#F.conllu
# training#40#journalism#M.conllu
# training#85#journalism#M.conllu
# test#160#journalism#F.conllu
# test#81#journalism#F.conllu
# training#92#journalism#M.conllu
# test#137#journalism#M.conllu
# training#30#journalism#M.conllu
# training#147#journalism#F.conllu
# test#99#journalism#F.conllu
# test#176#journalism#F.conllu
# test#185#journalism#F.conllu
# test#140#journalism#F.conllu
# test#153#journalism#M.conllu
# training#150#journalism#F.conllu
# training#159#journalism#F.conllu
# test#115#journalism#M.conllu
# training#87#journalism#M.conllu
# training#124#journalism#F.conllu
# training#111#journalism#F.conllu
# training#184#journalism#F.conllu
# training#54#journalism#M.conllu
# training#176#journalism#F.conllu
# training#69#journalism#M.conllu
# test#55#journalism#M.conllu
# test#17#journalism#M.conllu
# test#23#journalism#M.conllu
# test#51#journalism#M.conllu
# test#14#journalism#F.conllu
# test#175#journalism#F.conllu
# test#127#journalism#M.conllu
# training#170#journalism#F.conllu
# training#38#journalism#M.conllu
# training#165#journalism#F.conllu
# training#6#journalism#M.conllu
# test#198#journalism#F.conllu
# training#19#journalism#M.conllu
# test#41#journalism#F.conllu
# training#138#journalism#F.conllu
# training#180#journalism#F.conllu
# test#113#journalism#F.conllu
# training#10#journalism#M.conllu
# training#135#journalism#F.conllu
# test#124#journalism#F.conllu
# test#172#journalism#M.conllu
# test#190#journalism#M.conllu
# test#96#journalism#M.conllu
# test#152#journalism#M.conllu
# training#126#journalism#F.conllu
# test#178#journalism#F.conllu
# training#90#journalism#M.conllu
# test#156#journalism#M.conllu
# training#12#journalism#M.conllu
# training#97#journalism#M.conllu
# training#112#journalism#F.conllu
# test#36#journalism#F.conllu
# test#138#journalism#F.conllu
# training#163#journalism#F.conllu
# training#74#journalism#M.conllu
# test#88#journalism#M.conllu
# training#156#journalism#F.conllu
# test#60#journalism#M.conllu
# test#91#journalism#F.conllu
# test#52#journalism#F.conllu
# training#1#journalism#M.conllu
# test#101#journalism#M.conllu
# training#143#journalism#F.conllu
# test#30#journalism#F.conllu
# training#152#journalism#F.conllu
# training#106#journalism#F.conllu
# test#70#journalism#F.conllu
# test#8#journalism#M.conllu
# training#113#journalism#F.conllu
# training#62#journalism#M.conllu
# test#136#journalism#M.conllu
# training#182#journalism#F.conllu
# test#53#journalism#F.conllu
# test#20#journalism#M.conllu
# training#58#journalism#M.conllu
# test#29#journalism#F.conllu
# test#119#journalism#M.conllu
# test#146#journalism#F.conllu
# test#32#journalism#F.conllu
# test#18#journalism#F.conllu
# training#98#journalism#M.conllu
# test#193#journalism#M.conllu
# test#46#journalism#M.conllu
# test#21#journalism#F.conllu
# test#97#journalism#M.conllu
# test#142#journalism#F.conllu
# training#155#journalism#F.conllu
# test#133#journalism#F.conllu
# training#179#journalism#F.conllu
# training#108#journalism#F.conllu
# test#93#journalism#M.conllu
# training#51#journalism#M.conllu
# training#146#journalism#F.conllu
# test#122#journalism#M.conllu
# test#73#journalism#M.conllu
# test#80#journalism#M.conllu
# test#173#journalism#M.conllu
# test#155#journalism#F.conllu
# test#199#journalism#M.conllu
# training#34#journalism#M.conllu
# training#119#journalism#F.conllu
# test#130#journalism#F.conllu
# test#107#journalism#M.conllu
# training#80#journalism#M.conllu
# test#151#journalism#F.conllu
# training#7#journalism#M.conllu
# test#82#journalism#M.conllu
# training#192#journalism#F.conllu
# test#19#journalism#F.conllu
# test#1#journalism#F.conllu
# training#191#journalism#F.conllu
# test#109#journalism#F.conllu
# training#118#journalism#F.conllu
# test#33#journalism#F.conllu
# test#106#journalism#M.conllu
# training#24#journalism#M.conllu
# test#182#journalism#M.conllu
# test#158#journalism#F.conllu
# test#179#journalism#F.conllu
# test#120#journalism#F.conllu
# training#3#journalism#M.conllu
# training#8#journalism#M.conllu
# training#4#journalism#M.conllu
# test#112#journalism#F.conllu
# training#137#journalism#F.conllu
# test#167#journalism#F.conllu
# training#25#journalism#M.conllu
# training#36#journalism#M.conllu
# training#60#journalism#M.conllu
# training#127#journalism#F.conllu
# test#27#journalism#M.conllu
# training#17#journalism#M.conllu
# training#5#journalism#M.conllu
# training#129#journalism#F.conllu
# test#56#journalism#F.conllu
# test#71#journalism#F.conllu
# training#46#journalism#M.conllu
# test#72#journalism#M.conllu
# training#23#journalism#M.conllu
# test#102#journalism#F.conllu
# test#86#journalism#F.conllu
# training#136#journalism#F.conllu
# training#168#journalism#F.conllu
# test#149#journalism#M.conllu
# training#86#journalism#M.conllu
# test#87#journalism#M.conllu
# test#13#journalism#F.conllu
# test#184#journalism#F.conllu
# training#199#journalism#F.conllu
# test#49#journalism#F.conllu
# test#129#journalism#M.conllu
# test#76#journalism#M.conllu
# test#165#journalism#F.conllu
# training#81#journalism#M.conllu
# test#180#journalism#F.conllu
# training#162#journalism#F.conllu
# test#43#journalism#M.conllu
# training#174#journalism#F.conllu
# test#189#journalism#M.conllu
# training#63#journalism#M.conllu
# test#63#journalism#M.conllu
# training#107#journalism#F.conllu
# training#47#journalism#M.conllu
# training#122#journalism#F.conllu
# training#73#journalism#M.conllu
# test#50#journalism#F.conllu
# training#158#journalism#F.conllu
# training#145#journalism#F.conllu
# test#195#journalism#M.conllu
# test#188#journalism#F.conllu
# training#102#journalism#F.conllu
# training#31#journalism#M.conllu
# training#50#journalism#M.conllu
# training#84#journalism#M.conllu
# training#83#journalism#M.conllu
# training#53#journalism#M.conllu
# test#164#journalism#M.conllu
# training#130#journalism#F.conllu
# training#15#journalism#M.conllu
# training#100#journalism#M.conllu
# test#100#journalism#M.conllu
# training#178#journalism#F.conllu
# training#172#journalism#F.conllu
# test#192#journalism#F.conllu
# test#144#journalism#F.conllu
# training#153#journalism#F.conllu
# training#115#journalism#F.conllu
# test#5#journalism#M.conllu
# training#120#journalism#F.conllu
# training#67#journalism#M.conllu
# training#91#journalism#M.conllu
# test#61#journalism#M.conllu
# test#47#journalism#F.conllu
# test#196#journalism#M.conllu
# training#151#journalism#F.conllu
# test#125#journalism#M.conllu
# test#77#journalism#F.conllu
# training#183#journalism#F.conllu
# test#162#journalism#F.conllu
# test#170#journalism#M.conllu
# test#69#journalism#F.conllu
# training#37#journalism#M.conllu
# .ipynb_checkpoints
# training#189#journalism#F.conllu
# test#34#journalism#M.conllu
# training#186#journalism#F.conllu
# test#16#journalism#M.conllu
# training#39#journalism#M.conllu
# test#110#journalism#M.conllu
# training#142#journalism#F.conllu
# test#159#journalism#F.conllu
# test#118#journalism#M.conllu
# test#104#journalism#F.conllu
# training#20#journalism#M.conllu
# test#171#journalism#F.conllu
# training#75#journalism#M.conllu
# training#193#journalism#F.conllu
# training#103#journalism#F.conllu
# test#58#journalism#F.conllu
# test#147#journalism#F.conllu
# test#111#journalism#M.conllu
# test#128#journalism#M.conllu
# test#65#journalism#M.conllu
# training#13#journalism#M.conllu
# training#133#journalism#F.conllu
# test#169#journalism#F.conllu
# test#64#journalism#M.conllu
# training#134#journalism#F.conllu
# test#200#journalism#M.conllu
# test#150#journalism#M.conllu
# training#55#journalism#M.conllu
# test#39#journalism#F.conllu
# training#123#journalism#F.conllu
# test#161#journalism#M.conllu
# training#88#journalism#M.conllu
# test#4#journalism#F.conllu
# test#197#journalism#M.conllu
# training#49#journalism#M.conllu
# training#44#journalism#M.conllu
# training#149#journalism#F.conllu
# training#200#journalism#F.conllu
# training#196#journalism#F.conllu
# test#181#journalism#F.conllu
# training#89#journalism#M.conllu
# test#148#journalism#M.conllu
# training#187#journalism#F.conllu
# test#154#journalism#M.conllu
# training#29#journalism#M.conllu
# training#52#journalism#M.conllu
# training#194#journalism#F.conllu
# test#9#journalism#F.conllu
# test#28#journalism#M.conllu
# test#114#journalism#F.conllu
# training#68#journalism#M.conllu
# training#64#journalism#M.conllu
# test#132#journalism#F.conllu
# test#139#journalism#F.conllu
# test#31#journalism#F.conllu
# training#154#journalism#F.conllu
# test#168#journalism#F.conllu
# test#37#journalism#M.conllu
# training#32#journalism#M.conllu
# test#163#journalism#M.conllu
# training#181#journalism#F.conllu
# test#22#journalism#F.conllu
# training#48#journalism#M.conllu
# test#6#journalism#F.conllu
# training#105#journalism#F.conllu
# test#2#journalism#F.conllu
# test#187#journalism#M.conllu
# test#85#journalism#M.conllu
# test#35#journalism#F.conllu
# test#67#journalism#M.conllu
# training#28#journalism#M.conllu
# test#38#journalism#F.conllu
# training#195#journalism#F.conllu
# test#25#journalism#F.conllu
# training#9#journalism#M.conllu
# training#56#journalism#M.conllu
# training#198#journalism#F.conllu
# training#2#journalism#M.conllu
# training#188#journalism#F.conllu
# training#78#journalism#M.conllu
# training#157#journalism#F.conllu
# training#72#journalism#M.conllu
# test#194#journalism#M.conllu
# training#26#journalism#M.conllu
# test#57#journalism#F.conllu
# test#66#journalism#M.conllu
# training#21#journalism#M.conllu
# test#116#journalism#F.conllu
# test#10#journalism#F.conllu

# %%
file_path
# Out:
# '/content/profiling_output/11152/test#10#journalism#F.conllu'

# %%
document = Document(file_path)

# %%
path = document.document_path

info = path.split('.')[0]
info
# Out:
# '/content/profiling_output/11152/test#10#journalism#F'

# %%
info = info.split('#')
info
# Out:
# ['/content/profiling_output/11152/training', '37', 'journalism', 'M']

# %%
split = info[0]
genre = info[2]
gender = info[3]

# %%
gender
# Out:
# 'M'
