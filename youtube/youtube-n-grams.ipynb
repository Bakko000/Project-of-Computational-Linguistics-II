# %%
import re #pacchetto per espressioni regolari
import os #pacchetto per muoversi nelle cartelle
import sys
sys.path.append('..')  # Add parent directory to the Python path
from utils.helpers import *

# %%
conllu_dir = 'data/profiling_output/11462/'

# %%
all_documents = []
for file_name in os.listdir(conllu_dir):
    file_path = os.path.join(conllu_dir, file_name)
    document = Document(file_path)
    load_document_sentences(document)
    all_documents.append(document)

# %%
sample_document = all_documents[0]
for sentence in sample_document.sentences[:2]:
    tokens = [token.word for token in sentence.tokens]
    print(' - '.join(tokens))
    print('\n_________________\n')
# Out:
# Wow - io - mi - chiamo - Giada
#
# _________________

# %%
def extract_word_ngrams_from_sentence(word_ngrams, sentence, el, n):
    # creiamo una lista con tutte le parole
    if el == 'word':
        all_words = sentence.get_words()
    elif el == 'lemma':                             
        all_words = sentence.get_lemmas()
    elif el == 'pos':
        all_words = sentence.get_pos()
    else:
        raise Exception(f'Invalid element {el}')
    

    # scorriamo la lista delle parole ed estraiamo gli n-grammi
    for i in range(0, len(all_words) - n + 1): # -n+1 serve per non uscire dal vettore
        ngram_words = all_words[i: i + n]
        ngram = f'{el.upper()}_{n}_' + '_'.join(ngram_words)
        # print(f'{i}: {ngram_words} -> {ngram}')
        if ngram not in word_ngrams:
            word_ngrams[ngram] = 1
        else:
            word_ngrams[ngram] += 1

    return word_ngrams

# %%
def extract_documents_ngrams(all_documents, n):
    for document in all_documents:
        document_ngrams = dict()
        for sentence in document.sentences:
            extract_word_ngrams_from_sentence(document_ngrams, sentence, 'word', n)
            
        document.features = document_ngrams

# %%
def extract_documents_ngrams_normalized(all_documents, n):
    for document in all_documents:
        word_ngrams = dict()
        for sentence in document.sentences:
            extract_word_ngrams_from_sentence(word_ngrams, sentence, 'word', n)

        num_words = document.get_num_tokens()
        normalize_ngrams(word_ngrams, num_words)

        document_ngrams = word_ngrams 

        document.features = document_ngrams

# %% [markdown]
# # Bigrammi con Word, POS, Lemma

# %%
extract_documents_ngrams(all_documents, n=2) # n=unigramma, bigramma, trigramma, quadrigramma

# %%
extract_documents_ngrams_normalized(all_documents, n=2)

# %%
def train_test_split(all_documents):
    train_features_dict, train_labels = [], []
    test_features_dict, test_labels = [], []
    
    for document in all_documents:
        if document.split == 'training':
            train_features_dict.append(document.features)
            train_labels.append(document.gender)
        else:
            test_features_dict.append(document.features)
            test_labels.append(document.gender)
    
    return train_features_dict, train_labels, test_features_dict, test_labels

# %%
train_features_dict, train_labels, test_features_dict, test_labels = train_test_split(all_documents)

# %%
len(train_features_dict), len(train_labels), len(test_features_dict), len(test_labels)
# Out:
# (4395, 4395, 4400, 4400)

# %%
get_num_features(train_features_dict)
print(f'Numero features: {get_num_features(train_features_dict)}')
# Out:
# Numero features: 61491

# %%
#train_features_dict = filter_features(train_features_dict, 5)
#print(f'Numero features dopo il filtro: {get_num_features(train_features_dict)}')

# %%
from sklearn.feature_extraction import DictVectorizer

vectorizer = DictVectorizer()
X_train = vectorizer.fit_transform(train_features_dict)

# %%
vectorizer.get_feature_names_out(X_train).tolist()
# Out:
# ['WORD_2_!!!!!!!!!!!!!!_ahahahahha',
#  'WORD_2_!!!!!!!!!!_e',
#  'WORD_2_!!!!!!!!!_!!😂',
#  'WORD_2_!!!!!!!!!_sempre',
#  'WORD_2_!!!!!!!!_!',
#  'WORD_2_!!!!!!_!',
#  'WORD_2_!!!!!!burn_in',
#  'WORD_2_!!!!!VOI_CHE',
#  'WORD_2_!!!!!_!',
#  'WORD_2_!!!!!_A',
#  'WORD_2_!!!!!_LADRI',
#  'WORD_2_!!!!!_e',
#  'WORD_2_!!!!!_tanta',
#  'WORD_2_!!!!!grazie_!',
#  'WORD_2_!!!!!….💓.._💓',
#  'WORD_2_!!!!...tipo_chi',
#  'WORD_2_!!!!_!',
#  'WORD_2_!!!!_grande',
#  'WORD_2_!!!!grazie_!',
#  'WORD_2_!!!...tutti_quelli',
#  'WORD_2_!!!MITO_!',
#  'WORD_2_!!!_!',
#  'WORD_2_!!!_!!',
#  'WORD_2_!!!_!!!',
#  'WORD_2_!!!_!!!!!',
#  'WORD_2_!!!_!!!!!!',
#  'WORD_2_!!!_!!!!!!!',
#  'WORD_2_!!!_!!!!!!!!!!!!!',
#  'WORD_2_!!!_!!!!!!!!!!!!!!!!!!!!!!!',
#  'WORD_2_!!!_!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  'WORD_2_!!!_!par',
#  'WORD_2_!!!_!😘😘😍😍😍',
#  'WORD_2_!!!_"',
#  'WORD_2_!!!_)',
#  'WORD_2_!!!_.',
#  'WORD_2_!!!_?',
#  'WORD_2_!!!_A',
#  'WORD_2_!!!_BRAVA',
#  'WORD_2_!!!_Complimenti',
#  'WORD_2_!!!_FAI',
#  'WORD_2_!!!_Grandissima',
#  'WORD_2_!!!_Ho',
#  'WORD_2_!!!_Lorenzin',
#  'WORD_2_!!!_Meteore',
#  'WORD_2_!!!_PARASSITA',
#  'WORD_2_!!!_PICCOLO',
#  'WORD_2_!!!_Peccato',
#  'WORD_2_!!!_Semplice',
#  'WORD_2_!!!_Siamo',
#  'WORD_2_!!!_Soprattutto',
#  'WORD_2_!!!_Violenza',
#  'WORD_2_!!!_bellissimo',
#  'WORD_2_!!!_bravo',
#  'WORD_2_!!!_buona',
#  'WORD_2_!!!_complimenti',
#  'WORD_2_!!!_di',
#  'WORD_2_!!!_e',
#  'WORD_2_!!!_emozionante',
#  'WORD_2_!!!_forse',
#  'WORD_2_!!!_hihihi',
#  'WORD_2_!!!_il',
#  'WORD_2_!!!_immagino',
#  'WORD_2_!!!_incredibile',
#  'WORD_2_!!!_mi',
#  'WORD_2_!!!_prima',
#  'WORD_2_!!!_quanti',
#  'WORD_2_!!!_sei',
#  'WORD_2_!!!_siete',
#  'WORD_2_!!!_top',
#  'WORD_2_!!!_vedi',
#  'WORD_2_!!!_😉😉😉',
#  'WORD_2_!!!buona_pasqua',
#  'WORD_2_!!)_...comunque...in',
#  'WORD_2_!!........Poi_può',
#  'WORD_2_!!...grande_Ste',
#  'WORD_2_!!1_!!1!!',
#  'WORD_2_!!1_they',
#  'WORD_2_!!:_)',
#  'WORD_2_!!:_-',
#  'WORD_2_!!Fantastico_attore',
#  'WORD_2_!!Sii_a',
#  'WORD_2_!!TUTTI_I',
#  'WORD_2_!!_!',
#  'WORD_2_!!_!!',
#  'WORD_2_!!_!!!',
#  'WORD_2_!!_!!!!',
#  'WORD_2_!!_!!!!!',
#  'WORD_2_!!_!!!!!!',
#  'WORD_2_!!_!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!!!!!!!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  'WORD_2_!!_!!:',
#  'WORD_2_!!_!!👏',
#  'WORD_2_!!_!❤️❤️❤️❤️',
#  'WORD_2_!!_(',
#  'WORD_2_!!_.',
#  'WORD_2_!!_:',
#  'WORD_2_!!_?',
#  'WORD_2_!!_Complimenti',
#  'WORD_2_!!_Forza',
#  'WORD_2_!!_MA',
#  'WORD_2_!!_che',
#  'WORD_2_!!_complimenti',
#  'WORD_2_!!_grande',
#  'WORD_2_!!_ha',
#  'WORD_2_!!_madu',
#  'WORD_2_!!_molto',
#  'WORD_2_!!_palestina',
#  'WORD_2_!!_😂😂👍',
#  'WORD_2_!!_😭',
#  'WORD_2_!!ho_sbagliato',
#  'WORD_2_!!io_direi',
#  'WORD_2_!!la_canzone',
#  'WORD_2_!!non_ci',
#  'WORD_2_!!se_nn',
#  'WORD_2_!!sei_un',
#  'WORD_2_!!subiamo_cazzate',
#  'WORD_2_!!ti_si',
#  'WORD_2_!!un_artista',
#  'WORD_2_!!😂😂_però',
#  'WORD_2_!.......fortunato_te',
#  "WORD_2_!.....Comunque_l'",
#  'WORD_2_!.....siamo_in',
#  "WORD_2_!....non_avro'",
#  'WORD_2_!..._)Del',
#  'WORD_2_!...emozione_zero',
#  'WORD_2_!...il_vincitore',
#  'WORD_2_!:_)',
#  'WORD_2_!?_!',
#  'WORD_2_!?_!?',
#  'WORD_2_!?_)',
#  'WORD_2_!?_?',
#  'WORD_2_!Bello_,',
#  'WORD_2_!Che_attore',
#  'WORD_2_!Curiosità_:',
#  'WORD_2_!Da_Dio',
#  'WORD_2_!Io_esprimo',
#  'WORD_2_!Mi_dispiace',
#  'WORD_2_!Mi_piacciono',
#  'WORD_2_!Non_capisco',
#  'WORD_2_!Non_vi',
#  'WORD_2_!Ricordare_serve',
#  'WORD_2_!Rifletti_davvero',
#  'WORD_2_!Satana_è',
#  'WORD_2_!UFFA_!',
#  'WORD_2_!_!',
#  'WORD_2_!_!!',
#  'WORD_2_!_!!!',
#  'WORD_2_!_!!!!',
#  'WORD_2_!_!!!!!',
#  'WORD_2_!_!!!!!!',
#  'WORD_2_!_!!!!!!!',
#  'WORD_2_!_!!!!!!!!',
#  'WORD_2_!_!!!!!!!!!!',
#  'WORD_2_!_!!!!grazie',
#  'WORD_2_!_!!sei',
#  'WORD_2_!_!!subiamo',
#  'WORD_2_!_!!ti',
#  'WORD_2_!_!!😍😍😍',
#  'WORD_2_!_!ricordiamoci',
#  'WORD_2_!_!😂😂😂😂😂😂🤣🤣🤣🤣🤣🤣',
#  'WORD_2_!_!😭',
#  'WORD_2_!_"',
#  'WORD_2_!_(',
#  'WORD_2_!_)',
#  'WORD_2_!_,',
#  'WORD_2_!_:',
#  'WORD_2_!_?',
#  "WORD_2_!_A'",
#  'WORD_2_!_BASTA',
#  'WORD_2_!_BUTTATE',
#  'WORD_2_!_Complimenti',
#  'WORD_2_!_Comunque',
#  'WORD_2_!_Continua',
#  'WORD_2_!_Davvero',
#  'WORD_2_!_E',
#  'WORD_2_!_Fatelooo',
#  'WORD_2_!_Fidatevi',
#  'WORD_2_!_Grande',
#  'WORD_2_!_Grandioso',
#  'WORD_2_!_Grazie',
#  'WORD_2_!_IN',
#  'WORD_2_!_Lega',
#  'WORD_2_!_O',
#  'WORD_2_!_Passoh',
#  'WORD_2_!_Ragazzi',
#  'WORD_2_!_Riportiamo',
#  'WORD_2_!_Siete',
#  'WORD_2_!_Spreco',
#  'WORD_2_!_Tradotto',
#  'WORD_2_!_VERGOGNA',
#  'WORD_2_!_Vorrei',
#  'WORD_2_!__',
#  'WORD_2_!_ahahHhahahahahahahaha',
#  'WORD_2_!_ahaha',
#  'WORD_2_!_ahahahahahah',
#  'WORD_2_!_bel',
#  'WORD_2_!_canone',
#  'WORD_2_!_complimenti',
#  'WORD_2_!_comunque',
#  'WORD_2_!_continua',
#  'WORD_2_!_e',
#  'WORD_2_!_esisteranno',
#  'WORD_2_!_evviva',
#  'WORD_2_!_fantastico',
#  'WORD_2_!_grande',
#  'WORD_2_!_grazie',
#  'WORD_2_!_haha',
#  'WORD_2_!_hai',
#  'WORD_2_!_massima',
#  'WORD_2_!_non',
#  'WORD_2_!_o',
#  'WORD_2_!_purtroppo',
#  'WORD_2_!_questi',
#  'WORD_2_!_salvini',
#  'WORD_2_!_sempre',
#  'WORD_2_!_spero',
#  'WORD_2_!_un',
#  'WORD_2_!_uno',
#  'WORD_2_!_uomini',
#  'WORD_2_!_voglio',
#  'WORD_2_!_”',
#  'WORD_2_!_👏👏',
#  'WORD_2_!_🔝',
#  'WORD_2_!_😁',
#  'WORD_2_!_😄',
#  'WORD_2_!_😍😍',
#  'WORD_2_!_🙂',
#  'WORD_2_!attraverso_tua',
#  'WORD_2_!bravo!il_carnevale',
#  'WORD_2_!che_spettacolo!sei',
#  'WORD_2_!convertiti,_Dio',
#  'WORD_2_!cosa_vuoi',
#  'WORD_2_!credente,no!haaa_!quello',
#  'WORD_2_!dentro_!',
#  'WORD_2_!e_mi',
#  'WORD_2_!e_se',
#  'WORD_2_!faremo_i',
#  'WORD_2_!forza_fratello',
#  'WORD_2_!o_preferisci',
#  'WORD_2_!par_la',
#  'WORD_2_!quello_di',
#  'WORD_2_!ricordiamoci_che',
#  'WORD_2_!vedi_geroglifici',
#  'WORD_2_!…_Naturalmente',
#  'WORD_2_!❤Grande_Uomo❤',
#  'WORD_2_"_!',
#  'WORD_2_"_!!',
#  'WORD_2_"_!.....Comunque',
#  'WORD_2_"_"',
#  'WORD_2_"_#',
#  'WORD_2_"_\'',
#  'WORD_2_"_(',
#  'WORD_2_"_)',
#  'WORD_2_"_*non*',
#  'WORD_2_"_,',
#  'WORD_2_"_-',
#  'WORD_2_"_.',
#  'WORD_2_"_..',
#  'WORD_2_"_...',
#  'WORD_2_"_....',
#  'WORD_2_"_.....',
#  'WORD_2_"_......',
#  'WORD_2_"_...................MA',
#  'WORD_2_"_...Ah',
#  'WORD_2_"_...dice',
#  'WORD_2_"_...ehhhh',
#  'WORD_2_"_...in',
#  'WORD_2_"_.Gente',
#  'WORD_2_"_2',
#  'WORD_2_"_70',
#  'WORD_2_"_:',
#  'WORD_2_"_;',
#  'WORD_2_"_?',
#  'WORD_2_"_A',
#  'WORD_2_"_AAAAAH',
#  'WORD_2_"_AGVSSSS',
#  'WORD_2_"_ANALIZZARE',
#  'WORD_2_"_APPLICATE',
#  'WORD_2_"_Adesso',
#  'WORD_2_"_Affrettiamoci',
#  'WORD_2_"_Ah',
#  'WORD_2_"_Ahahaha',
#  'WORD_2_"_Allegri',
#  'WORD_2_"_Aloraaa',
#  'WORD_2_"_Amen',
#  'WORD_2_"_American',
#  'WORD_2_"_Anche',
#  'WORD_2_"_Appena',
#  'WORD_2_"_Ave',
#  'WORD_2_"_BELLA',
#  'WORD_2_"_Bambola',
#  'WORD_2_"_Benigni',
#  'WORD_2_"_CARO',
#  'WORD_2_"_CHE',
#  'WORD_2_"_CI',
#  'WORD_2_"_CIVILIZZATA',
#  'WORD_2_"_CLAUDIO',
#  'WORD_2_"_Calabria',
#  'WORD_2_"_Cani',
#  'WORD_2_"_Ci',
#  'WORD_2_"_Ciao',
#  'WORD_2_"_Come',
#  'WORD_2_"_DEMOCRAZIE',
#  'WORD_2_"_DONNA',
#  'WORD_2_"_Dietro',
#  'WORD_2_"_Dio',
#  'WORD_2_"_Dio.',
#  'WORD_2_"_Dirty',
#  'WORD_2_"_DripClan',
#  'WORD_2_"_E',
#  'WORD_2_"_E\'',
#  'WORD_2_"_EBREO',
#  'WORD_2_"_ED',
#  'WORD_2_"_EVOLUTA',
#  'WORD_2_"_Eh...............Ridendo',
#  'WORD_2_"_Ero-eroina',
#  'WORD_2_"_Esci',
#  'WORD_2_"_FUTURO',
#  'WORD_2_"_Fiumi',
#  'WORD_2_"_GENOCIDIO',
#  'WORD_2_"_GRANA',
#  'WORD_2_"_Grande',
#  'WORD_2_"_Grazie',
#  'WORD_2_"_Grida',
#  'WORD_2_"_Guai',
#  'WORD_2_"_I',
#  'WORD_2_"_IGNAAAZIOO',
#  'WORD_2_"_IL',
#  'WORD_2_"_INSOPPORTABILE',
#  'WORD_2_"_Il',
#  'WORD_2_"_Incapace',
#  'WORD_2_"_Io',
#  'WORD_2_"_L\'',
#  'WORD_2_"_LA',
#  'WORD_2_"_LIMITATI',
#  'WORD_2_"_LO',
#  'WORD_2_"_La',
#  'WORD_2_"_Le',
#  'WORD_2_"_Lei',
#  'WORD_2_"_Lo',
#  'WORD_2_"_Luca',
#  'WORD_2_"_Ma',
#  'WORD_2_"_Maroni',
#  'WORD_2_"_Mi',
#  'WORD_2_"_NON',
#  'WORD_2_"_NOOO',
#  'WORD_2_"_National',
#  'WORD_2_"_Nessun',
#  'WORD_2_"_Non',
#  'WORD_2_"_Nous',
#  'WORD_2_"_ONESTA\'',
#  'WORD_2_"_PERCHI',
#  'WORD_2_"_Pallottola',
#  'WORD_2_"_Parlare',
#  'WORD_2_"_Puffo',
#  'WORD_2_"_Quante',
#  'WORD_2_"_Quattro',
#  'WORD_2_"_Rivolgete',
#  'WORD_2_"_SEI',
#  'WORD_2_"_SESTA',
#  'WORD_2_"_SI',
#  'WORD_2_"_SIO',
#  'WORD_2_"_SOLD',
#  'WORD_2_"_SPECIALE',
#  'WORD_2_"_Santificati',
#  'WORD_2_"_Scusa',
#  'WORD_2_"_Shima',
#  'WORD_2_"_Solo',
#  'WORD_2_"_TU',
#  'WORD_2_"_Tell',
#  'WORD_2_"_Tener',
#  'WORD_2_"_The',
#  'WORD_2_"_Ti',
#  'WORD_2_"_Tuffiamoci',
#  'WORD_2_"_UFO',
#  'WORD_2_"_Vennero',
#  'WORD_2_"_Via',
#  'WORD_2_"_Voi',
#  'WORD_2_"_Vorrei',
#  'WORD_2_"_Và.......Ridendo',
#  'WORD_2_"_Yom',
#  'WORD_2_"_Zelig',
#  'WORD_2_"_a',
#  'WORD_2_"_abbiamo',
#  'WORD_2_"_accolti',
#  'WORD_2_"_adattano',
#  'WORD_2_"_ahahaha',
#  'WORD_2_"_ahahahahah',
#  'WORD_2_"_alloraaaaaa',
#  'WORD_2_"_aloraaaaaaaaaaa',
#  'WORD_2_"_alto',
#  'WORD_2_"_ambientale',
#  'WORD_2_"_andiamo',
#  'WORD_2_"_apologia',
#  'WORD_2_"_approfondimenti',
#  'WORD_2_"_aprite',
#  'WORD_2_"_avvenenza',
#  'WORD_2_"_avvenimenti',
#  'WORD_2_"_basita',
#  'WORD_2_"_bella',
#  'WORD_2_"_bellissima',
#  'WORD_2_"_bene',
#  'WORD_2_"_blablabla',
#  'WORD_2_"_buoni',
#  'WORD_2_"_c\'',
#  'WORD_2_"_cani',
#  'WORD_2_"_capo',
#  'WORD_2_"_capolavoro',
#  'WORD_2_"_cara',
#  'WORD_2_"_carta',
#  'WORD_2_"_cattivi',
#  'WORD_2_"_cazzo',
#  'WORD_2_"_centro',
#  'WORD_2_"_che',
#  'WORD_2_"_chi',
#  'WORD_2_"_chissà',
#  'WORD_2_"_ci',
#  'WORD_2_"_collega',
#  'WORD_2_"_come',
#  'WORD_2_"_con',
#  'WORD_2_"_contraddistinta',
#  'WORD_2_"_contro',
#  'WORD_2_"_credere',
#  'WORD_2_"_da',
#  'WORD_2_"_decedo',
#  'WORD_2_"_decommissioning',
#  'WORD_2_"_di',
#  'WORD_2_"_dialogo',
#  'WORD_2_"_dicce',
#  'WORD_2_"_dice',
#  'WORD_2_"_dicono',
#  'WORD_2_"_dimenticano',
#  'WORD_2_"_dittatore',
#  'WORD_2_"_diverso',
#  'WORD_2_"_domanda',
#  'WORD_2_"_dove',
#  'WORD_2_"_dovremmo',
#  'WORD_2_"_duello',
#  'WORD_2_"_e',
#  'WORD_2_"_era',
#  'WORD_2_"_erano',
#  'WORD_2_"_esci',
#  'WORD_2_"_esemplare',
#  'WORD_2_"_essere',
#  'WORD_2_"_etc.',
#  'WORD_2_"_familiare',
#  'WORD_2_"_farfallina',
#  'WORD_2_"_feccia',
#  'WORD_2_"_fede',
#  'WORD_2_"_figlia',
#  'WORD_2_"_filopalestinese',
#  'WORD_2_"_fin',
#  'WORD_2_"_format',
#  'WORD_2_"_foto',
#  'WORD_2_"_fratello',
#  'WORD_2_"_friends',
#  'WORD_2_"_fuori',
#  'WORD_2_"_furono',
#  'WORD_2_"_genio',
#  'WORD_2_"_gente',
#  'WORD_2_"_giocano',
#  'WORD_2_"_giornalista',
#  'WORD_2_"_giovanotti',
#  'WORD_2_"_giudicanti',
#  'WORD_2_"_gli',
#  'WORD_2_"_governano',
#  'WORD_2_"_grande',
#  'WORD_2_"_grazie',
#  'WORD_2_"_grigio',
#  'WORD_2_"_guerra',
#  'WORD_2_"_ha',
#  'WORD_2_"_hahahahaha',
#  'WORD_2_"_hai',
#  'WORD_2_"_i',
#  'WORD_2_"_il',
#  'WORD_2_"_immensa',
#  'WORD_2_"_immigrati',
#  'WORD_2_"_imposta',
#  'WORD_2_"_improvviso',
#  'WORD_2_"_in',
#  'WORD_2_"_incontri',
#  'WORD_2_"_indagata',
#  'WORD_2_"_indecisa',
#  'WORD_2_"_innovativa',
#  'WORD_2_"_intellettuale',
#  'WORD_2_"_intenso',
#  'WORD_2_"_io',
#  'WORD_2_"_italiano',
#  'WORD_2_"_killer',
#  'WORD_2_"_l\'',
#  'WORD_2_"_la',
#  'WORD_2_"_lei',
#  'WORD_2_"_liberta',
#  'WORD_2_"_like',
#  'WORD_2_"_ll',
#  'WORD_2_"_ma',
#  'WORD_2_"_mah',
#  'WORD_2_"_mal',
#  'WORD_2_"_male',
#  'WORD_2_"_membri',
#  'WORD_2_"_mettetevelo',
#  'WORD_2_"_mi',
#  'WORD_2_"_migrano',
#  'WORD_2_"_ministra',
#  'WORD_2_"_momenti',
#  'WORD_2_"_musica',
#  'WORD_2_"_nemico',
#  'WORD_2_"_nessuna',
#  'WORD_2_"_neutra',
#  'WORD_2_"_nietzsche',
#  'WORD_2_"_nira',
#  'WORD_2_"_no',
#  'WORD_2_"_noblesse',
#  'WORD_2_"_non',
#  'WORD_2_"_nonche',
#  'WORD_2_"_norma',
#  'WORD_2_"_nostro',
#  'WORD_2_"_nuovi',
#  'WORD_2_"_o',
#  'WORD_2_"_odio',
#  'WORD_2_"_opposizioni',
#  'WORD_2_"_ordinaria',
#  'WORD_2_"_pacifista',
#  'WORD_2_"_padreceleste.com',
#  'WORD_2_"_padri',
#  'WORD_2_"_palestinesi',
#  'WORD_2_"_parassita',
#  'WORD_2_"_pareva',
#  'WORD_2_"_partigiano',
#  'WORD_2_"_patetico',
#  'WORD_2_"_pensate',
#  'WORD_2_"_pensieri',
#  'WORD_2_"_pensionati',
#  'WORD_2_"_per',
#  'WORD_2_"_perbenista',
#  'WORD_2_"_pericolo',
#  'WORD_2_"_persona',
#  'WORD_2_"_petrodollari',
#  'WORD_2_"_politica',
#  'WORD_2_"_polivinilcoloruro',
#  'WORD_2_"_popolo',
#  'WORD_2_"_populista',
#  'WORD_2_"_potrebbero',
#  'WORD_2_"_prenda',
#  'WORD_2_"_presunta',
#  'WORD_2_"_pro',
#  'WORD_2_"_programma',
#  'WORD_2_"_provare',
#  'WORD_2_"_pura',
#  'WORD_2_"_quali',
#  'WORD_2_"_quando',
#  'WORD_2_"_quanto',
#  'WORD_2_"_quasi',
#  'WORD_2_"_quello',
#  'WORD_2_"_ragionare',
#  'WORD_2_"_religioni',
#  'WORD_2_"_ricomprenda',
#  'WORD_2_"_riesumato',
#  'WORD_2_"_rigido',
#  'WORD_2_"_risorsa',
#  'WORD_2_"_risorse',
#  'WORD_2_"_rubato',
#  'WORD_2_"_rumore',
#  'WORD_2_"_salvini',
#  'WORD_2_"_sanno',
#  'WORD_2_"_sapete',
#  'WORD_2_"_sardus',
#  'WORD_2_"_sarebbe',
#  'WORD_2_"_sbeffeggiava',
#  'WORD_2_"_sclerotico',
#  'WORD_2_"_scoperto',
#  'WORD_2_"_se',
#  'WORD_2_"_secessione',
#  'WORD_2_"_secondo',
#  'WORD_2_"_sei',
#  'WORD_2_"_senza',
#  'WORD_2_"_sfumando',
#  'WORD_2_"_signor',
#  'WORD_2_"_sintesi',
#  'WORD_2_"_sistema',
#  'WORD_2_"_smacchiamo',
#  'WORD_2_"_sono',
#  'WORD_2_"_sopravvivere',
#  'WORD_2_"_sostegno',
#  'WORD_2_"_specchietti',
#  'WORD_2_"_stato',
#  'WORD_2_"_stavano',
#  'WORD_2_"_su',
#  'WORD_2_"_sviste',
#  'WORD_2_"_tac',
#  'WORD_2_"_tenere',
#  'WORD_2_"_terra',
#  'WORD_2_"_terza',
#  'WORD_2_"_toscanacci',
#  'WORD_2_"_tot',
#  'WORD_2_"_tra',
#  'WORD_2_"_traduce',
#  'WORD_2_"_travellerriferimento',
#  'WORD_2_"_trovato"',
#  'WORD_2_"_un',
#  'WORD_2_"_una',
#  'WORD_2_"_unione',
#  'WORD_2_"_vedere',
#  'WORD_2_"_vedete',
#  'WORD_2_"_viaggiatore',
#  'WORD_2_"_violentato',
#  'WORD_2_"_vivere',
#  'WORD_2_"_vogliono',
#  'WORD_2_"_vu-cumprà',
#  'WORD_2_"_we',
#  'WORD_2_"_xD',
#  'WORD_2_"_youtuber',
#  'WORD_2_"_È',
#  'WORD_2_"_è',
#  'WORD_2_"_❤',
#  'WORD_2_"_😂',
#  'WORD_2_"_😂😂😂😂😂😂😂😂😂😂😂😙😙😙😙😙❤💙💙❤❤💋💋💋❤💋💋❤❤💙😍😍😍',
#  'WORD_2_"_😂🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣😂😂😂😂🤣😂🤣😂🤣😂🤣😂🤣😂😂😂🤣🤣😂🤣😂🤣',
#  'WORD_2_"_😣',
#  'WORD_2_#NAME_?',
#  'WORD_2_#SIOISTHEBEST_!',
#  'WORD_2_#_ForzaPovia',
#  'WORD_2_#_RESISTENZA',
#  'WORD_2_#_e',
#  'WORD_2_#boldrini_bambola',
#  'WORD_2_#donnenonbambolegonfiabili_IL',
#  'WORD_2_#emmamarrone_#browncrew',
#  'WORD_2_#favirisponde_vai',
#  'WORD_2_#lezzini_#maideboli',
#  'WORD_2_#nonèlinferno_#emmamarrone',
#  'WORD_2_#penisforharambe_#lezzini',
#  'WORD_2_#saschenzo_a',
#  'WORD_2_%_.',
#  'WORD_2_%_...',
#  'WORD_2_%_5stelle',
#  'WORD_2_%_MADE',
#  'WORD_2_%_W',
#  'WORD_2_%_che',
#  'WORD_2_%_di',
#  'WORD_2_%_e',
#  'WORD_2_%_non',
#  'WORD_2_%_questa',
#  'WORD_2_%_salvini',
#  'WORD_2_%_una',
#  'WORD_2_&_MORO',
#  'WORD_2_&_mates',
#  "WORD_2_''SBAGLIATI'_'",
#  "WORD_2_''_comici'",
#  "WORD_2_''_giusto",
#  "WORD_2_''_io",
#  "WORD_2_''_non",
#  "WORD_2_''_sono",
#  "WORD_2_''_tradire",
#  "WORD_2_'63_e",
#  "WORD_2_'64_The",
#  "WORD_2_'80_e",
#  "WORD_2_'90.._.",
#  "WORD_2_'92_?",
#  "WORD_2_'93_che",
#  "WORD_2_'93_mi",
#  "WORD_2_'95_sembrava",
#  "WORD_2_'Abd_Allâh",
#  "WORD_2_'Eva_'",
#  "WORD_2_'THE_WORST'",
#  "WORD_2_'_!",
#  'WORD_2_\'_"',
#  "WORD_2_'_'",
#  "WORD_2_'_(",
#  "WORD_2_'_,",
#  "WORD_2_'_-",
#  "WORD_2_'_.",
#  "WORD_2_'_BENIGNI",
#  "WORD_2_'_D",
#  "WORD_2_'_Ecco",
#  "WORD_2_'_IL",
#  "WORD_2_'_INTERA",
#  "WORD_2_'_Ibrahimovic",
#  "WORD_2_'_Il",
#  "WORD_2_'_Islanda",
#  "WORD_2_'_Italia",
#  "WORD_2_'_LA",
#  "WORD_2_'_Moni",
#  "WORD_2_'_Musica",
#  "WORD_2_'_Pierfrancesco",
#  "WORD_2_'_San",
#  "WORD_2_'_Se",
#  "WORD_2_'_TEMUTA",
#  "WORD_2_'_VERITIERA",
#  "WORD_2_'_We",
#  "WORD_2_'_a",
#  "WORD_2_'_alcune",
#  "WORD_2_'_ammalata",
#  "WORD_2_'_ancora",
#  "WORD_2_'_andiamo",
#  "WORD_2_'_andrei",
#  "WORD_2_'_aria",
#  "WORD_2_'_bella",
#  "WORD_2_'_bellisimo",
#  "WORD_2_'_bello",
#  "WORD_2_'_bene.....l",
#  "WORD_2_'_bravo",
#  "WORD_2_'_camminera",
#  "WORD_2_'_ch'",
#  "WORD_2_'_che",
#  "WORD_2_'_chi",
#  "WORD_2_'_ci",
#  "WORD_2_'_cit",
#  "WORD_2_'_come",
#  "WORD_2_'_composta",
#  "WORD_2_'_con",
#  "WORD_2_'_considero",
#  "WORD_2_'_cosi",
#  "WORD_2_'_così",
#  "WORD_2_'_da",
#  "WORD_2_'_dando",
#  "WORD_2_'_datagli",
#  "WORD_2_'_davvero",
#  "WORD_2_'_deciso",
#  "WORD_2_'_di",
#  "WORD_2_'_dimenticando",
#  "WORD_2_'_disponibile",
#  "WORD_2_'_dissidenti",
#  "WORD_2_'_dominante",
#  "WORD_2_'_dove",
#  "WORD_2_'_e",
#  "WORD_2_'_economico",
#  "WORD_2_'_enorme",
#  "WORD_2_'_esisteva",
#  "WORD_2_'_facile",
#  "WORD_2_'_famoso",
#  "WORD_2_'_fantastico",
#  "WORD_2_'_fare",
#  "WORD_2_'_felice",
#  "WORD_2_'_figa",
#  "WORD_2_'_fino",
#  "WORD_2_'_forse",
#  "WORD_2_'_gay",
#  "WORD_2_'_gia",
#  "WORD_2_'_giusto",
#  "WORD_2_'_gli",
#  "WORD_2_'_ha",
#  "WORD_2_'_hanno",
#  "WORD_2_'_il",
#  "WORD_2_'_immenso",
#  "WORD_2_'_immigrazione",
#  "WORD_2_'_in",
#  "WORD_2_'_indietro",
#  "WORD_2_'_indimenticabile!Sei",
#  "WORD_2_'_informato",
#  "WORD_2_'_inutile",
#  "WORD_2_'_ispirata",
#  "WORD_2_'_l",
#  "WORD_2_'_la",
#  "WORD_2_'_lecito",
#  "WORD_2_'_limitativo",
#  "WORD_2_'_lui",
#  "WORD_2_'_ma",
#  "WORD_2_'_mai",
#  "WORD_2_'_matto",
#  "WORD_2_'_molto",
#  "WORD_2_'_muoro",
#  "WORD_2_'_na",
#  "WORD_2_'_nazionale",
#  "WORD_2_'_non",
#  "WORD_2_'_nuova",
#  "WORD_2_'_per",
#  "WORD_2_'_perche",
#  "WORD_2_'_però",
#  "WORD_2_'_piaciuto",
#  "WORD_2_'_più",
#  "WORD_2_'_pochissimo",
#  "WORD_2_'_politico",
#  "WORD_2_'_presente",
#  "WORD_2_'_promiscuita",
#  "WORD_2_'_propriamente",
#  "WORD_2_'_qualcosa",
#  "WORD_2_'_quando",
#  "WORD_2_'_questa",
#  "WORD_2_'_queste",
#  "WORD_2_'_rallentata",
#  "WORD_2_'_responsabile",
#  "WORD_2_'_ricorda",
#  "WORD_2_'_riuscito",
#  "WORD_2_'_satanico",
#  "WORD_2_'_sbarcato.",
#  "WORD_2_'_scritto",
#  "WORD_2_'_se",
#  "WORD_2_'_sei",
#  "WORD_2_'_sembrato",
#  "WORD_2_'_semplici",
#  "WORD_2_'_sessismo",
#  "WORD_2_'_si",
#  "WORD_2_'_simultanea",
#  "WORD_2_'_sino",
#  "WORD_2_'_spesso",
#  "WORD_2_'_sragiona",
#  "WORD_2_'_stare",
#  "WORD_2_'_stato",
#  "WORD_2_'_sti",
#  "WORD_2_'_stia",
#  "WORD_2_'_sto",
#  "WORD_2_'_su",
#  "WORD_2_'_te",
#  "WORD_2_'_tenerezza",
#  "WORD_2_'_terroristici",
#  "WORD_2_'_tesoro",
#  "WORD_2_'_tornati",
#  "WORD_2_'_tra",
#  "WORD_2_'_trasuda",
#  "WORD_2_'_umanita",
#  "WORD_2_'_un",
#  "WORD_2_'_un'",
#  "WORD_2_'_una",
#  "WORD_2_'_veramente",
#  "WORD_2_'_verita",
#  "WORD_2_'_vero",
#  "WORD_2_'_😂😂😂😂😂",
#  "WORD_2_'e_Napul",
#  "WORD_2_'e_ndrocchia",
#  "WORD_2_'m_italian",
#  "WORD_2_'o_passat",
#  "WORD_2_'s_ITALIA",
#  "WORD_2_'s_Simulator",
#  "WORD_2_'s_act",
#  "WORD_2_'s_ignorance..",
#  "WORD_2_'s_wonderful",
#  "WORD_2_'t_happen",
#  "WORD_2_'t_laugh",
#  'WORD_2_(_!',
#  'WORD_2_(_(',
#  'WORD_2_(_*',
#  'WORD_2_(_**',
#  'WORD_2_(_***',
#  'WORD_2_(_****',
#  'WORD_2_(_+Sio😊😊',
#  'WORD_2_(_.',
#  'WORD_2_(_...',
#  'WORD_2_(_...........',
#  'WORD_2_(_..ma',
#  'WORD_2_(_1648',
#  'WORD_2_(_1863',
#  'WORD_2_(_1997-2017',
#  'WORD_2_(_5',
#  'WORD_2_(_:',
#  'WORD_2_(_=mistificazione',
#  'WORD_2_(_?',
#  'WORD_2_(_A',
#  'WORD_2_(_Achille',
#  'WORD_2_(_Aldilà',
#  'WORD_2_(_American',
#  'WORD_2_(_Arcangeli',
#  'WORD_2_(_Atti',
#  'WORD_2_(_BPA',
#  'WORD_2_(_Beh',
#  'WORD_2_(_Berlusca',
#  'WORD_2_(_Brando',
#  'WORD_2_(_Cairo',
#  'WORD_2_(_Cavallo',
#  'WORD_2_(_DATO',
#  'WORD_2_(_Dato',
#  'WORD_2_(_E',
#  'WORD_2_(_Eccezionale',
#  'WORD_2_(_G.Bongiorno',
#  'WORD_2_(_Genesi',
#  'WORD_2_(_Germania',
#  'WORD_2_(_Historia',
#  'WORD_2_(_IRREVERSIBILE',
#  'WORD_2_(_Inghilterra',
#  'WORD_2_(_Inoltre',
#  'WORD_2_(_Iraq',
#  'WORD_2_(_It',
#  'WORD_2_(_Italiani',
#  'WORD_2_(_Lega',
#  'WORD_2_(_Loro',
#  'WORD_2_(_Lucifero',
#  'WORD_2_(_Magari',
#  'WORD_2_(_Michele',
#  'WORD_2_(_NOI',
#  'WORD_2_(_ONU-UE',
#  'WORD_2_(_Oriana',
#  'WORD_2_(_Palermo',
#  'WORD_2_(_PdL',
#  'WORD_2_(_Per',
#  'WORD_2_(_Purtroppo',
#  'WORD_2_(_Quando',
#  'WORD_2_(_SONO',
#  'WORD_2_(_Salvini',
#  'WORD_2_(_UNIPOL',
#  'WORD_2_(_V',
#  'WORD_2_(_Vita',
#  'WORD_2_(_a',
#  'WORD_2_(_abbiamo',
#  'WORD_2_(_alcuni',
#  'WORD_2_(_aldilà',
#  'WORD_2_(_altrimenti',
#  'WORD_2_(_anche',
#  'WORD_2_(_ancora',
#  'WORD_2_(_andazzo',
#  'WORD_2_(_avendo',
#  'WORD_2_(_avesse',
#  'WORD_2_(_bella',
#  'WORD_2_(_brillantemente',
#  'WORD_2_(_bromazepam',
#  'WORD_2_(_buona',
#  "WORD_2_(_c'",
#  'WORD_2_(_canotto',
#  'WORD_2_(_capitan',
#  'WORD_2_(_ce',
#  'WORD_2_(_certo',
#  'WORD_2_(_che',
#  'WORD_2_(_ci',
#  'WORD_2_(_cibo',
#  'WORD_2_(_cioè',
#  'WORD_2_(_classe',
#  'WORD_2_(_come',
#  'WORD_2_(_comprendendo',
#  'WORD_2_(_compresa',
#  'WORD_2_(_con',
#  'WORD_2_(_coperta',
#  'WORD_2_(_cosa',
#  'WORD_2_(_credo',
#  'WORD_2_(_da',
#  'WORD_2_(_demoni',
#  'WORD_2_(_dentro',
#  'WORD_2_(_di',
#  'WORD_2_(_dice',
#  'WORD_2_(_dopo',
#  'WORD_2_(_e',
#  'WORD_2_(_eccezione',
#  'WORD_2_(_en',
#  'WORD_2_(_entrambi',
#  'WORD_2_(_estrema',
#  'WORD_2_(_fai',
#  'WORD_2_(_falso',
#  'WORD_2_(_femminile',
#  'WORD_2_(_finto',
#  'WORD_2_(_forse',
#  'WORD_2_(_gli',
#  'WORD_2_(_gran',
#  'WORD_2_(_ha',
#  'WORD_2_(_i',
#  'WORD_2_(_il',
#  'WORD_2_(_in',
#  'WORD_2_(_inclusi',
#  'WORD_2_(_inquadrato',
#  'WORD_2_(_insieme',
#  'WORD_2_(_l',
#  'WORD_2_(_la',
#  'WORD_2_(_le',
#  'WORD_2_(_lei',
#  'WORD_2_(_lo',
#  'WORD_2_(_lobby',
#  'WORD_2_(_luca',
#  'WORD_2_(_ma',
#  'WORD_2_(_molti',
#  'WORD_2_(_nn',
#  'WORD_2_(_non',
#  'WORD_2_(_normanni',
#  'WORD_2_(_o',
#  'WORD_2_(_oltre',
#  'WORD_2_(_oltretutto',
#  'WORD_2_(_ottimo',
#  'WORD_2_(_otto',
#  'WORD_2_(_ovviamente',
#  'WORD_2_(_p.s.',
#  'WORD_2_(_partendo',
#  'WORD_2_(_pena',
#  'WORD_2_(_per',
#  'WORD_2_(_perché',
#  'WORD_2_(_poichè',
#  'WORD_2_(_que',
#  'WORD_2_(_quelle',
#  'WORD_2_(_quelli',
#  'WORD_2_(_questione',
#  'WORD_2_(_questo',
#  'WORD_2_(_quindi',
#  'WORD_2_(_rappresentante',
#  'WORD_2_(_ricordo',
#  'WORD_2_(_salvata',
#  'WORD_2_(_scaricando',
#  'WORD_2_(_scusate',
#  'WORD_2_(_se',
#  'WORD_2_(_sebbene',
#  'WORD_2_(_secondo',
#  'WORD_2_(_seguace',
#  'WORD_2_(_senza',
#  'WORD_2_(_si',
#  'WORD_2_(_sic',
#  'WORD_2_(_solo',
#  'WORD_2_(_sono',
#  'WORD_2_(_soprattutto',
#  'WORD_2_(_sopratutto',
#  'WORD_2_(_speciale',
#  'WORD_2_(_spero',
#  'WORD_2_(_spesso',
#  'WORD_2_(_stato',
#  ...]

# %%
from sklearn.preprocessing import MaxAbsScaler

scaler = MaxAbsScaler()
X_train = scaler.fit_transform(X_train)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC

# Define the parameter grid to search through
param_grid = {
    'C': [10, 1, 0.1, 0.01, 0.001],  # Regularization parameter
    'dual': [True, False]
}

# Initialize SVM with linear kernel
svc = LinearSVC()

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=5, refit=True)

# Fit the grid search to your data
grid_search.fit(X_train, train_labels)

# Get mean test scores across folds
mean_test_scores = grid_search.cv_results_['mean_test_score']

# Print the best parameters and best score
print("Best parameters found:", grid_search.best_params_)
print("Best score found:", grid_search.best_score_)
# Out:
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters found: {'C': 0.001, 'dual': True}
# Best score found: 0.5337883959044368

# %%
X_test = vectorizer.transform(test_features_dict)
X_test = scaler.transform(X_test)

# %%
# Get the best estimator (model) found by grid search
best_model = grid_search.best_estimator_

# Now, you can use this best_model to make predictions on new data
# For example, if you have new data X_new, you can predict its labels as follows:
predictions = best_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix
test_predictions = predictions
print(classification_report(test_labels, test_predictions, zero_division=0)) # output_dict=True
# Out:
#               precision    recall  f1-score   support
#
#            F       0.51      0.82      0.63      2200
#            M       0.55      0.22      0.31      2200
#
#     accuracy                           0.52      4400
#    macro avg       0.53      0.52      0.47      4400
# weighted avg       0.53      0.52      0.47      4400

# %%
ConfusionMatrixDisplay.from_predictions(test_labels, test_predictions, xticks_rotation='vertical', cmap='Blues')

# %%
coefs = best_model.coef_  # ndarray of shape (1, n_features) if n_classes == 2 else (n_classes, n_features)

# %%
features_names = vectorizer.get_feature_names_out(X_train).tolist()
features_names
# Out:
# ['WORD_2_!!!!!!!!!!!!!!_ahahahahha',
#  'WORD_2_!!!!!!!!!!_e',
#  'WORD_2_!!!!!!!!!_!!😂',
#  'WORD_2_!!!!!!!!!_sempre',
#  'WORD_2_!!!!!!!!_!',
#  'WORD_2_!!!!!!_!',
#  'WORD_2_!!!!!!burn_in',
#  'WORD_2_!!!!!VOI_CHE',
#  'WORD_2_!!!!!_!',
#  'WORD_2_!!!!!_A',
#  'WORD_2_!!!!!_LADRI',
#  'WORD_2_!!!!!_e',
#  'WORD_2_!!!!!_tanta',
#  'WORD_2_!!!!!grazie_!',
#  'WORD_2_!!!!!….💓.._💓',
#  'WORD_2_!!!!...tipo_chi',
#  'WORD_2_!!!!_!',
#  'WORD_2_!!!!_grande',
#  'WORD_2_!!!!grazie_!',
#  'WORD_2_!!!...tutti_quelli',
#  'WORD_2_!!!MITO_!',
#  'WORD_2_!!!_!',
#  'WORD_2_!!!_!!',
#  'WORD_2_!!!_!!!',
#  'WORD_2_!!!_!!!!!',
#  'WORD_2_!!!_!!!!!!',
#  'WORD_2_!!!_!!!!!!!',
#  'WORD_2_!!!_!!!!!!!!!!!!!',
#  'WORD_2_!!!_!!!!!!!!!!!!!!!!!!!!!!!',
#  'WORD_2_!!!_!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  'WORD_2_!!!_!par',
#  'WORD_2_!!!_!😘😘😍😍😍',
#  'WORD_2_!!!_"',
#  'WORD_2_!!!_)',
#  'WORD_2_!!!_.',
#  'WORD_2_!!!_?',
#  'WORD_2_!!!_A',
#  'WORD_2_!!!_BRAVA',
#  'WORD_2_!!!_Complimenti',
#  'WORD_2_!!!_FAI',
#  'WORD_2_!!!_Grandissima',
#  'WORD_2_!!!_Ho',
#  'WORD_2_!!!_Lorenzin',
#  'WORD_2_!!!_Meteore',
#  'WORD_2_!!!_PARASSITA',
#  'WORD_2_!!!_PICCOLO',
#  'WORD_2_!!!_Peccato',
#  'WORD_2_!!!_Semplice',
#  'WORD_2_!!!_Siamo',
#  'WORD_2_!!!_Soprattutto',
#  'WORD_2_!!!_Violenza',
#  'WORD_2_!!!_bellissimo',
#  'WORD_2_!!!_bravo',
#  'WORD_2_!!!_buona',
#  'WORD_2_!!!_complimenti',
#  'WORD_2_!!!_di',
#  'WORD_2_!!!_e',
#  'WORD_2_!!!_emozionante',
#  'WORD_2_!!!_forse',
#  'WORD_2_!!!_hihihi',
#  'WORD_2_!!!_il',
#  'WORD_2_!!!_immagino',
#  'WORD_2_!!!_incredibile',
#  'WORD_2_!!!_mi',
#  'WORD_2_!!!_prima',
#  'WORD_2_!!!_quanti',
#  'WORD_2_!!!_sei',
#  'WORD_2_!!!_siete',
#  'WORD_2_!!!_top',
#  'WORD_2_!!!_vedi',
#  'WORD_2_!!!_😉😉😉',
#  'WORD_2_!!!buona_pasqua',
#  'WORD_2_!!)_...comunque...in',
#  'WORD_2_!!........Poi_può',
#  'WORD_2_!!...grande_Ste',
#  'WORD_2_!!1_!!1!!',
#  'WORD_2_!!1_they',
#  'WORD_2_!!:_)',
#  'WORD_2_!!:_-',
#  'WORD_2_!!Fantastico_attore',
#  'WORD_2_!!Sii_a',
#  'WORD_2_!!TUTTI_I',
#  'WORD_2_!!_!',
#  'WORD_2_!!_!!',
#  'WORD_2_!!_!!!',
#  'WORD_2_!!_!!!!',
#  'WORD_2_!!_!!!!!',
#  'WORD_2_!!_!!!!!!',
#  'WORD_2_!!_!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!!!!!!!!!!!!!!',
#  'WORD_2_!!_!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  'WORD_2_!!_!!:',
#  'WORD_2_!!_!!👏',
#  'WORD_2_!!_!❤️❤️❤️❤️',
#  'WORD_2_!!_(',
#  'WORD_2_!!_.',
#  'WORD_2_!!_:',
#  'WORD_2_!!_?',
#  'WORD_2_!!_Complimenti',
#  'WORD_2_!!_Forza',
#  'WORD_2_!!_MA',
#  'WORD_2_!!_che',
#  'WORD_2_!!_complimenti',
#  'WORD_2_!!_grande',
#  'WORD_2_!!_ha',
#  'WORD_2_!!_madu',
#  'WORD_2_!!_molto',
#  'WORD_2_!!_palestina',
#  'WORD_2_!!_😂😂👍',
#  'WORD_2_!!_😭',
#  'WORD_2_!!ho_sbagliato',
#  'WORD_2_!!io_direi',
#  'WORD_2_!!la_canzone',
#  'WORD_2_!!non_ci',
#  'WORD_2_!!se_nn',
#  'WORD_2_!!sei_un',
#  'WORD_2_!!subiamo_cazzate',
#  'WORD_2_!!ti_si',
#  'WORD_2_!!un_artista',
#  'WORD_2_!!😂😂_però',
#  'WORD_2_!.......fortunato_te',
#  "WORD_2_!.....Comunque_l'",
#  'WORD_2_!.....siamo_in',
#  "WORD_2_!....non_avro'",
#  'WORD_2_!..._)Del',
#  'WORD_2_!...emozione_zero',
#  'WORD_2_!...il_vincitore',
#  'WORD_2_!:_)',
#  'WORD_2_!?_!',
#  'WORD_2_!?_!?',
#  'WORD_2_!?_)',
#  'WORD_2_!?_?',
#  'WORD_2_!Bello_,',
#  'WORD_2_!Che_attore',
#  'WORD_2_!Curiosità_:',
#  'WORD_2_!Da_Dio',
#  'WORD_2_!Io_esprimo',
#  'WORD_2_!Mi_dispiace',
#  'WORD_2_!Mi_piacciono',
#  'WORD_2_!Non_capisco',
#  'WORD_2_!Non_vi',
#  'WORD_2_!Ricordare_serve',
#  'WORD_2_!Rifletti_davvero',
#  'WORD_2_!Satana_è',
#  'WORD_2_!UFFA_!',
#  'WORD_2_!_!',
#  'WORD_2_!_!!',
#  'WORD_2_!_!!!',
#  'WORD_2_!_!!!!',
#  'WORD_2_!_!!!!!',
#  'WORD_2_!_!!!!!!',
#  'WORD_2_!_!!!!!!!',
#  'WORD_2_!_!!!!!!!!',
#  'WORD_2_!_!!!!!!!!!!',
#  'WORD_2_!_!!!!grazie',
#  'WORD_2_!_!!sei',
#  'WORD_2_!_!!subiamo',
#  'WORD_2_!_!!ti',
#  'WORD_2_!_!!😍😍😍',
#  'WORD_2_!_!ricordiamoci',
#  'WORD_2_!_!😂😂😂😂😂😂🤣🤣🤣🤣🤣🤣',
#  'WORD_2_!_!😭',
#  'WORD_2_!_"',
#  'WORD_2_!_(',
#  'WORD_2_!_)',
#  'WORD_2_!_,',
#  'WORD_2_!_:',
#  'WORD_2_!_?',
#  "WORD_2_!_A'",
#  'WORD_2_!_BASTA',
#  'WORD_2_!_BUTTATE',
#  'WORD_2_!_Complimenti',
#  'WORD_2_!_Comunque',
#  'WORD_2_!_Continua',
#  'WORD_2_!_Davvero',
#  'WORD_2_!_E',
#  'WORD_2_!_Fatelooo',
#  'WORD_2_!_Fidatevi',
#  'WORD_2_!_Grande',
#  'WORD_2_!_Grandioso',
#  'WORD_2_!_Grazie',
#  'WORD_2_!_IN',
#  'WORD_2_!_Lega',
#  'WORD_2_!_O',
#  'WORD_2_!_Passoh',
#  'WORD_2_!_Ragazzi',
#  'WORD_2_!_Riportiamo',
#  'WORD_2_!_Siete',
#  'WORD_2_!_Spreco',
#  'WORD_2_!_Tradotto',
#  'WORD_2_!_VERGOGNA',
#  'WORD_2_!_Vorrei',
#  'WORD_2_!__',
#  'WORD_2_!_ahahHhahahahahahahaha',
#  'WORD_2_!_ahaha',
#  'WORD_2_!_ahahahahahah',
#  'WORD_2_!_bel',
#  'WORD_2_!_canone',
#  'WORD_2_!_complimenti',
#  'WORD_2_!_comunque',
#  'WORD_2_!_continua',
#  'WORD_2_!_e',
#  'WORD_2_!_esisteranno',
#  'WORD_2_!_evviva',
#  'WORD_2_!_fantastico',
#  'WORD_2_!_grande',
#  'WORD_2_!_grazie',
#  'WORD_2_!_haha',
#  'WORD_2_!_hai',
#  'WORD_2_!_massima',
#  'WORD_2_!_non',
#  'WORD_2_!_o',
#  'WORD_2_!_purtroppo',
#  'WORD_2_!_questi',
#  'WORD_2_!_salvini',
#  'WORD_2_!_sempre',
#  'WORD_2_!_spero',
#  'WORD_2_!_un',
#  'WORD_2_!_uno',
#  'WORD_2_!_uomini',
#  'WORD_2_!_voglio',
#  'WORD_2_!_”',
#  'WORD_2_!_👏👏',
#  'WORD_2_!_🔝',
#  'WORD_2_!_😁',
#  'WORD_2_!_😄',
#  'WORD_2_!_😍😍',
#  'WORD_2_!_🙂',
#  'WORD_2_!attraverso_tua',
#  'WORD_2_!bravo!il_carnevale',
#  'WORD_2_!che_spettacolo!sei',
#  'WORD_2_!convertiti,_Dio',
#  'WORD_2_!cosa_vuoi',
#  'WORD_2_!credente,no!haaa_!quello',
#  'WORD_2_!dentro_!',
#  'WORD_2_!e_mi',
#  'WORD_2_!e_se',
#  'WORD_2_!faremo_i',
#  'WORD_2_!forza_fratello',
#  'WORD_2_!o_preferisci',
#  'WORD_2_!par_la',
#  'WORD_2_!quello_di',
#  'WORD_2_!ricordiamoci_che',
#  'WORD_2_!vedi_geroglifici',
#  'WORD_2_!…_Naturalmente',
#  'WORD_2_!❤Grande_Uomo❤',
#  'WORD_2_"_!',
#  'WORD_2_"_!!',
#  'WORD_2_"_!.....Comunque',
#  'WORD_2_"_"',
#  'WORD_2_"_#',
#  'WORD_2_"_\'',
#  'WORD_2_"_(',
#  'WORD_2_"_)',
#  'WORD_2_"_*non*',
#  'WORD_2_"_,',
#  'WORD_2_"_-',
#  'WORD_2_"_.',
#  'WORD_2_"_..',
#  'WORD_2_"_...',
#  'WORD_2_"_....',
#  'WORD_2_"_.....',
#  'WORD_2_"_......',
#  'WORD_2_"_...................MA',
#  'WORD_2_"_...Ah',
#  'WORD_2_"_...dice',
#  'WORD_2_"_...ehhhh',
#  'WORD_2_"_...in',
#  'WORD_2_"_.Gente',
#  'WORD_2_"_2',
#  'WORD_2_"_70',
#  'WORD_2_"_:',
#  'WORD_2_"_;',
#  'WORD_2_"_?',
#  'WORD_2_"_A',
#  'WORD_2_"_AAAAAH',
#  'WORD_2_"_AGVSSSS',
#  'WORD_2_"_ANALIZZARE',
#  'WORD_2_"_APPLICATE',
#  'WORD_2_"_Adesso',
#  'WORD_2_"_Affrettiamoci',
#  'WORD_2_"_Ah',
#  'WORD_2_"_Ahahaha',
#  'WORD_2_"_Allegri',
#  'WORD_2_"_Aloraaa',
#  'WORD_2_"_Amen',
#  'WORD_2_"_American',
#  'WORD_2_"_Anche',
#  'WORD_2_"_Appena',
#  'WORD_2_"_Ave',
#  'WORD_2_"_BELLA',
#  'WORD_2_"_Bambola',
#  'WORD_2_"_Benigni',
#  'WORD_2_"_CARO',
#  'WORD_2_"_CHE',
#  'WORD_2_"_CI',
#  'WORD_2_"_CIVILIZZATA',
#  'WORD_2_"_CLAUDIO',
#  'WORD_2_"_Calabria',
#  'WORD_2_"_Cani',
#  'WORD_2_"_Ci',
#  'WORD_2_"_Ciao',
#  'WORD_2_"_Come',
#  'WORD_2_"_DEMOCRAZIE',
#  'WORD_2_"_DONNA',
#  'WORD_2_"_Dietro',
#  'WORD_2_"_Dio',
#  'WORD_2_"_Dio.',
#  'WORD_2_"_Dirty',
#  'WORD_2_"_DripClan',
#  'WORD_2_"_E',
#  'WORD_2_"_E\'',
#  'WORD_2_"_EBREO',
#  'WORD_2_"_ED',
#  'WORD_2_"_EVOLUTA',
#  'WORD_2_"_Eh...............Ridendo',
#  'WORD_2_"_Ero-eroina',
#  'WORD_2_"_Esci',
#  'WORD_2_"_FUTURO',
#  'WORD_2_"_Fiumi',
#  'WORD_2_"_GENOCIDIO',
#  'WORD_2_"_GRANA',
#  'WORD_2_"_Grande',
#  'WORD_2_"_Grazie',
#  'WORD_2_"_Grida',
#  'WORD_2_"_Guai',
#  'WORD_2_"_I',
#  'WORD_2_"_IGNAAAZIOO',
#  'WORD_2_"_IL',
#  'WORD_2_"_INSOPPORTABILE',
#  'WORD_2_"_Il',
#  'WORD_2_"_Incapace',
#  'WORD_2_"_Io',
#  'WORD_2_"_L\'',
#  'WORD_2_"_LA',
#  'WORD_2_"_LIMITATI',
#  'WORD_2_"_LO',
#  'WORD_2_"_La',
#  'WORD_2_"_Le',
#  'WORD_2_"_Lei',
#  'WORD_2_"_Lo',
#  'WORD_2_"_Luca',
#  'WORD_2_"_Ma',
#  'WORD_2_"_Maroni',
#  'WORD_2_"_Mi',
#  'WORD_2_"_NON',
#  'WORD_2_"_NOOO',
#  'WORD_2_"_National',
#  'WORD_2_"_Nessun',
#  'WORD_2_"_Non',
#  'WORD_2_"_Nous',
#  'WORD_2_"_ONESTA\'',
#  'WORD_2_"_PERCHI',
#  'WORD_2_"_Pallottola',
#  'WORD_2_"_Parlare',
#  'WORD_2_"_Puffo',
#  'WORD_2_"_Quante',
#  'WORD_2_"_Quattro',
#  'WORD_2_"_Rivolgete',
#  'WORD_2_"_SEI',
#  'WORD_2_"_SESTA',
#  'WORD_2_"_SI',
#  'WORD_2_"_SIO',
#  'WORD_2_"_SOLD',
#  'WORD_2_"_SPECIALE',
#  'WORD_2_"_Santificati',
#  'WORD_2_"_Scusa',
#  'WORD_2_"_Shima',
#  'WORD_2_"_Solo',
#  'WORD_2_"_TU',
#  'WORD_2_"_Tell',
#  'WORD_2_"_Tener',
#  'WORD_2_"_The',
#  'WORD_2_"_Ti',
#  'WORD_2_"_Tuffiamoci',
#  'WORD_2_"_UFO',
#  'WORD_2_"_Vennero',
#  'WORD_2_"_Via',
#  'WORD_2_"_Voi',
#  'WORD_2_"_Vorrei',
#  'WORD_2_"_Và.......Ridendo',
#  'WORD_2_"_Yom',
#  'WORD_2_"_Zelig',
#  'WORD_2_"_a',
#  'WORD_2_"_abbiamo',
#  'WORD_2_"_accolti',
#  'WORD_2_"_adattano',
#  'WORD_2_"_ahahaha',
#  'WORD_2_"_ahahahahah',
#  'WORD_2_"_alloraaaaaa',
#  'WORD_2_"_aloraaaaaaaaaaa',
#  'WORD_2_"_alto',
#  'WORD_2_"_ambientale',
#  'WORD_2_"_andiamo',
#  'WORD_2_"_apologia',
#  'WORD_2_"_approfondimenti',
#  'WORD_2_"_aprite',
#  'WORD_2_"_avvenenza',
#  'WORD_2_"_avvenimenti',
#  'WORD_2_"_basita',
#  'WORD_2_"_bella',
#  'WORD_2_"_bellissima',
#  'WORD_2_"_bene',
#  'WORD_2_"_blablabla',
#  'WORD_2_"_buoni',
#  'WORD_2_"_c\'',
#  'WORD_2_"_cani',
#  'WORD_2_"_capo',
#  'WORD_2_"_capolavoro',
#  'WORD_2_"_cara',
#  'WORD_2_"_carta',
#  'WORD_2_"_cattivi',
#  'WORD_2_"_cazzo',
#  'WORD_2_"_centro',
#  'WORD_2_"_che',
#  'WORD_2_"_chi',
#  'WORD_2_"_chissà',
#  'WORD_2_"_ci',
#  'WORD_2_"_collega',
#  'WORD_2_"_come',
#  'WORD_2_"_con',
#  'WORD_2_"_contraddistinta',
#  'WORD_2_"_contro',
#  'WORD_2_"_credere',
#  'WORD_2_"_da',
#  'WORD_2_"_decedo',
#  'WORD_2_"_decommissioning',
#  'WORD_2_"_di',
#  'WORD_2_"_dialogo',
#  'WORD_2_"_dicce',
#  'WORD_2_"_dice',
#  'WORD_2_"_dicono',
#  'WORD_2_"_dimenticano',
#  'WORD_2_"_dittatore',
#  'WORD_2_"_diverso',
#  'WORD_2_"_domanda',
#  'WORD_2_"_dove',
#  'WORD_2_"_dovremmo',
#  'WORD_2_"_duello',
#  'WORD_2_"_e',
#  'WORD_2_"_era',
#  'WORD_2_"_erano',
#  'WORD_2_"_esci',
#  'WORD_2_"_esemplare',
#  'WORD_2_"_essere',
#  'WORD_2_"_etc.',
#  'WORD_2_"_familiare',
#  'WORD_2_"_farfallina',
#  'WORD_2_"_feccia',
#  'WORD_2_"_fede',
#  'WORD_2_"_figlia',
#  'WORD_2_"_filopalestinese',
#  'WORD_2_"_fin',
#  'WORD_2_"_format',
#  'WORD_2_"_foto',
#  'WORD_2_"_fratello',
#  'WORD_2_"_friends',
#  'WORD_2_"_fuori',
#  'WORD_2_"_furono',
#  'WORD_2_"_genio',
#  'WORD_2_"_gente',
#  'WORD_2_"_giocano',
#  'WORD_2_"_giornalista',
#  'WORD_2_"_giovanotti',
#  'WORD_2_"_giudicanti',
#  'WORD_2_"_gli',
#  'WORD_2_"_governano',
#  'WORD_2_"_grande',
#  'WORD_2_"_grazie',
#  'WORD_2_"_grigio',
#  'WORD_2_"_guerra',
#  'WORD_2_"_ha',
#  'WORD_2_"_hahahahaha',
#  'WORD_2_"_hai',
#  'WORD_2_"_i',
#  'WORD_2_"_il',
#  'WORD_2_"_immensa',
#  'WORD_2_"_immigrati',
#  'WORD_2_"_imposta',
#  'WORD_2_"_improvviso',
#  'WORD_2_"_in',
#  'WORD_2_"_incontri',
#  'WORD_2_"_indagata',
#  'WORD_2_"_indecisa',
#  'WORD_2_"_innovativa',
#  'WORD_2_"_intellettuale',
#  'WORD_2_"_intenso',
#  'WORD_2_"_io',
#  'WORD_2_"_italiano',
#  'WORD_2_"_killer',
#  'WORD_2_"_l\'',
#  'WORD_2_"_la',
#  'WORD_2_"_lei',
#  'WORD_2_"_liberta',
#  'WORD_2_"_like',
#  'WORD_2_"_ll',
#  'WORD_2_"_ma',
#  'WORD_2_"_mah',
#  'WORD_2_"_mal',
#  'WORD_2_"_male',
#  'WORD_2_"_membri',
#  'WORD_2_"_mettetevelo',
#  'WORD_2_"_mi',
#  'WORD_2_"_migrano',
#  'WORD_2_"_ministra',
#  'WORD_2_"_momenti',
#  'WORD_2_"_musica',
#  'WORD_2_"_nemico',
#  'WORD_2_"_nessuna',
#  'WORD_2_"_neutra',
#  'WORD_2_"_nietzsche',
#  'WORD_2_"_nira',
#  'WORD_2_"_no',
#  'WORD_2_"_noblesse',
#  'WORD_2_"_non',
#  'WORD_2_"_nonche',
#  'WORD_2_"_norma',
#  'WORD_2_"_nostro',
#  'WORD_2_"_nuovi',
#  'WORD_2_"_o',
#  'WORD_2_"_odio',
#  'WORD_2_"_opposizioni',
#  'WORD_2_"_ordinaria',
#  'WORD_2_"_pacifista',
#  'WORD_2_"_padreceleste.com',
#  'WORD_2_"_padri',
#  'WORD_2_"_palestinesi',
#  'WORD_2_"_parassita',
#  'WORD_2_"_pareva',
#  'WORD_2_"_partigiano',
#  'WORD_2_"_patetico',
#  'WORD_2_"_pensate',
#  'WORD_2_"_pensieri',
#  'WORD_2_"_pensionati',
#  'WORD_2_"_per',
#  'WORD_2_"_perbenista',
#  'WORD_2_"_pericolo',
#  'WORD_2_"_persona',
#  'WORD_2_"_petrodollari',
#  'WORD_2_"_politica',
#  'WORD_2_"_polivinilcoloruro',
#  'WORD_2_"_popolo',
#  'WORD_2_"_populista',
#  'WORD_2_"_potrebbero',
#  'WORD_2_"_prenda',
#  'WORD_2_"_presunta',
#  'WORD_2_"_pro',
#  'WORD_2_"_programma',
#  'WORD_2_"_provare',
#  'WORD_2_"_pura',
#  'WORD_2_"_quali',
#  'WORD_2_"_quando',
#  'WORD_2_"_quanto',
#  'WORD_2_"_quasi',
#  'WORD_2_"_quello',
#  'WORD_2_"_ragionare',
#  'WORD_2_"_religioni',
#  'WORD_2_"_ricomprenda',
#  'WORD_2_"_riesumato',
#  'WORD_2_"_rigido',
#  'WORD_2_"_risorsa',
#  'WORD_2_"_risorse',
#  'WORD_2_"_rubato',
#  'WORD_2_"_rumore',
#  'WORD_2_"_salvini',
#  'WORD_2_"_sanno',
#  'WORD_2_"_sapete',
#  'WORD_2_"_sardus',
#  'WORD_2_"_sarebbe',
#  'WORD_2_"_sbeffeggiava',
#  'WORD_2_"_sclerotico',
#  'WORD_2_"_scoperto',
#  'WORD_2_"_se',
#  'WORD_2_"_secessione',
#  'WORD_2_"_secondo',
#  'WORD_2_"_sei',
#  'WORD_2_"_senza',
#  'WORD_2_"_sfumando',
#  'WORD_2_"_signor',
#  'WORD_2_"_sintesi',
#  'WORD_2_"_sistema',
#  'WORD_2_"_smacchiamo',
#  'WORD_2_"_sono',
#  'WORD_2_"_sopravvivere',
#  'WORD_2_"_sostegno',
#  'WORD_2_"_specchietti',
#  'WORD_2_"_stato',
#  'WORD_2_"_stavano',
#  'WORD_2_"_su',
#  'WORD_2_"_sviste',
#  'WORD_2_"_tac',
#  'WORD_2_"_tenere',
#  'WORD_2_"_terra',
#  'WORD_2_"_terza',
#  'WORD_2_"_toscanacci',
#  'WORD_2_"_tot',
#  'WORD_2_"_tra',
#  'WORD_2_"_traduce',
#  'WORD_2_"_travellerriferimento',
#  'WORD_2_"_trovato"',
#  'WORD_2_"_un',
#  'WORD_2_"_una',
#  'WORD_2_"_unione',
#  'WORD_2_"_vedere',
#  'WORD_2_"_vedete',
#  'WORD_2_"_viaggiatore',
#  'WORD_2_"_violentato',
#  'WORD_2_"_vivere',
#  'WORD_2_"_vogliono',
#  'WORD_2_"_vu-cumprà',
#  'WORD_2_"_we',
#  'WORD_2_"_xD',
#  'WORD_2_"_youtuber',
#  'WORD_2_"_È',
#  'WORD_2_"_è',
#  'WORD_2_"_❤',
#  'WORD_2_"_😂',
#  'WORD_2_"_😂😂😂😂😂😂😂😂😂😂😂😙😙😙😙😙❤💙💙❤❤💋💋💋❤💋💋❤❤💙😍😍😍',
#  'WORD_2_"_😂🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣😂😂😂😂🤣😂🤣😂🤣😂🤣😂🤣😂😂😂🤣🤣😂🤣😂🤣',
#  'WORD_2_"_😣',
#  'WORD_2_#NAME_?',
#  'WORD_2_#SIOISTHEBEST_!',
#  'WORD_2_#_ForzaPovia',
#  'WORD_2_#_RESISTENZA',
#  'WORD_2_#_e',
#  'WORD_2_#boldrini_bambola',
#  'WORD_2_#donnenonbambolegonfiabili_IL',
#  'WORD_2_#emmamarrone_#browncrew',
#  'WORD_2_#favirisponde_vai',
#  'WORD_2_#lezzini_#maideboli',
#  'WORD_2_#nonèlinferno_#emmamarrone',
#  'WORD_2_#penisforharambe_#lezzini',
#  'WORD_2_#saschenzo_a',
#  'WORD_2_%_.',
#  'WORD_2_%_...',
#  'WORD_2_%_5stelle',
#  'WORD_2_%_MADE',
#  'WORD_2_%_W',
#  'WORD_2_%_che',
#  'WORD_2_%_di',
#  'WORD_2_%_e',
#  'WORD_2_%_non',
#  'WORD_2_%_questa',
#  'WORD_2_%_salvini',
#  'WORD_2_%_una',
#  'WORD_2_&_MORO',
#  'WORD_2_&_mates',
#  "WORD_2_''SBAGLIATI'_'",
#  "WORD_2_''_comici'",
#  "WORD_2_''_giusto",
#  "WORD_2_''_io",
#  "WORD_2_''_non",
#  "WORD_2_''_sono",
#  "WORD_2_''_tradire",
#  "WORD_2_'63_e",
#  "WORD_2_'64_The",
#  "WORD_2_'80_e",
#  "WORD_2_'90.._.",
#  "WORD_2_'92_?",
#  "WORD_2_'93_che",
#  "WORD_2_'93_mi",
#  "WORD_2_'95_sembrava",
#  "WORD_2_'Abd_Allâh",
#  "WORD_2_'Eva_'",
#  "WORD_2_'THE_WORST'",
#  "WORD_2_'_!",
#  'WORD_2_\'_"',
#  "WORD_2_'_'",
#  "WORD_2_'_(",
#  "WORD_2_'_,",
#  "WORD_2_'_-",
#  "WORD_2_'_.",
#  "WORD_2_'_BENIGNI",
#  "WORD_2_'_D",
#  "WORD_2_'_Ecco",
#  "WORD_2_'_IL",
#  "WORD_2_'_INTERA",
#  "WORD_2_'_Ibrahimovic",
#  "WORD_2_'_Il",
#  "WORD_2_'_Islanda",
#  "WORD_2_'_Italia",
#  "WORD_2_'_LA",
#  "WORD_2_'_Moni",
#  "WORD_2_'_Musica",
#  "WORD_2_'_Pierfrancesco",
#  "WORD_2_'_San",
#  "WORD_2_'_Se",
#  "WORD_2_'_TEMUTA",
#  "WORD_2_'_VERITIERA",
#  "WORD_2_'_We",
#  "WORD_2_'_a",
#  "WORD_2_'_alcune",
#  "WORD_2_'_ammalata",
#  "WORD_2_'_ancora",
#  "WORD_2_'_andiamo",
#  "WORD_2_'_andrei",
#  "WORD_2_'_aria",
#  "WORD_2_'_bella",
#  "WORD_2_'_bellisimo",
#  "WORD_2_'_bello",
#  "WORD_2_'_bene.....l",
#  "WORD_2_'_bravo",
#  "WORD_2_'_camminera",
#  "WORD_2_'_ch'",
#  "WORD_2_'_che",
#  "WORD_2_'_chi",
#  "WORD_2_'_ci",
#  "WORD_2_'_cit",
#  "WORD_2_'_come",
#  "WORD_2_'_composta",
#  "WORD_2_'_con",
#  "WORD_2_'_considero",
#  "WORD_2_'_cosi",
#  "WORD_2_'_così",
#  "WORD_2_'_da",
#  "WORD_2_'_dando",
#  "WORD_2_'_datagli",
#  "WORD_2_'_davvero",
#  "WORD_2_'_deciso",
#  "WORD_2_'_di",
#  "WORD_2_'_dimenticando",
#  "WORD_2_'_disponibile",
#  "WORD_2_'_dissidenti",
#  "WORD_2_'_dominante",
#  "WORD_2_'_dove",
#  "WORD_2_'_e",
#  "WORD_2_'_economico",
#  "WORD_2_'_enorme",
#  "WORD_2_'_esisteva",
#  "WORD_2_'_facile",
#  "WORD_2_'_famoso",
#  "WORD_2_'_fantastico",
#  "WORD_2_'_fare",
#  "WORD_2_'_felice",
#  "WORD_2_'_figa",
#  "WORD_2_'_fino",
#  "WORD_2_'_forse",
#  "WORD_2_'_gay",
#  "WORD_2_'_gia",
#  "WORD_2_'_giusto",
#  "WORD_2_'_gli",
#  "WORD_2_'_ha",
#  "WORD_2_'_hanno",
#  "WORD_2_'_il",
#  "WORD_2_'_immenso",
#  "WORD_2_'_immigrazione",
#  "WORD_2_'_in",
#  "WORD_2_'_indietro",
#  "WORD_2_'_indimenticabile!Sei",
#  "WORD_2_'_informato",
#  "WORD_2_'_inutile",
#  "WORD_2_'_ispirata",
#  "WORD_2_'_l",
#  "WORD_2_'_la",
#  "WORD_2_'_lecito",
#  "WORD_2_'_limitativo",
#  "WORD_2_'_lui",
#  "WORD_2_'_ma",
#  "WORD_2_'_mai",
#  "WORD_2_'_matto",
#  "WORD_2_'_molto",
#  "WORD_2_'_muoro",
#  "WORD_2_'_na",
#  "WORD_2_'_nazionale",
#  "WORD_2_'_non",
#  "WORD_2_'_nuova",
#  "WORD_2_'_per",
#  "WORD_2_'_perche",
#  "WORD_2_'_però",
#  "WORD_2_'_piaciuto",
#  "WORD_2_'_più",
#  "WORD_2_'_pochissimo",
#  "WORD_2_'_politico",
#  "WORD_2_'_presente",
#  "WORD_2_'_promiscuita",
#  "WORD_2_'_propriamente",
#  "WORD_2_'_qualcosa",
#  "WORD_2_'_quando",
#  "WORD_2_'_questa",
#  "WORD_2_'_queste",
#  "WORD_2_'_rallentata",
#  "WORD_2_'_responsabile",
#  "WORD_2_'_ricorda",
#  "WORD_2_'_riuscito",
#  "WORD_2_'_satanico",
#  "WORD_2_'_sbarcato.",
#  "WORD_2_'_scritto",
#  "WORD_2_'_se",
#  "WORD_2_'_sei",
#  "WORD_2_'_sembrato",
#  "WORD_2_'_semplici",
#  "WORD_2_'_sessismo",
#  "WORD_2_'_si",
#  "WORD_2_'_simultanea",
#  "WORD_2_'_sino",
#  "WORD_2_'_spesso",
#  "WORD_2_'_sragiona",
#  "WORD_2_'_stare",
#  "WORD_2_'_stato",
#  "WORD_2_'_sti",
#  "WORD_2_'_stia",
#  "WORD_2_'_sto",
#  "WORD_2_'_su",
#  "WORD_2_'_te",
#  "WORD_2_'_tenerezza",
#  "WORD_2_'_terroristici",
#  "WORD_2_'_tesoro",
#  "WORD_2_'_tornati",
#  "WORD_2_'_tra",
#  "WORD_2_'_trasuda",
#  "WORD_2_'_umanita",
#  "WORD_2_'_un",
#  "WORD_2_'_un'",
#  "WORD_2_'_una",
#  "WORD_2_'_veramente",
#  "WORD_2_'_verita",
#  "WORD_2_'_vero",
#  "WORD_2_'_😂😂😂😂😂",
#  "WORD_2_'e_Napul",
#  "WORD_2_'e_ndrocchia",
#  "WORD_2_'m_italian",
#  "WORD_2_'o_passat",
#  "WORD_2_'s_ITALIA",
#  "WORD_2_'s_Simulator",
#  "WORD_2_'s_act",
#  "WORD_2_'s_ignorance..",
#  "WORD_2_'s_wonderful",
#  "WORD_2_'t_happen",
#  "WORD_2_'t_laugh",
#  'WORD_2_(_!',
#  'WORD_2_(_(',
#  'WORD_2_(_*',
#  'WORD_2_(_**',
#  'WORD_2_(_***',
#  'WORD_2_(_****',
#  'WORD_2_(_+Sio😊😊',
#  'WORD_2_(_.',
#  'WORD_2_(_...',
#  'WORD_2_(_...........',
#  'WORD_2_(_..ma',
#  'WORD_2_(_1648',
#  'WORD_2_(_1863',
#  'WORD_2_(_1997-2017',
#  'WORD_2_(_5',
#  'WORD_2_(_:',
#  'WORD_2_(_=mistificazione',
#  'WORD_2_(_?',
#  'WORD_2_(_A',
#  'WORD_2_(_Achille',
#  'WORD_2_(_Aldilà',
#  'WORD_2_(_American',
#  'WORD_2_(_Arcangeli',
#  'WORD_2_(_Atti',
#  'WORD_2_(_BPA',
#  'WORD_2_(_Beh',
#  'WORD_2_(_Berlusca',
#  'WORD_2_(_Brando',
#  'WORD_2_(_Cairo',
#  'WORD_2_(_Cavallo',
#  'WORD_2_(_DATO',
#  'WORD_2_(_Dato',
#  'WORD_2_(_E',
#  'WORD_2_(_Eccezionale',
#  'WORD_2_(_G.Bongiorno',
#  'WORD_2_(_Genesi',
#  'WORD_2_(_Germania',
#  'WORD_2_(_Historia',
#  'WORD_2_(_IRREVERSIBILE',
#  'WORD_2_(_Inghilterra',
#  'WORD_2_(_Inoltre',
#  'WORD_2_(_Iraq',
#  'WORD_2_(_It',
#  'WORD_2_(_Italiani',
#  'WORD_2_(_Lega',
#  'WORD_2_(_Loro',
#  'WORD_2_(_Lucifero',
#  'WORD_2_(_Magari',
#  'WORD_2_(_Michele',
#  'WORD_2_(_NOI',
#  'WORD_2_(_ONU-UE',
#  'WORD_2_(_Oriana',
#  'WORD_2_(_Palermo',
#  'WORD_2_(_PdL',
#  'WORD_2_(_Per',
#  'WORD_2_(_Purtroppo',
#  'WORD_2_(_Quando',
#  'WORD_2_(_SONO',
#  'WORD_2_(_Salvini',
#  'WORD_2_(_UNIPOL',
#  'WORD_2_(_V',
#  'WORD_2_(_Vita',
#  'WORD_2_(_a',
#  'WORD_2_(_abbiamo',
#  'WORD_2_(_alcuni',
#  'WORD_2_(_aldilà',
#  'WORD_2_(_altrimenti',
#  'WORD_2_(_anche',
#  'WORD_2_(_ancora',
#  'WORD_2_(_andazzo',
#  'WORD_2_(_avendo',
#  'WORD_2_(_avesse',
#  'WORD_2_(_bella',
#  'WORD_2_(_brillantemente',
#  'WORD_2_(_bromazepam',
#  'WORD_2_(_buona',
#  "WORD_2_(_c'",
#  'WORD_2_(_canotto',
#  'WORD_2_(_capitan',
#  'WORD_2_(_ce',
#  'WORD_2_(_certo',
#  'WORD_2_(_che',
#  'WORD_2_(_ci',
#  'WORD_2_(_cibo',
#  'WORD_2_(_cioè',
#  'WORD_2_(_classe',
#  'WORD_2_(_come',
#  'WORD_2_(_comprendendo',
#  'WORD_2_(_compresa',
#  'WORD_2_(_con',
#  'WORD_2_(_coperta',
#  'WORD_2_(_cosa',
#  'WORD_2_(_credo',
#  'WORD_2_(_da',
#  'WORD_2_(_demoni',
#  'WORD_2_(_dentro',
#  'WORD_2_(_di',
#  'WORD_2_(_dice',
#  'WORD_2_(_dopo',
#  'WORD_2_(_e',
#  'WORD_2_(_eccezione',
#  'WORD_2_(_en',
#  'WORD_2_(_entrambi',
#  'WORD_2_(_estrema',
#  'WORD_2_(_fai',
#  'WORD_2_(_falso',
#  'WORD_2_(_femminile',
#  'WORD_2_(_finto',
#  'WORD_2_(_forse',
#  'WORD_2_(_gli',
#  'WORD_2_(_gran',
#  'WORD_2_(_ha',
#  'WORD_2_(_i',
#  'WORD_2_(_il',
#  'WORD_2_(_in',
#  'WORD_2_(_inclusi',
#  'WORD_2_(_inquadrato',
#  'WORD_2_(_insieme',
#  'WORD_2_(_l',
#  'WORD_2_(_la',
#  'WORD_2_(_le',
#  'WORD_2_(_lei',
#  'WORD_2_(_lo',
#  'WORD_2_(_lobby',
#  'WORD_2_(_luca',
#  'WORD_2_(_ma',
#  'WORD_2_(_molti',
#  'WORD_2_(_nn',
#  'WORD_2_(_non',
#  'WORD_2_(_normanni',
#  'WORD_2_(_o',
#  'WORD_2_(_oltre',
#  'WORD_2_(_oltretutto',
#  'WORD_2_(_ottimo',
#  'WORD_2_(_otto',
#  'WORD_2_(_ovviamente',
#  'WORD_2_(_p.s.',
#  'WORD_2_(_partendo',
#  'WORD_2_(_pena',
#  'WORD_2_(_per',
#  'WORD_2_(_perché',
#  'WORD_2_(_poichè',
#  'WORD_2_(_que',
#  'WORD_2_(_quelle',
#  'WORD_2_(_quelli',
#  'WORD_2_(_questione',
#  'WORD_2_(_questo',
#  'WORD_2_(_quindi',
#  'WORD_2_(_rappresentante',
#  'WORD_2_(_ricordo',
#  'WORD_2_(_salvata',
#  'WORD_2_(_scaricando',
#  'WORD_2_(_scusate',
#  'WORD_2_(_se',
#  'WORD_2_(_sebbene',
#  'WORD_2_(_secondo',
#  'WORD_2_(_seguace',
#  'WORD_2_(_senza',
#  'WORD_2_(_si',
#  'WORD_2_(_sic',
#  'WORD_2_(_solo',
#  'WORD_2_(_sono',
#  'WORD_2_(_soprattutto',
#  'WORD_2_(_sopratutto',
#  'WORD_2_(_speciale',
#  'WORD_2_(_spero',
#  'WORD_2_(_spesso',
#  'WORD_2_(_stato',
#  ...]

# %%
import matplotlib.pyplot as plt

# Assuming `coefs` is your coefficients obtained from the SVM model
# Assuming `features_names` is a list containing the names of your features
idx = 0
class_coefs = coefs[idx]

feature_importances = {feature_name: coef for feature_name, coef in zip(features_names, class_coefs)}
sorted_feature_importances = dict(sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))

num_to_plot = 15
print(f'Feature importance')
plt.figure(figsize=(10, 8))
plt.barh(range(num_to_plot), list(sorted_feature_importances.values())[:num_to_plot], align='center')
plt.yticks(range(num_to_plot), list(sorted_feature_importances.keys())[:num_to_plot])
plt.show()
# Out:
# Feature importance

# %%
coef = coefs.ravel()
top_positive_coefficients = np.argsort(coef)[-20:]
top_negative_coefficients = np.argsort(coef)[:20]
top_coefficients = np.hstack([top_negative_coefficients, top_positive_coefficients])
# create plot
plt.figure(figsize=(15, 10))
colors = ["red" if c < 0 else "blue" for c in coef[top_coefficients]]
plt.bar(np.arange(2 * 20), coef[top_coefficients], color=colors)
feature_names = np.array(features_names)
plt.xticks(np.arange(1, 1 + 2 * 20), feature_names[top_coefficients], rotation=60, ha="right")
plt.show()

# %% [markdown]
# # Trigrammi con POS, Lemma, Word

# %%
# Bigrammi con Word, POS, Lemma
extract_documents_ngrams(all_documents, n=3) # n=unigramma, bigramma, trigramma, quadrigramma
extract_documents_ngrams_normalized(all_documents, n=3)
def train_test_split(all_documents):
    train_features_dict, train_labels = [], []
    test_features_dict, test_labels = [], []
    
    for document in all_documents:
        if document.split == 'training':
            train_features_dict.append(document.features)
            train_labels.append(document.gender)
        else:
            test_features_dict.append(document.features)
            test_labels.append(document.gender)
    
    return train_features_dict, train_labels, test_features_dict, test_labels
train_features_dict, train_labels, test_features_dict, test_labels = train_test_split(all_documents)
len(train_features_dict), len(train_labels), len(test_features_dict), len(test_labels)

print("Report modello con trigrammi")
print()
get_num_features(train_features_dict)
print(f'Numero features: {get_num_features(train_features_dict)}')
#train_features_dict = filter_features(train_features_dict, 5)
#print(f'Numero features dopo il filtro: {get_num_features(train_features_dict)}')


vectorizer = DictVectorizer()
X_train = vectorizer.fit_transform(train_features_dict)
vectorizer.get_feature_names_out(X_train).tolist()

scaler = MaxAbsScaler()
X_train = scaler.fit_transform(X_train)

# Define the parameter grid to search through
param_grid = {
    'C': [10, 1, 0.1, 0.01, 0.001],  # Regularization parameter
    'dual': [True, False]
}

# Initialize SVM with linear kernel
svc = LinearSVC()

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=5, refit=True)

# Fit the grid search to your data
grid_search.fit(X_train, train_labels)

# Get mean test scores across folds
mean_test_scores = grid_search.cv_results_['mean_test_score']

print()
# Print the best parameters and best score
print("Best parameters found:", grid_search.best_params_)
print("Best score found:", grid_search.best_score_)
X_test = vectorizer.transform(test_features_dict)
X_test = scaler.transform(X_test)
# Get the best estimator (model) found by grid search
best_model = grid_search.best_estimator_

# Now, you can use this best_model to make predictions on new data
# For example, if you have new data X_new, you can predict its labels as follows:
predictions = best_model.predict(X_test)

test_predictions = predictions
print(classification_report(test_labels, test_predictions, zero_division=0)) # output_dict=True
print()


coefs = best_model.coef_  # ndarray of shape (1, n_features) if n_classes == 2 else (n_classes, n_features)
coefs.shape
features_names = vectorizer.get_feature_names_out(X_train).tolist()
features_names

# Assuming `coefs` is your coefficients obtained from the SVM model
# Assuming `features_names` is a list containing the names of your features
idx = 0
class_coefs = coefs[idx]

feature_importances = {feature_name: coef for feature_name, coef in zip(features_names, class_coefs)}
sorted_feature_importances = dict(sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))

num_to_plot = 15
print(f'Feature importance')
plt.figure(figsize=(10, 8))
plt.barh(range(num_to_plot), list(sorted_feature_importances.values())[:num_to_plot], align='center')
plt.yticks(range(num_to_plot), list(sorted_feature_importances.keys())[:num_to_plot])
plt.show()

coef = coefs.ravel()
top_positive_coefficients = np.argsort(coef)[-20:]
top_negative_coefficients = np.argsort(coef)[:20]
top_coefficients = np.hstack([top_negative_coefficients, top_positive_coefficients])
# create plot
plt.figure(figsize=(15, 10))
colors = ["red" if c < 0 else "blue" for c in coef[top_coefficients]]
plt.bar(np.arange(2 * 20), coef[top_coefficients], color=colors)
feature_names = np.array(features_names)
plt.xticks(np.arange(1, 1 + 2 * 20), feature_names[top_coefficients], rotation=60, ha="right")
plt.show()



print("Confusion Matrix")
ConfusionMatrixDisplay.from_predictions(test_labels, test_predictions, xticks_rotation='vertical', cmap='Blues')
# Out:
# Report modello con trigrammi
#
# Numero features: 82421
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters found: {'C': 0.01, 'dual': True}
# Best score found: 0.502844141069397
#               precision    recall  f1-score   support
#
#            F       0.50      0.94      0.65      2200
#            M       0.51      0.07      0.12      2200
#
#     accuracy                           0.50      4400
#    macro avg       0.51      0.50      0.39      4400
# weighted avg       0.51      0.50      0.39      4400
#
#
# Feature importance
# Confusion Matrix

# %% [markdown]
# # Quadrigrammi con POS, Lemma, Word

# %%
# Bigrammi con Word, POS, Lemma
extract_documents_ngrams(all_documents, n=4) # n=unigramma, bigramma, trigramma, quadrigramma
extract_documents_ngrams_normalized(all_documents, n=4)
def train_test_split(all_documents):
    train_features_dict, train_labels = [], []
    test_features_dict, test_labels = [], []
    
    for document in all_documents:
        if document.split == 'training':
            train_features_dict.append(document.features)
            train_labels.append(document.gender)
        else:
            test_features_dict.append(document.features)
            test_labels.append(document.gender)
    
    return train_features_dict, train_labels, test_features_dict, test_labels
train_features_dict, train_labels, test_features_dict, test_labels = train_test_split(all_documents)
len(train_features_dict), len(train_labels), len(test_features_dict), len(test_labels)

print("Report modello con quadrigrammi")
print()
get_num_features(train_features_dict)
print(f'Numero features: {get_num_features(train_features_dict)}')
#train_features_dict = filter_features(train_features_dict, 5)
#print(f'Numero features dopo il filtro: {get_num_features(train_features_dict)}')


vectorizer = DictVectorizer()
X_train = vectorizer.fit_transform(train_features_dict)
vectorizer.get_feature_names_out(X_train).tolist()

scaler = MaxAbsScaler()
X_train = scaler.fit_transform(X_train)

# Define the parameter grid to search through
param_grid = {
    'C': [10, 1, 0.1, 0.01, 0.001],  # Regularization parameter
    'dual': [True, False]
}

# Initialize SVM with linear kernel
svc = LinearSVC()

# Initialize GridSearchCV with 5-fold cross-validation
grid_search = GridSearchCV(estimator=svc, param_grid=param_grid, cv=5, refit=True)

# Fit the grid search to your data
grid_search.fit(X_train, train_labels)

# Get mean test scores across folds
mean_test_scores = grid_search.cv_results_['mean_test_score']

print()
# Print the best parameters and best score
print("Best parameters found:", grid_search.best_params_)
print("Best score found:", grid_search.best_score_)
X_test = vectorizer.transform(test_features_dict)
X_test = scaler.transform(X_test)
# Get the best estimator (model) found by grid search
best_model = grid_search.best_estimator_

# Now, you can use this best_model to make predictions on new data
# For example, if you have new data X_new, you can predict its labels as follows:
predictions = best_model.predict(X_test)

test_predictions = predictions
print(classification_report(test_labels, test_predictions, zero_division=0)) # output_dict=True
print()


coefs = best_model.coef_  # ndarray of shape (1, n_features) if n_classes == 2 else (n_classes, n_features)
coefs.shape
features_names = vectorizer.get_feature_names_out(X_train).tolist()
features_names

# Assuming `coefs` is your coefficients obtained from the SVM model
# Assuming `features_names` is a list containing the names of your features
idx = 0
class_coefs = coefs[idx]

feature_importances = {feature_name: coef for feature_name, coef in zip(features_names, class_coefs)}
sorted_feature_importances = dict(sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))

num_to_plot = 15
print(f'Feature importance')
plt.figure(figsize=(10, 8))
plt.barh(range(num_to_plot), list(sorted_feature_importances.values())[:num_to_plot], align='center')
plt.yticks(range(num_to_plot), list(sorted_feature_importances.keys())[:num_to_plot])
plt.show()

coef = coefs.ravel()
top_positive_coefficients = np.argsort(coef)[-20:]
top_negative_coefficients = np.argsort(coef)[:20]
top_coefficients = np.hstack([top_negative_coefficients, top_positive_coefficients])
# create plot
plt.figure(figsize=(15, 10))
colors = ["red" if c < 0 else "blue" for c in coef[top_coefficients]]
plt.bar(np.arange(2 * 20), coef[top_coefficients], color=colors)
feature_names = np.array(features_names)
plt.xticks(np.arange(1, 1 + 2 * 20), feature_names[top_coefficients], rotation=60, ha="right")
plt.show()



print("Confusion Matrix")
ConfusionMatrixDisplay.from_predictions(test_labels, test_predictions, xticks_rotation='vertical', cmap='Blues')
# Out:
# Report modello con quadrigrammi
#
# Numero features: 81095
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters found: {'C': 0.1, 'dual': True}
# Best score found: 0.5007963594994311
#               precision    recall  f1-score   support
#
#            F       0.50      0.99      0.67      2200
#            M       0.64      0.01      0.02      2200
#
#     accuracy                           0.50      4400
#    macro avg       0.57      0.50      0.34      4400
# weighted avg       0.57      0.50      0.34      4400
#
#
# Feature importance
# Confusion Matrix
